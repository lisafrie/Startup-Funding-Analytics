# %% [markdown]
# #Set up Code

# %%
# !pip install pandasql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandasql in /usr/local/lib/python3.7/dist-packages (0.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.3.5)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.4.43)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (2.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (4.1.1)

# %%
import pandas as pd
import numpy as np
import datetime as dt
import pandasql as ps

# %%
prefix = '/content/drive'
from google.colab import drive
drive.mount(prefix, force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Companies Analysis and Preprocessing

# %%
def set_to_floats(x):
  x = str(x)
  if x == '':
    return np.nan
  if x.strip() == '-':
    return np.nan
  if x == 'nan':
    return np.nan
  return float(x.replace(',', ''))

# %%
companies = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CIS 550/companies.csv')
companies[' funding_total_usd '] = companies[' funding_total_usd '].apply(lambda x: set_to_floats(x))
companies
# Out:
#                                                permalink  \
# 0                                  /organization/waywire
# 1                        /organization/tv-communications
# 2                          /organization/rock-your-paper
# 3                         /organization/in-touch-network
# 4                         /organization/r-ranch-and-mine
# ...                                                  ...
# 49433                                /organization/zzish
# 49434  /organization/zznode-science-and-technology-co...
# 49435                          /organization/zzzzapp-com
# 49436                         /organization/a-list-games
# 49437                                    /organization/x
#
#                                 name                   homepage_url  \
# 0                           #waywire         http://www.waywire.com
# 1                 &TV Communications          http://enjoyandtv.com
# 2                  'Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 4                 -R- Ranch and Mine                            NaN
# ...                              ...                            ...
# 49433                          Zzish           http://www.zzish.com
# 49434  ZZNode Science and Technology          http://www.zznode.com
# 49435          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 49436                  [a]list games      http://www.alistgames.com
# 49437                          [x+1]       http://www.xplusone.com/
#
#                                            category_list  \
# 0             |Entertainment|Politics|Social Media|News|
# 1                                                |Games|
# 2                                 |Publishing|Education|
# 3      |Electronics|Guides|Coffee|Restaurants|Music|i...
# 4                          |Tourism|Entertainment|Games|
# ...                                                  ...
# 49433  |Analytics|Gamification|Developer APIs|iOS|And...
# 49434                              |Enterprise Software|
# 49435      |Web Development|Advertising|Wireless|Mobile|
# 49436                                            |Games|
# 49437                              |Enterprise Software|
#
#                      market    funding_total_usd      status country_code  \
# 0                      News             1750000.0   acquired          USA
# 1                     Games             4000000.0  operating          USA
# 2                Publishing               40000.0  operating          EST
# 3               Electronics             1500000.0  operating          GBR
# 4                   Tourism               60000.0  operating          USA
# ...                      ...                  ...        ...          ...
# 49433             Education              320000.0  operating          GBR
# 49434   Enterprise Software             1587301.0  operating          CHN
# 49435       Web Development               97398.0  operating          HRV
# 49436                 Games             9300000.0  operating          NaN
# 49437   Enterprise Software            45000000.0  operating          USA
#
#       state_code         region         city  funding_rounds  founded_at  \
# 0             NY  New York City     New York               1  2012-06-01
# 1             CA    Los Angeles  Los Angeles               2         NaN
# 2            NaN        Tallinn      Tallinn               1  2012-10-26
# 3            NaN         London       London               1  2011-04-01
# 4             TX         Dallas   Fort Worth               2  2014-01-01
# ...          ...            ...          ...             ...         ...
# 49433        NaN         London       London               1  2013-01-28
# 49434        NaN        Beijing      Beijing               1         NaN
# 49435        NaN          Split        Split               5  2012-05-13
# 49436        NaN            NaN          NaN               1         NaN
# 49437         NY  New York City     New York               4  1999-01-01
#
#       founded_month founded_quarter  founded_year first_funding_at  \
# 0           2012-06         2012-Q2        2012.0       2012-06-30
# 1               NaN             NaN           NaN       2010-06-04
# 2           2012-10         2012-Q4        2012.0       2012-08-09
# 3           2011-04         2011-Q2        2011.0       2011-04-01
# 4           2014-01         2014-Q1        2014.0       2014-08-17
# ...             ...             ...           ...              ...
# 49433       2013-01         2013-Q1        2013.0       2014-03-24
# 49434           NaN             NaN           NaN       2012-04-01
# 49435       2012-05         2012-Q2        2012.0       2011-11-01
# 49436           NaN             NaN           NaN       2011-11-21
# 49437       1999-01         1999-Q1        1999.0       2008-06-01
#
#       last_funding_at
# 0          2012-06-30
# 1          2010-09-23
# 2          2012-08-09
# 3          2011-04-01
# 4          2014-09-26
# ...               ...
# 49433      2014-03-24
# 49434      2012-04-01
# 49435      2014-09-10
# 49436      2011-11-21
# 49437      2013-04-04
#
# [49438 rows x 18 columns]

# %% [markdown]
# ## Summary Stats

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49438 entries, 0 to 49437
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   permalink            49438 non-null  object
#  1   name                 49437 non-null  object
#  2   homepage_url         45989 non-null  object
#  3   category_list        45477 non-null  object
#  4    market              45470 non-null  object
#  5    funding_total_usd   40978 non-null  float64
#  6   status               48124 non-null  object
#  7   country_code         44165 non-null  object
#  8   state_code           30161 non-null  object
#  9   region               44165 non-null  object
#  10  city                 43322 non-null  object
#  11  funding_rounds       49438 non-null  int64
#  12  founded_at           38554 non-null  object
#  13  founded_month        38482 non-null  object
#  14  founded_quarter      38482 non-null  object
#  15  founded_year         38482 non-null  float64
#  16  first_funding_at     49438 non-null  object
#  17  last_funding_at      49438 non-null  object
# dtypes: float64(2), int64(1), object(15)
# memory usage: 6.8+ MB

# %%
companies.describe()
# Out:
#         funding_total_usd   funding_rounds  founded_year
# count         4.097800e+04    49438.000000  38482.000000
# mean          1.591297e+07        1.696205   2007.359129
# std           1.685621e+08        1.294213      7.579203
# min           1.000000e+00        1.000000   1902.000000
# 25%           3.500000e+05        1.000000   2006.000000
# 50%           2.000000e+06        1.000000   2010.000000
# 75%           1.000000e+07        2.000000   2012.000000
# max           3.007950e+10       18.000000   2014.000000

# %%
companies.nunique()
# Out:
# permalink              49436
# name                   49350
# homepage_url           45850
# category_list          16675
#  market                  753
#  funding_total_usd     14629
# status                     3
# country_code             115
# state_code                61
# region                  1089
# city                    4188
# funding_rounds            17
# founded_at              3369
# founded_month            420
# founded_quarter          218
# founded_year             103
# first_funding_at        3914
# last_funding_at         3657
# dtype: int64

# %%
companies.corr()
# Out:
#                       funding_total_usd   funding_rounds  founded_year
#  funding_total_usd              1.000000        0.105506     -0.071897
# funding_rounds                  0.105506        1.000000     -0.058314
# founded_year                   -0.071897       -0.058314      1.000000

# %% [markdown]
# ## Analysis

# %%
column_names = ['permalink', 'name', 'homepage_url', 'category_list', ' market ', ' funding_total_usd ', 'status', 'country_code', 'state_code', 'region', 'city', 'funding_rounds', 'founded_at', 'founded_month', 'founded_quarter', 'founded_year', 'first_funding_at', 'last_funding_at']

for col in column_names:
  print('\n\n')
  print("==========================================================================")
  print(col.upper())
  print("VALUE COUNTS")
  print(companies[col].value_counts())
  print("\n")

  print("DUPLICATE COUNTS")
  print(companies.duplicated(subset=col, keep='first').sum())
  print("\n")

  print("NULL COUNTS AND PERCENTAGE")
  print(companies[col].isnull().sum())
  print(companies[col].isnull().sum()/(companies['permalink'].nunique())*100)
  print('\n')
  
  print("NULL ROWS")
  display(companies[companies[col].isnull()])
# Out:
# ==========================================================================
# PERMALINK
# VALUE COUNTS
# /organization/treasure-valley-urology-services    2
# /organization/prysm                               2
# /organization/waywire                             1
# /organization/polybona                            1
# /organization/pollfish                            1
#                                                  ..
# /organization/game-ventures                       1
# /organization/game9z                              1
# /organization/gameaccount-network                 1
# /organization/gameanalytics                       1
# /organization/x                                   1
# Name: permalink, Length: 49436, dtype: int64
#
#
# DUPLICATE COUNTS
# 2
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [permalink, name, homepage_url, category_list,  market ,  funding_total_usd , status, country_code, state_code, region, city, funding_rounds, founded_at, founded_month, founded_quarter, founded_year, first_funding_at, last_funding_at]
# Index: []
# ==========================================================================
# NAME
# VALUE COUNTS
# Roost                  4
# Spire                  4
# Cue                    3
# Compass                3
# Hubbub                 3
#                       ..
# Game Trust             1
# Game Ventures          1
# Game9z                 1
# GameAccount Network    1
# [x+1]                  1
# Name: name, Length: 49350, dtype: int64
#
#
# DUPLICATE COUNTS
# 87
#
#
# NULL COUNTS AND PERCENTAGE
# 1
# 0.0020228173800469294
#
#
# NULL ROWS
#                       permalink name           homepage_url category_list  \
# 28221  /organization/tell-it-in  NaN  http://tellitin10.com    |Startups|
#
#           market    funding_total_usd   status country_code state_code region  \
# 28221   Startups               25000.0  closed          NaN        NaN    NaN
#
#       city  funding_rounds  founded_at founded_month founded_quarter  \
# 28221  NaN               1  2011-10-01       2011-10         2011-Q4
#
#        founded_year first_funding_at last_funding_at
# 28221        2011.0       2012-03-01      2012-03-01
# ==========================================================================
# HOMEPAGE_URL
# VALUE COUNTS
# http://spaceport.io              2
# http://shelby.tv                 2
# http://www.kuwo.cn               2
# http://gui.de                    2
# http://primordialgenetics.com    2
#                                 ..
# http://www.gamecooks.net         1
# http://www.game-craft.com        1
# http://www.gamedigitalplc.com    1
# http://game-insight.com          1
# http://www.xplusone.com/         1
# Name: homepage_url, Length: 45850, dtype: int64
#
#
# DUPLICATE COUNTS
# 3587
#
#
# NULL COUNTS AND PERCENTAGE
# 3449
# 6.97669714378186
#
#
# NULL ROWS
#                             permalink                name homepage_url  \
# 4      /organization/r-ranch-and-mine  -R- Ranch and Mine          NaN
# 11              /organization/1-4-all             1-4 All          NaN
# 14     /organization/1-618-technology    1.618 Technology          NaN
# 29             /organization/10°north            10°North          NaN
# 42          /organization/121-rentals         121 Rentals          NaN
# ...                               ...                 ...          ...
# 49341      /organization/zperfectgift        zPerfectGift          NaN
# 49356            /organization/zuffle              Zuffle          NaN
# 49378         /organization/zumodrive           zumodrive          NaN
# 49390              /organization/zuse                Zuse          NaN
# 49402             /organization/zwamy               Zwamy          NaN
#
#                         category_list         market    funding_total_usd   \
# 4       |Tourism|Entertainment|Games|        Tourism               60000.0
# 11     |Entertainment|Games|Software|       Software                   NaN
# 14                      |Real Estate|    Real Estate                   NaN
# 29                          |Fashion|        Fashion                   NaN
# 42                      |Real Estate|    Real Estate                   NaN
# ...                               ...             ...                  ...
# 49341                  |Social Media|   Social Media               25000.0
# 49356                             NaN             NaN             132351.0
# 49378                             NaN             NaN                  NaN
# 49390                      |Software|       Software                   NaN
# 49402                             NaN             NaN             387794.0
#
#           status country_code state_code          region               city  \
# 4      operating          USA         TX          Dallas         Fort Worth
# 11     operating          USA         NC      NC - Other  Connellys Springs
# 14     operating          USA         FL         Orlando            Orlando
# 29     operating          CAN         ON         Toronto        Mississauga
# 42     operating          USA         TX      TX - Other           Amarillo
# ...          ...          ...        ...             ...                ...
# 49341  operating          USA         UT  Salt Lake City            Midvale
# 49356  operating          ITA        NaN     ITA - Other              Prato
# 49378  operating          NaN        NaN             NaN                NaN
# 49390  operating          USA         NY   New York City           New York
# 49402  operating          USA         CA     SF Bay Area    Los Altos Hills
#
#        funding_rounds  founded_at founded_month founded_quarter  founded_year  \
# 4                   2  2014-01-01       2014-01         2014-Q1        2014.0
# 11                  1         NaN           NaN             NaN           NaN
# 14                  1  2013-12-07       2013-12         2013-Q4        2013.0
# 29                  1  2014-08-12       2014-08         2014-Q3        2014.0
# 42                  1  2011-04-12       2011-04         2011-Q2        2011.0
# ...               ...         ...           ...             ...           ...
# 49341               1  2010-01-01       2010-01         2010-Q1        2010.0
# 49356               1         NaN           NaN             NaN           NaN
# 49378               1         NaN           NaN             NaN           NaN
# 49390               1         NaN           NaN             NaN           NaN
# 49402               1  2013-01-01       2013-01         2013-Q1        2013.0
#
#       first_funding_at last_funding_at
# 4           2014-08-17      2014-09-26
# 11          2013-04-21      2013-04-21
# 14          2014-01-22      2014-01-22
# 29          2014-08-12      2014-08-12
# 42          2014-09-03      2014-09-03
# ...                ...             ...
# 49341       2012-09-26      2012-09-26
# 49356       2013-07-26      2013-07-26
# 49378       2007-09-01      2007-09-01
# 49390       2013-05-01      2013-05-01
# 49402       2014-04-02      2014-04-02
#
# [3449 rows x 18 columns]
# ==========================================================================
# CATEGORY_LIST
# VALUE COUNTS
# |Software|                                                                                     3650
# |Biotechnology|                                                                                3597
# |E-Commerce|                                                                                   1263
# |Mobile|                                                                                       1211
# |Curated Web|                                                                                  1120
#                                                                                                ...
# |Fashion|Digital Media|Marketplaces|E-Commerce|                                                   1
# |Advertising|Web Development|App Marketing|Enterprises|Cloud Computing|Enterprise Software|       1
# |Web Design|Software|Web Tools|Web Development|Enterprise Software|                               1
# |3D|Web Tools|Entertainment|Curated Web|                                                          1
# |Web Development|Advertising|Wireless|Mobile|                                                     1
# Name: category_list, Length: 16675, dtype: int64
#
#
# DUPLICATE COUNTS
# 32762
#
#
# NULL COUNTS AND PERCENTAGE
# 3961
# 8.012379642365888
#
#
# NULL ROWS
#                                 permalink                  name  \
# 48                    /organization/12bis                 12Bis
# 61               /organization/16lab-inc-            16Lab Inc.
# 72                  /organization/1d4-pty               1d4 Pty
# 85                /organization/1rp-media             1RP Media
# 88     /organization/1st-choice-lawn-care  1st Choice Lawn Care
# ...                                   ...                   ...
# 49356                /organization/zuffle                Zuffle
# 49378             /organization/zumodrive             zumodrive
# 49389               /organization/zursh-2                 Zursh
# 49397                /organization/zuzher                Zuzher
# 49402                 /organization/zwamy                 Zwamy
#
#                           homepage_url category_list  market   \
# 48                    http://12bis.com           NaN      NaN
# 61                http://www.16lab.net           NaN      NaN
# 72     http://www.immortaloutdoors.com           NaN      NaN
# 85                                 NaN           NaN      NaN
# 88                                 NaN           NaN      NaN
# ...                                ...           ...      ...
# 49356                              NaN           NaN      NaN
# 49378                              NaN           NaN      NaN
# 49389            http://www.zursh.com/           NaN      NaN
# 49397           http://www.zuzher.com/           NaN      NaN
# 49402                              NaN           NaN      NaN
#
#         funding_total_usd      status country_code state_code       region  \
# 48                130636.0  operating          FRA        NaN        Paris
# 61                     NaN  operating          NaN        NaN          NaN
# 72                 40000.0  operating          NOR        NaN   Aust-Agder
# 85                     NaN  operating          USA         CA  Los Angeles
# 88                     NaN  operating          USA         LA   Shreveport
# ...                    ...        ...          ...        ...          ...
# 49356             132351.0  operating          ITA        NaN  ITA - Other
# 49378                  NaN  operating          NaN        NaN          NaN
# 49389              25000.0  operating          NaN        NaN          NaN
# 49397              15698.0  operating          NaN        NaN          NaN
# 49402             387794.0  operating          USA         CA  SF Bay Area
#
#                   city  funding_rounds  founded_at founded_month  \
# 48               Paris               1  2008-01-01       2008-01
# 61                 NaN               1  2013-04-24       2013-04
# 72                 NaN               1         NaN           NaN
# 85         Los Angeles               1  2011-01-01       2011-01
# 88        Bossier City               1  2012-08-01       2012-08
# ...                ...             ...         ...           ...
# 49356            Prato               1         NaN           NaN
# 49378              NaN               1         NaN           NaN
# 49389              NaN               1         NaN           NaN
# 49397              NaN               1  2012-05-01       2012-05
# 49402  Los Altos Hills               1  2013-01-01       2013-01
#
#       founded_quarter  founded_year first_funding_at last_funding_at
# 48            2008-Q1        2008.0       2012-03-15      2012-03-15
# 61            2013-Q2        2013.0       2014-11-26      2014-11-26
# 72                NaN           NaN       2012-04-11      2012-04-11
# 85            2011-Q1        2011.0       2012-06-29      2012-06-29
# 88            2012-Q3        2012.0       2012-07-22      2012-07-22
# ...               ...           ...              ...             ...
# 49356             NaN           NaN       2013-07-26      2013-07-26
# 49378             NaN           NaN       2007-09-01      2007-09-01
# 49389             NaN           NaN       2014-05-01      2014-05-01
# 49397         2012-Q2        2012.0       2012-08-01      2012-08-01
# 49402         2013-Q1        2013.0       2014-04-02      2014-04-02
#
# [3961 rows x 18 columns]
# ==========================================================================
#  MARKET
# VALUE COUNTS
#  Software                4620
#  Biotechnology           3688
#  Mobile                  1983
#  E-Commerce              1805
#  Curated Web             1655
#                          ...
#  Contact Centers            1
#  Swimming                   1
#  Retirement                 1
#  Musical Instruments        1
#  Rural Energy               1
# Name:  market , Length: 753, dtype: int64
#
#
# DUPLICATE COUNTS
# 48684
#
#
# NULL COUNTS AND PERCENTAGE
# 3968
# 8.026539364026215
#
#
# NULL ROWS
#                                 permalink                  name  \
# 48                    /organization/12bis                 12Bis
# 61               /organization/16lab-inc-            16Lab Inc.
# 72                  /organization/1d4-pty               1d4 Pty
# 85                /organization/1rp-media             1RP Media
# 88     /organization/1st-choice-lawn-care  1st Choice Lawn Care
# ...                                   ...                   ...
# 49356                /organization/zuffle                Zuffle
# 49378             /organization/zumodrive             zumodrive
# 49389               /organization/zursh-2                 Zursh
# 49397                /organization/zuzher                Zuzher
# 49402                 /organization/zwamy                 Zwamy
#
#                           homepage_url category_list  market   \
# 48                    http://12bis.com           NaN      NaN
# 61                http://www.16lab.net           NaN      NaN
# 72     http://www.immortaloutdoors.com           NaN      NaN
# 85                                 NaN           NaN      NaN
# 88                                 NaN           NaN      NaN
# ...                                ...           ...      ...
# 49356                              NaN           NaN      NaN
# 49378                              NaN           NaN      NaN
# 49389            http://www.zursh.com/           NaN      NaN
# 49397           http://www.zuzher.com/           NaN      NaN
# 49402                              NaN           NaN      NaN
#
#         funding_total_usd      status country_code state_code       region  \
# 48                130636.0  operating          FRA        NaN        Paris
# 61                     NaN  operating          NaN        NaN          NaN
# 72                 40000.0  operating          NOR        NaN   Aust-Agder
# 85                     NaN  operating          USA         CA  Los Angeles
# 88                     NaN  operating          USA         LA   Shreveport
# ...                    ...        ...          ...        ...          ...
# 49356             132351.0  operating          ITA        NaN  ITA - Other
# 49378                  NaN  operating          NaN        NaN          NaN
# 49389              25000.0  operating          NaN        NaN          NaN
# 49397              15698.0  operating          NaN        NaN          NaN
# 49402             387794.0  operating          USA         CA  SF Bay Area
#
#                   city  funding_rounds  founded_at founded_month  \
# 48               Paris               1  2008-01-01       2008-01
# 61                 NaN               1  2013-04-24       2013-04
# 72                 NaN               1         NaN           NaN
# 85         Los Angeles               1  2011-01-01       2011-01
# 88        Bossier City               1  2012-08-01       2012-08
# ...                ...             ...         ...           ...
# 49356            Prato               1         NaN           NaN
# 49378              NaN               1         NaN           NaN
# 49389              NaN               1         NaN           NaN
# 49397              NaN               1  2012-05-01       2012-05
# 49402  Los Altos Hills               1  2013-01-01       2013-01
#
#       founded_quarter  founded_year first_funding_at last_funding_at
# 48            2008-Q1        2008.0       2012-03-15      2012-03-15
# 61            2013-Q2        2013.0       2014-11-26      2014-11-26
# 72                NaN           NaN       2012-04-11      2012-04-11
# 85            2011-Q1        2011.0       2012-06-29      2012-06-29
# 88            2012-Q3        2012.0       2012-07-22      2012-07-22
# ...               ...           ...              ...             ...
# 49356             NaN           NaN       2013-07-26      2013-07-26
# 49378             NaN           NaN       2007-09-01      2007-09-01
# 49389             NaN           NaN       2014-05-01      2014-05-01
# 49397         2012-Q2        2012.0       2012-08-01      2012-08-01
# 49402         2013-Q1        2013.0       2014-04-02      2014-04-02
#
# [3968 rows x 18 columns]
# ==========================================================================
#  FUNDING_TOTAL_USD
# VALUE COUNTS
# 1000000.0     928
# 500000.0      765
# 100000.0      750
# 40000.0       680
# 2000000.0     626
#              ...
# 11253082.0      1
# 17926365.0      1
# 177404.0        1
# 252052.0        1
# 97398.0         1
# Name:  funding_total_usd , Length: 14629, dtype: int64
#
#
# DUPLICATE COUNTS
# 34808
#
#
# NULL COUNTS AND PERCENTAGE
# 8460
# 17.113035035197022
#
#
# NULL ROWS
#                              permalink                 name  \
# 8       /organization/004-technologies     004 Technologies
# 11               /organization/1-4-all              1-4 All
# 12         /organization/1-800-dentist        1-800-DENTIST
# 14      /organization/1-618-technology     1.618 Technology
# 19     /organization/1000jobboersen-de    1000jobboersen.de
# ...                                ...                  ...
# 49411               /organization/zygo  Zygo Communications
# 49418           /organization/zymergen             Zymergen
# 49421              /organization/zympi                Zympi
# 49422          /organization/zymr-inc-           Zymr, Inc.
# 49423              /organization/zyncd                Zyncd
#
#                                 homepage_url  \
# 8          http://004gmbh.de/en/004-interact
# 11                                       NaN
# 12                http://www.1800dentist.com
# 14                                       NaN
# 19              http://www.1000jobboersen.de
# ...                                      ...
# 49411  http://www.zygocommunications.com/who
# 49418                http://www.zymergen.com
# 49421                   http://www.zympi.com
# 49422                    http://www.zymr.com
# 49423                   http://www.zyncd.com
#
#                                            category_list  \
# 8                                             |Software|
# 11                        |Entertainment|Games|Software|
# 12                                 |Health and Wellness|
# 14                                         |Real Estate|
# 19                                         |Curated Web|
# ...                                                  ...
# 49411                                       |SMS|Mobile|
# 49418                                    |Biotechnology|
# 49421                    |Networking|Web Hosting|Mobile|
# 49422  |Open Source|Network Security|Networking|Virtu...
# 49423               |Knowledge Management|Crowdsourcing|
#
#                      market    funding_total_usd      status country_code  \
# 8                  Software                   NaN  operating          USA
# 11                 Software                   NaN  operating          USA
# 12      Health and Wellness                   NaN  operating          USA
# 14              Real Estate                   NaN  operating          USA
# 19              Curated Web                   NaN  operating          DEU
# ...                      ...                  ...        ...          ...
# 49411                Mobile                   NaN     closed          GBR
# 49418         Biotechnology                   NaN  operating          USA
# 49421           Web Hosting                   NaN  operating          NaN
# 49422               Testing                   NaN  operating          USA
# 49423         Crowdsourcing                   NaN  operating          GBR
#
#       state_code                 region               city  funding_rounds  \
# 8             IL  Springfield, Illinois          Champaign               1
# 11            NC             NC - Other  Connellys Springs               1
# 12            CA            Los Angeles        Los Angeles               1
# 14            FL                Orlando            Orlando               1
# 19           NaN                 Berlin             Berlin               1
# ...          ...                    ...                ...             ...
# 49411        NaN                 London             London               1
# 49418         CA            SF Bay Area      San Francisco               1
# 49421        NaN                    NaN                NaN               1
# 49422         CA            SF Bay Area        Santa Clara               1
# 49423        NaN                 London             London               1
#
#        founded_at founded_month founded_quarter  founded_year  \
# 8      2010-01-01       2010-01         2010-Q1        2010.0
# 11            NaN           NaN             NaN           NaN
# 12     1986-01-01       1986-01         1986-Q1        1986.0
# 14     2013-12-07       2013-12         2013-Q4        2013.0
# 19            NaN           NaN             NaN           NaN
# ...           ...           ...             ...           ...
# 49411  2005-06-21       2005-06         2005-Q2        2005.0
# 49418  2013-01-01       2013-01         2013-Q1        2013.0
# 49421  2010-09-03       2010-09         2010-Q3        2010.0
# 49422         NaN           NaN             NaN           NaN
# 49423  2014-01-01       2014-01         2014-Q1        2014.0
#
#       first_funding_at last_funding_at
# 8           2014-07-24      2014-07-24
# 11          2013-04-21      2013-04-21
# 12          2010-08-19      2010-08-19
# 14          2014-01-22      2014-01-22
# 19          2011-09-16      2011-09-16
# ...                ...             ...
# 49411       2007-11-19      2007-11-19
# 49418       2014-01-01      2014-01-01
# 49421       2011-11-22      2011-11-22
# 49422       2012-12-12      2012-12-12
# 49423       2014-02-01      2014-02-01
#
# [8460 rows x 18 columns]
# ==========================================================================
# STATUS
# VALUE COUNTS
# operating    41829
# acquired      3692
# closed        2603
# Name: status, dtype: int64
#
#
# DUPLICATE COUNTS
# 49434
#
#
# NULL COUNTS AND PERCENTAGE
# 1314
# 2.6579820373816654
#
#
# NULL ROWS
#                                     permalink                  name  \
# 5                  /organization/club-domains         .Club Domains
# 67                   /organization/1c-company            1C Company
# 89         /organization/1st-merchant-funding  1st Merchant Funding
# 121                       /organization/24h00                 24h00
# 238                       /organization/3nder                 3nder
# ...                                       ...                   ...
# 49175                   /organization/zingaya               Zingaya
# 49248  /organization/tyrosine-pharmaceuticals                Zocere
# 49288                 /organization/zoojoo-be             zoojoo.BE
# 49289                    /organization/zookal                Zookal
# 49412          /organization/zygo-corporation      Zygo Corporation
#
#                              homepage_url  \
# 5                        http://nic.club/
# 67                       http://1c.ru/eng
# 89     http://www.1stmerchantfunding.com/
# 121               http://www.boosket.com/
# 238               http://www.3nderapp.com
# ...                                   ...
# 49175              http://www.zingaya.com
# 49248                  http://zocere.com/
# 49288                http://www.zoojoo.be
# 49289               http://www.zookal.com
# 49412                 http://www.zygo.com
#
#                                            category_list  \
# 5                                             |Software|
# 67                          |Video Games|Games|Software|
# 89                                  |Financial Services|
# 121                                                  NaN
# 238    |iOS|Online Dating|Mobile|Location Based Servi...
# ...                                                  ...
# 49175  |Customer Service|E-Commerce|VoIP|Telecommunic...
# 49248                                    |Biotechnology|
# 49288                                         |Software|
# 49289                   |Education|Textbooks|E-Commerce|
# 49412                                    |Manufacturing|
#
#                     market    funding_total_usd  status country_code  \
# 5                 Software             7000000.0    NaN          USA
# 67                Software           200000000.0    NaN          RUS
# 89      Financial Services            10000000.0    NaN          USA
# 121                     NaN                  NaN    NaN          FRA
# 238           Social Media                   NaN    NaN          NaN
# ...                     ...                  ...    ...          ...
# 49175            Messaging             1150000.0    NaN          USA
# 49248        Biotechnology              100000.0    NaN          NaN
# 49288             Software                   NaN    NaN          IND
# 49289           E-Commerce             2060000.0    NaN          AUS
# 49412        Manufacturing             9000000.0    NaN          USA
#
#       state_code          region          city  funding_rounds  founded_at  \
# 5             FL  Ft. Lauderdale  Oakland Park               1  2011-10-10
# 67           NaN          Moscow        Moscow               1  1991-01-01
# 89            FL           Miami         Miami               1  2007-01-01
# 121          NaN           Paris         Paris               1  2006-01-01
# 238          NaN             NaN           NaN               1  2014-02-18
# ...          ...             ...           ...             ...         ...
# 49175         CA     SF Bay Area     Palo Alto               1  2010-06-01
# 49248        NaN             NaN           NaN               1  2012-01-01
# 49288        NaN       Bangalore     Bangalore               1  2012-01-01
# 49289        NaN          Sydney        Sydney               3  2011-03-01
# 49412         CT      CT - Other   Middlefield               1         NaN
#
#       founded_month founded_quarter  founded_year first_funding_at  \
# 5           2011-10         2011-Q4        2011.0       2013-05-31
# 67          1991-01         1991-Q1        1991.0       2011-10-03
# 89          2007-01         2007-Q1        2007.0       2014-05-07
# 121         2006-01         2006-Q1        2006.0       2006-08-01
# 238         2014-02         2014-Q1        2014.0       2014-05-09
# ...             ...             ...           ...              ...
# 49175       2010-06         2010-Q2        2010.0       2011-10-26
# 49248       2012-01         2012-Q1        2012.0       2013-09-25
# 49288       2012-01         2012-Q1        2012.0       2014-05-15
# 49289       2011-03         2011-Q1        2011.0       2011-12-01
# 49412           NaN             NaN           NaN       2011-10-24
#
#       last_funding_at
# 5          2013-05-31
# 67         2011-10-03
# 89         2014-05-07
# 121        2006-08-01
# 238        2014-05-09
# ...               ...
# 49175      2011-10-26
# 49248      2013-09-25
# 49288      2014-05-15
# 49289      2013-09-30
# 49412      2011-10-24
#
# [1314 rows x 18 columns]
# ==========================================================================
# COUNTRY_CODE
# VALUE COUNTS
# USA    28793
# GBR     2642
# CAN     1405
# CHN     1239
# DEU      968
#        ...
# ALB        1
# MOZ        1
# LIE        1
# BRN        1
# MAF        1
# Name: country_code, Length: 115, dtype: int64
#
#
# DUPLICATE COUNTS
# 49322
#
#
# NULL COUNTS AND PERCENTAGE
# 5273
# 10.66631604498746
#
#
# NULL ROWS
#                              permalink               name  \
# 7                /organization/0-6-com            0-6.com
# 18          /organization/1000-markets       1000 Markets
# 24              /organization/100du-tv           100du.tv
# 31                 /organization/10sec              10sec
# 36     /organization/115-network-disks  115 network disks
# ...                                ...                ...
# 49389            /organization/zursh-2              Zursh
# 49397             /organization/zuzher             Zuzher
# 49407          /organization/zwoor-com          zwoor.com
# 49421              /organization/zympi              Zympi
# 49436       /organization/a-list-games      [a]list games
#
#                      homepage_url  \
# 7              http://www.0-6.com
# 18     http://www.1000markets.com
# 24           http://www.100du.com
# 31                 http://10s.ec/
# 36            http://www.115.com/
# ...                           ...
# 49389       http://www.zursh.com/
# 49397      http://www.zuzher.com/
# 49407        http://www.zwoor.com
# 49421        http://www.zympi.com
# 49436   http://www.alistgames.com
#
#                                            category_list            market   \
# 7                                          |Curated Web|       Curated Web
# 18                         |Marketplaces|Art|E-Commerce|      Marketplaces
# 24                                         |Hospitality|       Hospitality
# 31          |Social Commerce|E-Commerce|Mobile Commerce|   Mobile Commerce
# 36                                           |Education|         Education
# ...                                                  ...                ...
# 49389                                                NaN                NaN
# 49397                                                NaN                NaN
# 49407  |Meeting Software|Polling|Surveys|Android|iPho...           Polling
# 49421                    |Networking|Web Hosting|Mobile|       Web Hosting
# 49436                                            |Games|             Games
#
#         funding_total_usd      status country_code state_code region city  \
# 7                2000000.0  operating          NaN        NaN    NaN  NaN
# 18                500000.0   acquired          NaN        NaN    NaN  NaN
# 24               3000000.0  operating          NaN        NaN    NaN  NaN
# 31               1600000.0  operating          NaN        NaN    NaN  NaN
# 36                     NaN  operating          NaN        NaN    NaN  NaN
# ...                    ...        ...          ...        ...    ...  ...
# 49389              25000.0  operating          NaN        NaN    NaN  NaN
# 49397              15698.0  operating          NaN        NaN    NaN  NaN
# 49407             100000.0  operating          NaN        NaN    NaN  NaN
# 49421                  NaN  operating          NaN        NaN    NaN  NaN
# 49436            9300000.0  operating          NaN        NaN    NaN  NaN
#
#        funding_rounds  founded_at founded_month founded_quarter  founded_year  \
# 7                   1  2007-01-01       2007-01         2007-Q1        2007.0
# 18                  1  2009-01-01       2009-01         2009-Q1        2009.0
# 24                  2         NaN           NaN             NaN           NaN
# 31                  2  2013-07-08       2013-07         2013-Q3        2013.0
# 36                  1         NaN           NaN             NaN           NaN
# ...               ...         ...           ...             ...           ...
# 49389               1         NaN           NaN             NaN           NaN
# 49397               1  2012-05-01       2012-05         2012-Q2        2012.0
# 49407               1  2010-01-01       2010-01         2010-Q1        2010.0
# 49421               1  2010-09-03       2010-09         2010-Q3        2010.0
# 49436               1         NaN           NaN             NaN           NaN
#
#       first_funding_at last_funding_at
# 7           2008-03-19      2008-03-19
# 18          2009-05-15      2009-05-15
# 24          2008-01-07      2010-08-13
# 31          2013-10-31      2014-05-08
# 36          2011-11-01      2011-11-01
# ...                ...             ...
# 49389       2014-05-01      2014-05-01
# 49397       2012-08-01      2012-08-01
# 49407       2011-01-01      2011-01-01
# 49421       2011-11-22      2011-11-22
# 49436       2011-11-21      2011-11-21
#
# [5273 rows x 18 columns]
# ==========================================================================
# STATE_CODE
# VALUE COUNTS
# CA    9917
# NY    2914
# MA    1969
# TX    1466
# WA     974
#       ...
# MB      13
# AK      12
# NB       8
# SK       4
# PE       2
# Name: state_code, Length: 61, dtype: int64
#
#
# DUPLICATE COUNTS
# 49376
#
#
# NULL COUNTS AND PERCENTAGE
# 19277
# 38.993850635164655
#
#
# NULL ROWS
#                                                permalink  \
# 2                          /organization/rock-your-paper
# 3                         /organization/in-touch-network
# 6                             /organization/fox-networks
# 7                                  /organization/0-6-com
# 9                       /organization/01games-technology
# ...                                                  ...
# 49432                           /organization/zytoprotec
# 49433                                /organization/zzish
# 49434  /organization/zznode-science-and-technology-co...
# 49435                          /organization/zzzzapp-com
# 49436                         /organization/a-list-games
#
#                                 name                   homepage_url  \
# 2                  'Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 6                      .Fox Networks          http://www.dotfox.com
# 7                            0-6.com             http://www.0-6.com
# 9                 01Games Technology         http://www.01games.hk/
# ...                              ...                            ...
# 49432                     Zytoprotec      http://www.zytoprotec.com
# 49433                          Zzish           http://www.zzish.com
# 49434  ZZNode Science and Technology          http://www.zznode.com
# 49435          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 49436                  [a]list games      http://www.alistgames.com
#
#                                            category_list  \
# 2                                 |Publishing|Education|
# 3      |Electronics|Guides|Coffee|Restaurants|Music|i...
# 6                                          |Advertising|
# 7                                          |Curated Web|
# 9                                                |Games|
# ...                                                  ...
# 49432                                    |Biotechnology|
# 49433  |Analytics|Gamification|Developer APIs|iOS|And...
# 49434                              |Enterprise Software|
# 49435      |Web Development|Advertising|Wireless|Mobile|
# 49436                                            |Games|
#
#                      market    funding_total_usd      status country_code  \
# 2                Publishing               40000.0  operating          EST
# 3               Electronics             1500000.0  operating          GBR
# 6               Advertising             4912393.0     closed          ARG
# 7               Curated Web             2000000.0  operating          NaN
# 9                     Games               41250.0  operating          HKG
# ...                      ...                  ...        ...          ...
# 49432         Biotechnology             2686600.0  operating          AUT
# 49433             Education              320000.0  operating          GBR
# 49434   Enterprise Software             1587301.0  operating          CHN
# 49435       Web Development               97398.0  operating          HRV
# 49436                 Games             9300000.0  operating          NaN
#
#       state_code        region                city  funding_rounds  \
# 2            NaN       Tallinn             Tallinn               1
# 3            NaN        London              London               1
# 6            NaN  Buenos Aires        Buenos Aires               1
# 7            NaN           NaN                 NaN               1
# 9            NaN     Hong Kong           Hong Kong               1
# ...          ...           ...                 ...             ...
# 49432        NaN        Vienna  Gerasdorf Bei Wien               1
# 49433        NaN        London              London               1
# 49434        NaN       Beijing             Beijing               1
# 49435        NaN         Split               Split               5
# 49436        NaN           NaN                 NaN               1
#
#        founded_at founded_month founded_quarter  founded_year  \
# 2      2012-10-26       2012-10         2012-Q4        2012.0
# 3      2011-04-01       2011-04         2011-Q2        2011.0
# 6             NaN           NaN             NaN           NaN
# 7      2007-01-01       2007-01         2007-Q1        2007.0
# 9             NaN           NaN             NaN           NaN
# ...           ...           ...             ...           ...
# 49432  2007-01-01       2007-01         2007-Q1        2007.0
# 49433  2013-01-28       2013-01         2013-Q1        2013.0
# 49434         NaN           NaN             NaN           NaN
# 49435  2012-05-13       2012-05         2012-Q2        2012.0
# 49436         NaN           NaN             NaN           NaN
#
#       first_funding_at last_funding_at
# 2           2012-08-09      2012-08-09
# 3           2011-04-01      2011-04-01
# 6           2007-01-16      2007-01-16
# 7           2008-03-19      2008-03-19
# 9           2014-07-01      2014-07-01
# ...                ...             ...
# 49432       2013-01-29      2013-01-29
# 49433       2014-03-24      2014-03-24
# 49434       2012-04-01      2012-04-01
# 49435       2011-11-01      2014-09-10
# 49436       2011-11-21      2011-11-21
#
# [19277 rows x 18 columns]
# ==========================================================================
# REGION
# VALUE COUNTS
# SF Bay Area        6804
# New York City      2577
# Boston             1837
# London             1588
# Los Angeles        1389
#                    ...
# Palma Del Río         1
# Harbin                1
# Teddington            1
# Borehamwood           1
# Buckinghamshire       1
# Name: region, Length: 1089, dtype: int64
#
#
# DUPLICATE COUNTS
# 48348
#
#
# NULL COUNTS AND PERCENTAGE
# 5273
# 10.66631604498746
#
#
# NULL ROWS
#                              permalink               name  \
# 7                /organization/0-6-com            0-6.com
# 18          /organization/1000-markets       1000 Markets
# 24              /organization/100du-tv           100du.tv
# 31                 /organization/10sec              10sec
# 36     /organization/115-network-disks  115 network disks
# ...                                ...                ...
# 49389            /organization/zursh-2              Zursh
# 49397             /organization/zuzher             Zuzher
# 49407          /organization/zwoor-com          zwoor.com
# 49421              /organization/zympi              Zympi
# 49436       /organization/a-list-games      [a]list games
#
#                      homepage_url  \
# 7              http://www.0-6.com
# 18     http://www.1000markets.com
# 24           http://www.100du.com
# 31                 http://10s.ec/
# 36            http://www.115.com/
# ...                           ...
# 49389       http://www.zursh.com/
# 49397      http://www.zuzher.com/
# 49407        http://www.zwoor.com
# 49421        http://www.zympi.com
# 49436   http://www.alistgames.com
#
#                                            category_list            market   \
# 7                                          |Curated Web|       Curated Web
# 18                         |Marketplaces|Art|E-Commerce|      Marketplaces
# 24                                         |Hospitality|       Hospitality
# 31          |Social Commerce|E-Commerce|Mobile Commerce|   Mobile Commerce
# 36                                           |Education|         Education
# ...                                                  ...                ...
# 49389                                                NaN                NaN
# 49397                                                NaN                NaN
# 49407  |Meeting Software|Polling|Surveys|Android|iPho...           Polling
# 49421                    |Networking|Web Hosting|Mobile|       Web Hosting
# 49436                                            |Games|             Games
#
#         funding_total_usd      status country_code state_code region city  \
# 7                2000000.0  operating          NaN        NaN    NaN  NaN
# 18                500000.0   acquired          NaN        NaN    NaN  NaN
# 24               3000000.0  operating          NaN        NaN    NaN  NaN
# 31               1600000.0  operating          NaN        NaN    NaN  NaN
# 36                     NaN  operating          NaN        NaN    NaN  NaN
# ...                    ...        ...          ...        ...    ...  ...
# 49389              25000.0  operating          NaN        NaN    NaN  NaN
# 49397              15698.0  operating          NaN        NaN    NaN  NaN
# 49407             100000.0  operating          NaN        NaN    NaN  NaN
# 49421                  NaN  operating          NaN        NaN    NaN  NaN
# 49436            9300000.0  operating          NaN        NaN    NaN  NaN
#
#        funding_rounds  founded_at founded_month founded_quarter  founded_year  \
# 7                   1  2007-01-01       2007-01         2007-Q1        2007.0
# 18                  1  2009-01-01       2009-01         2009-Q1        2009.0
# 24                  2         NaN           NaN             NaN           NaN
# 31                  2  2013-07-08       2013-07         2013-Q3        2013.0
# 36                  1         NaN           NaN             NaN           NaN
# ...               ...         ...           ...             ...           ...
# 49389               1         NaN           NaN             NaN           NaN
# 49397               1  2012-05-01       2012-05         2012-Q2        2012.0
# 49407               1  2010-01-01       2010-01         2010-Q1        2010.0
# 49421               1  2010-09-03       2010-09         2010-Q3        2010.0
# 49436               1         NaN           NaN             NaN           NaN
#
#       first_funding_at last_funding_at
# 7           2008-03-19      2008-03-19
# 18          2009-05-15      2009-05-15
# 24          2008-01-07      2010-08-13
# 31          2013-10-31      2014-05-08
# 36          2011-11-01      2011-11-01
# ...                ...             ...
# 49389       2014-05-01      2014-05-01
# 49397       2012-08-01      2012-08-01
# 49407       2011-01-01      2011-01-01
# 49421       2011-11-22      2011-11-22
# 49436       2011-11-21      2011-11-21
#
# [5273 rows x 18 columns]
# ==========================================================================
# CITY
# VALUE COUNTS
# San Francisco            2615
# New York                 2334
# London                   1257
# Palo Alto                 597
# Austin                    583
#                          ...
# Richmond Upon Thames        1
# Kunming                     1
# Browns Mills                1
# Paducah                     1
# Damansara New Village       1
# Name: city, Length: 4188, dtype: int64
#
#
# DUPLICATE COUNTS
# 45249
#
#
# NULL COUNTS AND PERCENTAGE
# 6116
# 12.37155109636702
#
#
# NULL ROWS
#                              permalink               name  \
# 7                /organization/0-6-com            0-6.com
# 18          /organization/1000-markets       1000 Markets
# 24              /organization/100du-tv           100du.tv
# 31                 /organization/10sec              10sec
# 36     /organization/115-network-disks  115 network disks
# ...                                ...                ...
# 49389            /organization/zursh-2              Zursh
# 49397             /organization/zuzher             Zuzher
# 49407          /organization/zwoor-com          zwoor.com
# 49421              /organization/zympi              Zympi
# 49436       /organization/a-list-games      [a]list games
#
#                      homepage_url  \
# 7              http://www.0-6.com
# 18     http://www.1000markets.com
# 24           http://www.100du.com
# 31                 http://10s.ec/
# 36            http://www.115.com/
# ...                           ...
# 49389       http://www.zursh.com/
# 49397      http://www.zuzher.com/
# 49407        http://www.zwoor.com
# 49421        http://www.zympi.com
# 49436   http://www.alistgames.com
#
#                                            category_list            market   \
# 7                                          |Curated Web|       Curated Web
# 18                         |Marketplaces|Art|E-Commerce|      Marketplaces
# 24                                         |Hospitality|       Hospitality
# 31          |Social Commerce|E-Commerce|Mobile Commerce|   Mobile Commerce
# 36                                           |Education|         Education
# ...                                                  ...                ...
# 49389                                                NaN                NaN
# 49397                                                NaN                NaN
# 49407  |Meeting Software|Polling|Surveys|Android|iPho...           Polling
# 49421                    |Networking|Web Hosting|Mobile|       Web Hosting
# 49436                                            |Games|             Games
#
#         funding_total_usd      status country_code state_code region city  \
# 7                2000000.0  operating          NaN        NaN    NaN  NaN
# 18                500000.0   acquired          NaN        NaN    NaN  NaN
# 24               3000000.0  operating          NaN        NaN    NaN  NaN
# 31               1600000.0  operating          NaN        NaN    NaN  NaN
# 36                     NaN  operating          NaN        NaN    NaN  NaN
# ...                    ...        ...          ...        ...    ...  ...
# 49389              25000.0  operating          NaN        NaN    NaN  NaN
# 49397              15698.0  operating          NaN        NaN    NaN  NaN
# 49407             100000.0  operating          NaN        NaN    NaN  NaN
# 49421                  NaN  operating          NaN        NaN    NaN  NaN
# 49436            9300000.0  operating          NaN        NaN    NaN  NaN
#
#        funding_rounds  founded_at founded_month founded_quarter  founded_year  \
# 7                   1  2007-01-01       2007-01         2007-Q1        2007.0
# 18                  1  2009-01-01       2009-01         2009-Q1        2009.0
# 24                  2         NaN           NaN             NaN           NaN
# ...
# 49436                                            |Games|
#
#                      market    funding_total_usd      status country_code  \
# 1                     Games             4000000.0  operating          USA
# 6               Advertising             4912393.0     closed          ARG
# 9                     Games               41250.0  operating          HKG
# 11                 Software                   NaN  operating          USA
# 19              Curated Web                   NaN  operating          DEU
# ...                      ...                  ...        ...          ...
# 49412         Manufacturing             9000000.0        NaN          USA
# 49422               Testing                   NaN  operating          USA
# 49431            E-Commerce             1510500.0  operating          USA
# 49434   Enterprise Software             1587301.0  operating          CHN
# 49436                 Games             9300000.0  operating          NaN
#
#       state_code        region               city  funding_rounds founded_at  \
# 1             CA   Los Angeles        Los Angeles               2        NaN
# 6            NaN  Buenos Aires       Buenos Aires               1        NaN
# 9            NaN     Hong Kong          Hong Kong               1        NaN
# 11            NC    NC - Other  Connellys Springs               1        NaN
# 19           NaN        Berlin             Berlin               1        NaN
# ...          ...           ...                ...             ...        ...
# 49412         CT    CT - Other        Middlefield               1        NaN
# 49422         CA   SF Bay Area        Santa Clara               1        NaN
# 49431         MA        Boston          Cambridge               4        NaN
# 49434        NaN       Beijing            Beijing               1        NaN
# 49436        NaN           NaN                NaN               1        NaN
#
#       founded_month founded_quarter  founded_year first_funding_at  \
# 1               NaN             NaN           NaN       2010-06-04
# 6               NaN             NaN           NaN       2007-01-16
# 9               NaN             NaN           NaN       2014-07-01
# 11              NaN             NaN           NaN       2013-04-21
# 19              NaN             NaN           NaN       2011-09-16
# ...             ...             ...           ...              ...
# 49412           NaN             NaN           NaN       2011-10-24
# 49422           NaN             NaN           NaN       2012-12-12
# 49431           NaN             NaN           NaN       2010-10-21
# 49434           NaN             NaN           NaN       2012-04-01
# 49436           NaN             NaN           NaN       2011-11-21
#
#       last_funding_at
# 1          2010-09-23
# 6          2007-01-16
# 9          2014-07-01
# 11         2013-04-21
# 19         2011-09-16
# ...               ...
# 49412      2011-10-24
# 49422      2012-12-12
# 49431      2012-10-18
# 49434      2012-04-01
# 49436      2011-11-21
#
# [10956 rows x 18 columns]
# ==========================================================================
# FOUNDED_QUARTER
# VALUE COUNTS
# 2012-Q1    2904
# 2011-Q1    2768
# 2010-Q1    2259
# 2013-Q1    2206
# 2009-Q1    1852
#            ...
# 1991-Q3       1
# 1986-Q4       1
# 1960-Q2       1
# 1973-Q4       1
# 1907-Q1       1
# Name: founded_quarter, Length: 218, dtype: int64
#
#
# DUPLICATE COUNTS
# 49219
#
#
# NULL COUNTS AND PERCENTAGE
# 10956
# 22.161987215794156
#
#
# NULL ROWS
#                                                permalink  \
# 1                        /organization/tv-communications
# 6                             /organization/fox-networks
# 9                       /organization/01games-technology
# 11                                 /organization/1-4-all
# 19                       /organization/1000jobboersen-de
# ...                                                  ...
# 49412                     /organization/zygo-corporation
# 49422                            /organization/zymr-inc-
# 49431                                /organization/zyrra
# 49434  /organization/zznode-science-and-technology-co...
# 49436                         /organization/a-list-games
#
#                                 name                  homepage_url  \
# 1                 &TV Communications         http://enjoyandtv.com
# 6                      .Fox Networks         http://www.dotfox.com
# 9                 01Games Technology        http://www.01games.hk/
# 11                           1-4 All                           NaN
# 19                 1000jobboersen.de  http://www.1000jobboersen.de
# ...                              ...                           ...
# 49412               Zygo Corporation           http://www.zygo.com
# 49422                     Zymr, Inc.           http://www.zymr.com
# 49431                          Zyrra          http://www.zyrra.com
# 49434  ZZNode Science and Technology         http://www.zznode.com
# 49436                  [a]list games     http://www.alistgames.com
#
#                                            category_list  \
# 1                                                |Games|
# 6                                          |Advertising|
# 9                                                |Games|
# 11                        |Entertainment|Games|Software|
# 19                                         |Curated Web|
# ...                                                  ...
# 49412                                    |Manufacturing|
# 49422  |Open Source|Network Security|Networking|Virtu...
# 49431                                       |E-Commerce|
# 49434                              |Enterprise Software|
# 49436                                            |Games|
#
#                      market    funding_total_usd      status country_code  \
# 1                     Games             4000000.0  operating          USA
# 6               Advertising             4912393.0     closed          ARG
# 9                     Games               41250.0  operating          HKG
# 11                 Software                   NaN  operating          USA
# 19              Curated Web                   NaN  operating          DEU
# ...                      ...                  ...        ...          ...
# 49412         Manufacturing             9000000.0        NaN          USA
# 49422               Testing                   NaN  operating          USA
# 49431            E-Commerce             1510500.0  operating          USA
# 49434   Enterprise Software             1587301.0  operating          CHN
# 49436                 Games             9300000.0  operating          NaN
#
#       state_code        region               city  funding_rounds founded_at  \
# 1             CA   Los Angeles        Los Angeles               2        NaN
# 6            NaN  Buenos Aires       Buenos Aires               1        NaN
# 9            NaN     Hong Kong          Hong Kong               1        NaN
# 11            NC    NC - Other  Connellys Springs               1        NaN
# 19           NaN        Berlin             Berlin               1        NaN
# ...          ...           ...                ...             ...        ...
# 49412         CT    CT - Other        Middlefield               1        NaN
# 49422         CA   SF Bay Area        Santa Clara               1        NaN
# 49431         MA        Boston          Cambridge               4        NaN
# 49434        NaN       Beijing            Beijing               1        NaN
# 49436        NaN           NaN                NaN               1        NaN
#
#       founded_month founded_quarter  founded_year first_funding_at  \
# 1               NaN             NaN           NaN       2010-06-04
# 6               NaN             NaN           NaN       2007-01-16
# 9               NaN             NaN           NaN       2014-07-01
# 11              NaN             NaN           NaN       2013-04-21
# 19              NaN             NaN           NaN       2011-09-16
# ...             ...             ...           ...              ...
# 49412           NaN             NaN           NaN       2011-10-24
# 49422           NaN             NaN           NaN       2012-12-12
# 49431           NaN             NaN           NaN       2010-10-21
# 49434           NaN             NaN           NaN       2012-04-01
# 49436           NaN             NaN           NaN       2011-11-21
#
#       last_funding_at
# 1          2010-09-23
# 6          2007-01-16
# 9          2014-07-01
# 11         2013-04-21
# 19         2011-09-16
# ...               ...
# 49412      2011-10-24
# 49422      2012-12-12
# 49431      2012-10-18
# 49434      2012-04-01
# 49436      2011-11-21
#
# [10956 rows x 18 columns]
# ==========================================================================
# FOUNDED_YEAR
# VALUE COUNTS
# 2012.0    5211
# 2011.0    4905
# 2013.0    4044
# 2010.0    3773
# 2009.0    2979
#           ...
# 1943.0       1
# 1946.0       1
# 1918.0       1
# 1944.0       1
# 1907.0       1
# Name: founded_year, Length: 103, dtype: int64
#
#
# DUPLICATE COUNTS
# 49334
#
#
# NULL COUNTS AND PERCENTAGE
# 10956
# 22.161987215794156
#
#
# NULL ROWS
#                                                permalink  \
# 1                        /organization/tv-communications
# 6                             /organization/fox-networks
# 9                       /organization/01games-technology
# 11                                 /organization/1-4-all
# 19                       /organization/1000jobboersen-de
# ...                                                  ...
# 49412                     /organization/zygo-corporation
# 49422                            /organization/zymr-inc-
# 49431                                /organization/zyrra
# 49434  /organization/zznode-science-and-technology-co...
# 49436                         /organization/a-list-games
#
#                                 name                  homepage_url  \
# 1                 &TV Communications         http://enjoyandtv.com
# 6                      .Fox Networks         http://www.dotfox.com
# 9                 01Games Technology        http://www.01games.hk/
# 11                           1-4 All                           NaN
# 19                 1000jobboersen.de  http://www.1000jobboersen.de
# ...                              ...                           ...
# 49412               Zygo Corporation           http://www.zygo.com
# 49422                     Zymr, Inc.           http://www.zymr.com
# 49431                          Zyrra          http://www.zyrra.com
# 49434  ZZNode Science and Technology         http://www.zznode.com
# 49436                  [a]list games     http://www.alistgames.com
#
#                                            category_list  \
# 1                                                |Games|
# 6                                          |Advertising|
# 9                                                |Games|
# 11                        |Entertainment|Games|Software|
# 19                                         |Curated Web|
# ...                                                  ...
# 49412                                    |Manufacturing|
# 49422  |Open Source|Network Security|Networking|Virtu...
# 49431                                       |E-Commerce|
# 49434                              |Enterprise Software|
# 49436                                            |Games|
#
#                      market    funding_total_usd      status country_code  \
# 1                     Games             4000000.0  operating          USA
# 6               Advertising             4912393.0     closed          ARG
# 9                     Games               41250.0  operating          HKG
# 11                 Software                   NaN  operating          USA
# 19              Curated Web                   NaN  operating          DEU
# ...                      ...                  ...        ...          ...
# 49412         Manufacturing             9000000.0        NaN          USA
# 49422               Testing                   NaN  operating          USA
# 49431            E-Commerce             1510500.0  operating          USA
# 49434   Enterprise Software             1587301.0  operating          CHN
# 49436                 Games             9300000.0  operating          NaN
#
#       state_code        region               city  funding_rounds founded_at  \
# 1             CA   Los Angeles        Los Angeles               2        NaN
# 6            NaN  Buenos Aires       Buenos Aires               1        NaN
# 9            NaN     Hong Kong          Hong Kong               1        NaN
# 11            NC    NC - Other  Connellys Springs               1        NaN
# 19           NaN        Berlin             Berlin               1        NaN
# ...          ...           ...                ...             ...        ...
# 49412         CT    CT - Other        Middlefield               1        NaN
# 49422         CA   SF Bay Area        Santa Clara               1        NaN
# 49431         MA        Boston          Cambridge               4        NaN
# 49434        NaN       Beijing            Beijing               1        NaN
# 49436        NaN           NaN                NaN               1        NaN
#
#       founded_month founded_quarter  founded_year first_funding_at  \
# 1               NaN             NaN           NaN       2010-06-04
# 6               NaN             NaN           NaN       2007-01-16
# 9               NaN             NaN           NaN       2014-07-01
# 11              NaN             NaN           NaN       2013-04-21
# 19              NaN             NaN           NaN       2011-09-16
# ...             ...             ...           ...              ...
# 49412           NaN             NaN           NaN       2011-10-24
# 49422           NaN             NaN           NaN       2012-12-12
# 49431           NaN             NaN           NaN       2010-10-21
# 49434           NaN             NaN           NaN       2012-04-01
# 49436           NaN             NaN           NaN       2011-11-21
#
#       last_funding_at
# 1          2010-09-23
# 6          2007-01-16
# 9          2014-07-01
# 11         2013-04-21
# 19         2011-09-16
# ...               ...
# 49412      2011-10-24
# 49422      2012-12-12
# 49431      2012-10-18
# 49434      2012-04-01
# 49436      2011-11-21
#
# [10956 rows x 18 columns]
# ==========================================================================
# FIRST_FUNDING_AT
# VALUE COUNTS
# 2012-01-01    468
# 2013-01-01    463
# 2008-01-01    422
# 2011-01-01    392
# 2007-01-01    342
#              ...
# 2006-12-30      1
# 2008-07-16      1
# 0019-11-20      1
# 2006-04-09      1
# 2004-10-12      1
# Name: first_funding_at, Length: 3914, dtype: int64
#
#
# DUPLICATE COUNTS
# 45524
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [permalink, name, homepage_url, category_list,  market ,  funding_total_usd , status, country_code, state_code, region, city, funding_rounds, founded_at, founded_month, founded_quarter, founded_year, first_funding_at, last_funding_at]
# Index: []
# ==========================================================================
# LAST_FUNDING_AT
# VALUE COUNTS
# 2013-01-01    387
# 2014-01-01    364
# 2012-01-01    348
# 2008-01-01    302
# 2011-01-01    272
#              ...
# 2005-09-03      1
# 2009-05-24      1
# 2010-10-02      1
# 1998-06-30      1
# 2008-07-13      1
# Name: last_funding_at, Length: 3657, dtype: int64
#
#
# DUPLICATE COUNTS
# 45781
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [permalink, name, homepage_url, category_list,  market ,  funding_total_usd , status, country_code, state_code, region, city, funding_rounds, founded_at, founded_month, founded_quarter, founded_year, first_funding_at, last_funding_at]
# Index: []

# %% [markdown]
# # Rounds Analysis and Preprocessing

# %%
rounds = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CIS 550/rounds.csv')
rounds[' raised_amount_usd '] = rounds[' raised_amount_usd '].apply(lambda x: set_to_floats(x))
rounds = rounds.drop(columns= 'Unnamed: 16')
rounds
# Out:
#                      company_permalink        company_name  \
# 0                /organization/waywire            #waywire
# 1      /organization/tv-communications  &TV Communications
# 2      /organization/tv-communications  &TV Communications
# 3        /organization/rock-your-paper   'Rock' Your Paper
# 4       /organization/in-touch-network   (In)Touch Network
# ...                                ...                 ...
# 83865       /organization/a-list-games       [a]list games
# 83866                  /organization/x               [x+1]
# 83867                  /organization/x               [x+1]
# 83868                  /organization/x               [x+1]
# 83869                  /organization/x               [x+1]
#
#                                    company_category_list       company_market  \
# 0             |Entertainment|Politics|Social Media|News|                 News
# 1                                                |Games|                Games
# 2                                                |Games|                Games
# 3                                 |Publishing|Education|           Publishing
# 4      |Electronics|Guides|Coffee|Restaurants|Music|i...          Electronics
# ...                                                  ...                  ...
# 83865                                            |Games|                Games
# 83866                              |Enterprise Software|  Enterprise Software
# 83867                              |Enterprise Software|  Enterprise Software
# 83868                              |Enterprise Software|  Enterprise Software
# 83869                              |Enterprise Software|  Enterprise Software
#
#       company_country_code company_state_code company_region company_city  \
# 0                      USA                 NY  New York City     New York
# 1                      USA                 CA    Los Angeles  Los Angeles
# 2                      USA                 CA    Los Angeles  Los Angeles
# 3                      EST                NaN        Tallinn      Tallinn
# 4                      GBR                NaN         London       London
# ...                    ...                ...            ...          ...
# 83865                  NaN                NaN            NaN          NaN
# 83866                  USA                 NY  New York City     New York
# 83867                  USA                 NY  New York City     New York
# 83868                  USA                 NY  New York City     New York
# 83869                  USA                 NY  New York City     New York
#
#                                funding_round_permalink funding_round_type  \
# 0      /funding-round/cc409188fa2b63482bd9008f682c2efa               seed
# 1      /funding-round/59a3669a64e39360c2b939300bcda162            venture
# 2      /funding-round/86d22afc65107b6941e6c43c671ecbb8            venture
# 3      /funding-round/f06b420775f7cb6c1541a9db526534bb               seed
# 4      /funding-round/33c3f135f05d7b734b8d7b7c8ae82647               seed
# ...                                                ...                ...
# 83865  /funding-round/57d5459df4b227527e2edb2c1f183132               seed
# 83866  /funding-round/9e17c1f6579169daac605d43926e02fb     debt_financing
# 83867  /funding-round/ba12fd8e3d341db1c81b16282018ff7e            venture
# 83868  /funding-round/deb408bbd9f539af78ea69fb532ffa75            venture
# 83869  /funding-round/5c5ebcc9d85c2a5f810e319c249a36e7            venture
#
#       funding_round_code   funded_at funded_month  funded_quarter   \
# 0                    NaN  2012-06-30      2012-06         2012-Q2
# 1                    NaN  2010-09-23      2010-09         2010-Q3
# 2                    NaN  2010-06-04      2010-06         2010-Q2
# 3                    NaN  2012-08-09      2012-08         2012-Q3
# 4                    NaN  2011-04-01      2011-04         2011-Q2
# ...                  ...         ...          ...              ...
# 83865                NaN  2011-11-21      2011-11         2011-Q4
# 83866                NaN  2013-04-04      2013-04         2013-Q2
# 83867                  A  2008-06-01      2008-06         2008-Q2
# 83868                  B  2011-01-03      2011-01         2011-Q1
# 83869                NaN  2009-08-17      2009-08         2009-Q3
#
#        funded_year   raised_amount_usd
# 0           2012.0            1750000.0
# 1           2010.0            3000000.0
# 2           2010.0            1000000.0
# 3           2012.0              40000.0
# 4           2011.0            1500000.0
# ...            ...                  ...
# 83865       2011.0            9300000.0
# 83866       2013.0           17000000.0
# 83867       2008.0           16000000.0
# 83868       2011.0           10000000.0
# 83869       2009.0            2000000.0
#
# [83870 rows x 16 columns]

# %% [markdown]
# ## Summary Stats

# %%
rounds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83870 entries, 0 to 83869
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   company_permalink        83870 non-null  object
#  1   company_name             83869 non-null  object
#  2   company_category_list    79424 non-null  object
#  3   company_market           79417 non-null  object
#  4   company_country_code     77304 non-null  object
#  5   company_state_code       56497 non-null  object
#  6   company_region           77304 non-null  object
#  7   company_city             76223 non-null  object
#  8   funding_round_permalink  83870 non-null  object
#  9   funding_round_type       83870 non-null  object
#  10  funding_round_code       22870 non-null  object
#  11  funded_at                83870 non-null  object
#  12  funded_month             83860 non-null  object
#  13   funded_quarter          83860 non-null  object
#  14  funded_year              83860 non-null  float64
#  15   raised_amount_usd       70915 non-null  float64
# dtypes: float64(2), object(14)
# memory usage: 10.2+ MB

# %%
rounds.describe()
# Out:
#         funded_year   raised_amount_usd
# count  83860.000000         7.091500e+04
# mean    2011.018173         9.176873e+06
# std        2.889240         9.665408e+07
# min     1921.000000         1.000000e+00
# 25%     2010.000000         3.611505e+05
# 50%     2012.000000         1.700000e+06
# 75%     2013.000000         6.574399e+06
# max     2015.000000         2.127194e+10

# %%
rounds.nunique()
# Out:
# company_permalink          49427
# company_name               49344
# company_category_list      16666
# company_market               753
# company_country_code         115
# company_state_code            61
# company_region              1089
# company_city                4188
# funding_round_permalink    83870
# funding_round_type            13
# funding_round_code             8
# funded_at                   4159
# funded_month                 308
#  funded_quarter              130
# funded_year                   39
#  raised_amount_usd         16582
# dtype: int64

# %% [markdown]
# ## Analysis

# %%
column_names = ['company_permalink', 'company_name', 'company_category_list', 'company_market', 'company_country_code', 'company_state_code', 'company_region', 'company_city', 'funding_round_permalink', 'funding_round_type', 'funding_round_code', 'funded_at', 'funded_month', ' funded_quarter ', 'funded_year', ' raised_amount_usd ']

for col in column_names:
  print('\n\n')
  print("==========================================================================")
  print(col.upper())
  print("VALUE COUNTS")
  print(rounds[col].value_counts())
  print("\n")

  print("DUPLICATE COUNTS")
  print(rounds.duplicated(subset=col, keep='first').sum())
  print("\n")

  print("NULL COUNTS AND PERCENTAGE")
  print(rounds[col].isnull().sum())
  print(rounds[col].isnull().sum()/len(rounds)*100)
  print('\n')
  
  print("NULL ROWS")
  display(rounds[rounds[col].isnull()])
# Out:
# ==========================================================================
# COMPANY_PERMALINK
# VALUE COUNTS
# /organization/solarflare               18
# /organization/mobivery                 16
# /organization/terascala                15
# /organization/aperto-networks          15
# /organization/instamed                 15
#                                        ..
# /organization/itsalat-international     1
# /organization/itsdapper                 1
# /organization/itsgoinon                 1
# /organization/itsmyurls                 1
# /organization/waywire                   1
# Name: company_permalink, Length: 49427, dtype: int64
#
#
# DUPLICATE COUNTS
# 34443
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, funding_round_permalink, funding_round_type, funding_round_code, funded_at, funded_month,  funded_quarter , funded_year,  raised_amount_usd ]
# Index: []
# ==========================================================================
# COMPANY_NAME
# VALUE COUNTS
# Solarflare Communications    18
# Mobivery                     16
# InstaMed                     15
# Aperto Networks              15
# Terascala                    15
#                              ..
# Iframe Apps                   1
# iFrat Wars                    1
# IfThisFits                    1
# ifussss                       1
# Lost Property Heaven          1
# Name: company_name, Length: 49344, dtype: int64
#
#
# DUPLICATE COUNTS
# 34525
#
#
# NULL COUNTS AND PERCENTAGE
# 1
# 0.0011923214498628831
#
#
# NULL ROWS
#               company_permalink company_name company_category_list  \
# 47686  /organization/tell-it-in          NaN            |Startups|
#
#       company_market company_country_code company_state_code company_region  \
# 47686       Startups                  NaN                NaN            NaN
#
#       company_city                          funding_round_permalink  \
# 47686          NaN  /funding-round/9c987e616755a78c51a4aa67c27a2a93
#
#       funding_round_type funding_round_code   funded_at funded_month  \
# 47686               seed                NaN  2012-03-01      2012-03
#
#        funded_quarter   funded_year   raised_amount_usd
# 47686         2012-Q1        2012.0              25000.0
# ==========================================================================
# COMPANY_CATEGORY_LIST
# VALUE COUNTS
# |Biotechnology|                                      7429
# |Software|                                           5824
# |Mobile|                                             2106
# |E-Commerce|                                         1978
# |Clean Technology|                                   1976
#                                                      ...
# |Software|Databases|Android|Mobile|Games|               1
# |Health Care|Web Tools|Software|                        1
# |Parenting|Social Media|Kids|Health and Wellness|       1
# |Internet|Nonprofits|Software|                          1
# |Entertainment|Politics|Social Media|News|              1
# Name: company_category_list, Length: 16666, dtype: int64
#
#
# DUPLICATE COUNTS
# 67203
#
#
# NULL COUNTS AND PERCENTAGE
# 4446
# 5.301061166090379
#
#
# NULL ROWS
#               company_permalink company_name company_category_list  \
# 60        /organization/12-labs      12 Labs                   NaN
# 76          /organization/12bis        12Bis                   NaN
# 100    /organization/16lab-inc-   16Lab Inc.                   NaN
# 115       /organization/1d4-pty      1d4 Pty                   NaN
# 132     /organization/1rp-media    1RP Media                   NaN
# ...                         ...          ...                   ...
# 83705      /organization/zuffle       Zuffle                   NaN
# 83746   /organization/zumodrive    zumodrive                   NaN
# 83768     /organization/zursh-2        Zursh                   NaN
# 83777      /organization/zuzher       Zuzher                   NaN
# 83786       /organization/zwamy        Zwamy                   NaN
#
#       company_market company_country_code company_state_code company_region  \
# 60               NaN                  NaN                NaN            NaN
# 76               NaN                  FRA                NaN          Paris
# 100              NaN                  NaN                NaN            NaN
# 115              NaN                  NOR                NaN     Aust-Agder
# 132              NaN                  USA                 CA    Los Angeles
# ...              ...                  ...                ...            ...
# 83705            NaN                  ITA                NaN    ITA - Other
# 83746            NaN                  NaN                NaN            NaN
# 83768            NaN                  NaN                NaN            NaN
# 83777            NaN                  NaN                NaN            NaN
# 83786            NaN                  USA                 CA    SF Bay Area
#
#           company_city                          funding_round_permalink  \
# 60                 NaN  /funding-round/958803df0c565d11afba52347f7efcde
# 76               Paris  /funding-round/19c048bab9708ca7aa465043160f59d1
# 100                NaN  /funding-round/2ee9967324046aa900ea572116ec9c38
# 115                NaN  /funding-round/3ad3787e6b62433a3e718dfe36ad133f
# 132        Los Angeles  /funding-round/f7400a94939ef73f70af0c52b54b31ce
# ...                ...                                              ...
# 83705            Prato  /funding-round/0871ea19b46655d8d109605e8b3f2330
# 83746              NaN  /funding-round/8e802d38dafc2673e37668852603d2a4
# 83768              NaN  /funding-round/c1fd05266e33d67cc540de1571ff31d3
# 83777              NaN  /funding-round/1538682f335c8aed32a7079bafa8a3a0
# 83786  Los Altos Hills  /funding-round/60491a4268d65adccab2653b47031af7
#
#       funding_round_type funding_round_code   funded_at funded_month  \
# 60                  seed                NaN  0026-11-14          NaN
# 76                  seed                NaN  2012-03-15      2012-03
# 100                 seed                NaN  2014-11-26      2014-11
# 115                 seed                NaN  2012-04-11      2012-04
# 132                 seed                NaN  2012-06-29      2012-06
# ...                  ...                ...         ...          ...
# 83705               seed                NaN  2013-07-26      2013-07
# 83746   convertible_note                NaN  2007-09-01      2007-09
# 83768               seed                NaN  2014-05-01      2014-05
# 83777              angel                NaN  2012-08-01      2012-08
# 83786     debt_financing                NaN  2014-04-02      2014-04
#
#        funded_quarter   funded_year   raised_amount_usd
# 60                 NaN          NaN             765000.0
# 76            2012-Q1        2012.0             130636.0
# 100           2014-Q4        2014.0                  NaN
# 115           2012-Q2        2012.0              40000.0
# 132           2012-Q2        2012.0                  NaN
# ...                ...          ...                  ...
# 83705         2013-Q3        2013.0             132351.0
# 83746         2007-Q3        2007.0                  NaN
# 83768         2014-Q2        2014.0              25000.0
# 83777         2012-Q3        2012.0              15698.0
# 83786         2014-Q2        2014.0             387794.0
#
# [4446 rows x 16 columns]
# ==========================================================================
# COMPANY_MARKET
# VALUE COUNTS
# Biotechnology              7652
# Software                   7632
# Mobile                     3571
# E-Commerce                 2959
# Health Care                2778
#                            ...
# New Product Development       1
# Homeless Shelter              1
# Insurance Companies           1
# Custom Retail                 1
# Rural Energy                  1
# Name: company_market, Length: 753, dtype: int64
#
#
# DUPLICATE COUNTS
# 83116
#
#
# NULL COUNTS AND PERCENTAGE
# 4453
# 5.309407416239418
#
#
# NULL ROWS
#               company_permalink company_name company_category_list  \
# 60        /organization/12-labs      12 Labs                   NaN
# 76          /organization/12bis        12Bis                   NaN
# 100    /organization/16lab-inc-   16Lab Inc.                   NaN
# 115       /organization/1d4-pty      1d4 Pty                   NaN
# 132     /organization/1rp-media    1RP Media                   NaN
# ...                         ...          ...                   ...
# 83705      /organization/zuffle       Zuffle                   NaN
# 83746   /organization/zumodrive    zumodrive                   NaN
# 83768     /organization/zursh-2        Zursh                   NaN
# 83777      /organization/zuzher       Zuzher                   NaN
# 83786       /organization/zwamy        Zwamy                   NaN
#
#       company_market company_country_code company_state_code company_region  \
# 60               NaN                  NaN                NaN            NaN
# 76               NaN                  FRA                NaN          Paris
# 100              NaN                  NaN                NaN            NaN
# 115              NaN                  NOR                NaN     Aust-Agder
# 132              NaN                  USA                 CA    Los Angeles
# ...              ...                  ...                ...            ...
# 83705            NaN                  ITA                NaN    ITA - Other
# 83746            NaN                  NaN                NaN            NaN
# 83768            NaN                  NaN                NaN            NaN
# 83777            NaN                  NaN                NaN            NaN
# 83786            NaN                  USA                 CA    SF Bay Area
#
#           company_city                          funding_round_permalink  \
# 60                 NaN  /funding-round/958803df0c565d11afba52347f7efcde
# 76               Paris  /funding-round/19c048bab9708ca7aa465043160f59d1
# 100                NaN  /funding-round/2ee9967324046aa900ea572116ec9c38
# 115                NaN  /funding-round/3ad3787e6b62433a3e718dfe36ad133f
# 132        Los Angeles  /funding-round/f7400a94939ef73f70af0c52b54b31ce
# ...                ...                                              ...
# 83705            Prato  /funding-round/0871ea19b46655d8d109605e8b3f2330
# 83746              NaN  /funding-round/8e802d38dafc2673e37668852603d2a4
# 83768              NaN  /funding-round/c1fd05266e33d67cc540de1571ff31d3
# 83777              NaN  /funding-round/1538682f335c8aed32a7079bafa8a3a0
# 83786  Los Altos Hills  /funding-round/60491a4268d65adccab2653b47031af7
#
#       funding_round_type funding_round_code   funded_at funded_month  \
# 60                  seed                NaN  0026-11-14          NaN
# 76                  seed                NaN  2012-03-15      2012-03
# 100                 seed                NaN  2014-11-26      2014-11
# 115                 seed                NaN  2012-04-11      2012-04
# 132                 seed                NaN  2012-06-29      2012-06
# ...                  ...                ...         ...          ...
# 83705               seed                NaN  2013-07-26      2013-07
# 83746   convertible_note                NaN  2007-09-01      2007-09
# 83768               seed                NaN  2014-05-01      2014-05
# 83777              angel                NaN  2012-08-01      2012-08
# 83786     debt_financing                NaN  2014-04-02      2014-04
#
#        funded_quarter   funded_year   raised_amount_usd
# 60                 NaN          NaN             765000.0
# 76            2012-Q1        2012.0             130636.0
# 100           2014-Q4        2014.0                  NaN
# 115           2012-Q2        2012.0              40000.0
# 132           2012-Q2        2012.0                  NaN
# ...                ...          ...                  ...
# 83705         2013-Q3        2013.0             132351.0
# 83746         2007-Q3        2007.0                  NaN
# 83768         2014-Q2        2014.0              25000.0
# 83777         2012-Q3        2012.0              15698.0
# 83786         2014-Q2        2014.0             387794.0
#
# [4453 rows x 16 columns]
# ==========================================================================
# COMPANY_COUNTRY_CODE
# VALUE COUNTS
# USA    54313
# GBR     4072
# CAN     2229
# CHN     2125
# DEU     1462
#        ...
# SOM        1
# MOZ        1
# ALB        1
# SYC        1
# JEY        1
# Name: company_country_code, Length: 115, dtype: int64
#
#
# DUPLICATE COUNTS
# 83754
#
#
# NULL COUNTS AND PERCENTAGE
# 6566
# 7.82878263979969
#
#
# NULL ROWS
#                 company_permalink   company_name  \
# 9           /organization/0-6-com        0-6.com
# 24     /organization/1000-markets   1000 Markets
# 41         /organization/100du-tv       100du.tv
# 42         /organization/100du-tv       100du.tv
# 51            /organization/10sec          10sec
# ...                           ...            ...
# 83768       /organization/zursh-2          Zursh
# 83777        /organization/zuzher         Zuzher
# 83791     /organization/zwoor-com      zwoor.com
# 83825         /organization/zympi          Zympi
# 83865  /organization/a-list-games  [a]list games
#
#                                    company_category_list   company_market  \
# 9                                          |Curated Web|      Curated Web
# 24                         |Marketplaces|Art|E-Commerce|     Marketplaces
# 41                                         |Hospitality|      Hospitality
# 42                                         |Hospitality|      Hospitality
# 51          |Social Commerce|E-Commerce|Mobile Commerce|  Mobile Commerce
# ...                                                  ...              ...
# 83768                                                NaN              NaN
# 83777                                                NaN              NaN
# 83791  |Meeting Software|Polling|Surveys|Android|iPho...          Polling
# 83825                    |Networking|Web Hosting|Mobile|      Web Hosting
# 83865                                            |Games|            Games
#
#       company_country_code company_state_code company_region company_city  \
# 9                      NaN                NaN            NaN          NaN
# 24                     NaN                NaN            NaN          NaN
# 41                     NaN                NaN            NaN          NaN
# 42                     NaN                NaN            NaN          NaN
# 51                     NaN                NaN            NaN          NaN
# ...                    ...                ...            ...          ...
# 83768                  NaN                NaN            NaN          NaN
# 83777                  NaN                NaN            NaN          NaN
# 83791                  NaN                NaN            NaN          NaN
# 83825                  NaN                NaN            NaN          NaN
# 83865                  NaN                NaN            NaN          NaN
#
#                                funding_round_permalink   funding_round_type  \
# 9      /funding-round/5727accaeaa57461bd22a9bdd945382d              venture
# 24     /funding-round/ce6749b6441f52ccaf38b6d5578779fd                 seed
# 41     /funding-round/46a9d3228f69c036e8076f1362ac58cd              venture
# 42     /funding-round/8797d60368bb0227f0d0ab4c72aef886              venture
# 51     /funding-round/3f842b5ec5236ed37e375b73e945ab7f                 seed
# ...                                                ...                  ...
# 83768  /funding-round/c1fd05266e33d67cc540de1571ff31d3                 seed
# 83777  /funding-round/1538682f335c8aed32a7079bafa8a3a0                angel
# 83791  /funding-round/817aedacbcb0993d2a748aab3f22648f                 seed
# 83825  /funding-round/4aaf79fabd66416d679c9830c01f31d1  equity_crowdfunding
# 83865  /funding-round/57d5459df4b227527e2edb2c1f183132                 seed
#
#       funding_round_code   funded_at funded_month  funded_quarter   \
# 9                      A  2008-03-19      2008-03         2008-Q1
# 24                   NaN  2009-05-15      2009-05         2009-Q2
# 41                     C  2010-08-13      2010-08         2010-Q3
# 42                     A  2008-01-07      2008-01         2008-Q1
# 51                   NaN  2014-05-08      2014-05         2014-Q2
# ...                  ...         ...          ...              ...
# 83768                NaN  2014-05-01      2014-05         2014-Q2
# 83777                NaN  2012-08-01      2012-08         2012-Q3
# 83791                NaN  2011-01-01      2011-01         2011-Q1
# 83825                NaN  2011-11-22      2011-11         2011-Q4
# 83865                NaN  2011-11-21      2011-11         2011-Q4
#
#        funded_year   raised_amount_usd
# 9           2008.0            2000000.0
# 24          2009.0             500000.0
# 41          2010.0                  NaN
# 42          2008.0            3000000.0
# 51          2014.0            1600000.0
# ...            ...                  ...
# 83768       2014.0              25000.0
# 83777       2012.0              15698.0
# 83791       2011.0             100000.0
# 83825       2011.0                  NaN
# 83865       2011.0            9300000.0
#
# [6566 rows x 16 columns]
# ==========================================================================
# COMPANY_STATE_CODE
# VALUE COUNTS
# CA    20173
# NY     5254
# MA     4421
# TX     2640
# WA     1928
#       ...
# WY       18
# MB       14
# NB       11
# SK        5
# PE        3
# Name: company_state_code, Length: 61, dtype: int64
#
#
# DUPLICATE COUNTS
# 83808
#
#
# NULL COUNTS AND PERCENTAGE
# 27373
# 32.637415047096695
#
#
# NULL ROWS
#                       company_permalink           company_name  \
# 3         /organization/rock-your-paper      'Rock' Your Paper
# 4        /organization/in-touch-network      (In)Touch Network
# 8            /organization/fox-networks          .Fox Networks
# 9                 /organization/0-6-com                0-6.com
# 11     /organization/01games-technology     01Games Technology
# ...                                 ...                    ...
# 83861         /organization/zzzzapp-com  Zzzzapp Wireless ltd.
# 83862         /organization/zzzzapp-com  Zzzzapp Wireless ltd.
# 83863         /organization/zzzzapp-com  Zzzzapp Wireless ltd.
# 83864         /organization/zzzzapp-com  Zzzzapp Wireless ltd.
# 83865        /organization/a-list-games          [a]list games
#
#                                    company_category_list   company_market  \
# 3                                 |Publishing|Education|       Publishing
# 4      |Electronics|Guides|Coffee|Restaurants|Music|i...      Electronics
# 8                                          |Advertising|      Advertising
# 9                                          |Curated Web|      Curated Web
# 11                                               |Games|            Games
# ...                                                  ...              ...
# 83861      |Web Development|Advertising|Wireless|Mobile|  Web Development
# 83862      |Web Development|Advertising|Wireless|Mobile|  Web Development
# 83863      |Web Development|Advertising|Wireless|Mobile|  Web Development
# 83864      |Web Development|Advertising|Wireless|Mobile|  Web Development
# 83865                                            |Games|            Games
#
#       company_country_code company_state_code company_region  company_city  \
# 3                      EST                NaN        Tallinn       Tallinn
# 4                      GBR                NaN         London        London
# 8                      ARG                NaN   Buenos Aires  Buenos Aires
# 9                      NaN                NaN            NaN           NaN
# 11                     HKG                NaN      Hong Kong     Hong Kong
# ...                    ...                ...            ...           ...
# 83861                  HRV                NaN          Split         Split
# 83862                  HRV                NaN          Split         Split
# 83863                  HRV                NaN          Split         Split
# 83864                  HRV                NaN          Split         Split
# 83865                  NaN                NaN            NaN           NaN
#
#                                funding_round_permalink funding_round_type  \
# 3      /funding-round/f06b420775f7cb6c1541a9db526534bb               seed
# 4      /funding-round/33c3f135f05d7b734b8d7b7c8ae82647               seed
# 8      /funding-round/69a1536a6f4506538afd7aa7241ddbe1        undisclosed
# 9      /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 11     /funding-round/7d53696f2b4f607a2f2a8cbb83d01839               seed
# ...                                                ...                ...
# 83861  /funding-round/22ef2fafb4d20ac3aa4b86143dbf6c8e               seed
# 83862  /funding-round/6ba41360588bc6e3f77e9b50a0ebfafa               seed
# 83863  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 83864  /funding-round/8f6d25b8ee4199e586484d817bceda05   convertible_note
# 83865  /funding-round/57d5459df4b227527e2edb2c1f183132               seed
#
#       funding_round_code   funded_at funded_month  funded_quarter   \
# 3                    NaN  2012-08-09      2012-08         2012-Q3
# 4                    NaN  2011-04-01      2011-04         2011-Q2
# 8                    NaN  2007-01-16      2007-01         2007-Q1
# 9                      A  2008-03-19      2008-03         2008-Q1
# 11                   NaN  2014-07-01      2014-07         2014-Q3
# ...                  ...         ...          ...              ...
# 83861                NaN  2011-11-01      2011-11         2011-Q4
# 83862                NaN  2013-08-01      2013-08         2013-Q3
# 83863                NaN  2013-03-19      2013-03         2013-Q1
# 83864                NaN  2014-01-01      2014-01         2014-Q1
# 83865                NaN  2011-11-21      2011-11         2011-Q4
#
#        funded_year   raised_amount_usd
# 3           2012.0              40000.0
# 4           2011.0            1500000.0
# 8           2007.0            4912393.0
# 9           2008.0            2000000.0
# 11          2014.0              41250.0
# ...            ...                  ...
# 83861       2011.0               7000.0
# 83862       2013.0              32165.0
# 83863       2013.0              32360.0
# 83864       2014.0              12955.0
# 83865       2011.0            9300000.0
#
# [27373 rows x 16 columns]
# ==========================================================================
# COMPANY_REGION
# VALUE COUNTS
# SF Bay Area        14473
# New York City       4760
# Boston              4156
# London              2593
# Los Angeles         2451
#                    ...
# Reigate                1
# Andhra Pradesh         1
# MOZ - Other            1
# Kolbermoor             1
# Buckinghamshire        1
# Name: company_region, Length: 1089, dtype: int64
#
#
# DUPLICATE COUNTS
# 82780
#
#
# NULL COUNTS AND PERCENTAGE
# 6566
# 7.82878263979969
#
#
# NULL ROWS
#                 company_permalink   company_name  \
# 9           /organization/0-6-com        0-6.com
# 24     /organization/1000-markets   1000 Markets
# 41         /organization/100du-tv       100du.tv
# 42         /organization/100du-tv       100du.tv
# 51            /organization/10sec          10sec
# ...                           ...            ...
# 83768       /organization/zursh-2          Zursh
# 83777        /organization/zuzher         Zuzher
# 83791     /organization/zwoor-com      zwoor.com
# 83825         /organization/zympi          Zympi
# 83865  /organization/a-list-games  [a]list games
#
#                                    company_category_list   company_market  \
# 9                                          |Curated Web|      Curated Web
# 24                         |Marketplaces|Art|E-Commerce|     Marketplaces
# 41                                         |Hospitality|      Hospitality
# 42                                         |Hospitality|      Hospitality
# 51          |Social Commerce|E-Commerce|Mobile Commerce|  Mobile Commerce
# ...                                                  ...              ...
# 83768                                                NaN              NaN
# 83777                                                NaN              NaN
# 83791  |Meeting Software|Polling|Surveys|Android|iPho...          Polling
# 83825                    |Networking|Web Hosting|Mobile|      Web Hosting
# 83865                                            |Games|            Games
#
#       company_country_code company_state_code company_region company_city  \
# 9                      NaN                NaN            NaN          NaN
# 24                     NaN                NaN            NaN          NaN
# 41                     NaN                NaN            NaN          NaN
# 42                     NaN                NaN            NaN          NaN
# 51                     NaN                NaN            NaN          NaN
# ...                    ...                ...            ...          ...
# 83768                  NaN                NaN            NaN          NaN
# 83777                  NaN                NaN            NaN          NaN
# 83791                  NaN                NaN            NaN          NaN
# 83825                  NaN                NaN            NaN          NaN
# 83865                  NaN                NaN            NaN          NaN
#
#                                funding_round_permalink   funding_round_type  \
# 9      /funding-round/5727accaeaa57461bd22a9bdd945382d              venture
# 24     /funding-round/ce6749b6441f52ccaf38b6d5578779fd                 seed
# 41     /funding-round/46a9d3228f69c036e8076f1362ac58cd              venture
# 42     /funding-round/8797d60368bb0227f0d0ab4c72aef886              venture
# 51     /funding-round/3f842b5ec5236ed37e375b73e945ab7f                 seed
# ...                                                ...                  ...
# 83768  /funding-round/c1fd05266e33d67cc540de1571ff31d3                 seed
# 83777  /funding-round/1538682f335c8aed32a7079bafa8a3a0                angel
# 83791  /funding-round/817aedacbcb0993d2a748aab3f22648f                 seed
# 83825  /funding-round/4aaf79fabd66416d679c9830c01f31d1  equity_crowdfunding
# 83865  /funding-round/57d5459df4b227527e2edb2c1f183132                 seed
#
#       funding_round_code   funded_at funded_month  funded_quarter   \
# 9                      A  2008-03-19      2008-03         2008-Q1
# 24                   NaN  2009-05-15      2009-05         2009-Q2
# 41                     C  2010-08-13      2010-08         2010-Q3
# 42                     A  2008-01-07      2008-01         2008-Q1
# 51                   NaN  2014-05-08      2014-05         2014-Q2
# ...                  ...         ...          ...              ...
# 83768                NaN  2014-05-01      2014-05         2014-Q2
# 83777                NaN  2012-08-01      2012-08         2012-Q3
# 83791                NaN  2011-01-01      2011-01         2011-Q1
# 83825                NaN  2011-11-22      2011-11         2011-Q4
# 83865                NaN  2011-11-21      2011-11         2011-Q4
#
#        funded_year   raised_amount_usd
# 9           2008.0            2000000.0
# 24          2009.0             500000.0
# 41          2010.0                  NaN
# 42          2008.0            3000000.0
# 51          2014.0            1600000.0
# ...            ...                  ...
# 83768       2014.0              25000.0
# 83777       2012.0              15698.0
# 83791       2011.0             100000.0
# 83825       2011.0                  NaN
# 83865       2011.0            9300000.0
#
# [6566 rows x 16 columns]
# ==========================================================================
# COMPANY_CITY
# VALUE COUNTS
# San Francisco       5397
# New York            4401
# London              2003
# Palo Alto           1199
# Cambridge           1182
#                     ...
# Wylie                  1
# State University       1
# Coldwater              1
# Skövde                 1
# Moncalieri             1
# Name: company_city, Length: 4188, dtype: int64
#
#
# DUPLICATE COUNTS
# 79681
#
#
# NULL COUNTS AND PERCENTAGE
# 7647
# 9.117682127101466
#
#
# NULL ROWS
#                 company_permalink   company_name  \
# 9           /organization/0-6-com        0-6.com
# 24     /organization/1000-markets   1000 Markets
# 41         /organization/100du-tv       100du.tv
# 42         /organization/100du-tv       100du.tv
# 51            /organization/10sec          10sec
# ...                           ...            ...
# 83768       /organization/zursh-2          Zursh
# 83777        /organization/zuzher         Zuzher
# 83791     /organization/zwoor-com      zwoor.com
# 83825         /organization/zympi          Zympi
# 83865  /organization/a-list-games  [a]list games
#
#                                    company_category_list   company_market  \
# 9                                          |Curated Web|      Curated Web
# 24                         |Marketplaces|Art|E-Commerce|     Marketplaces
# 41                                         |Hospitality|      Hospitality
# 42                                         |Hospitality|      Hospitality
# 51          |Social Commerce|E-Commerce|Mobile Commerce|  Mobile Commerce
# ...                                                  ...              ...
# 83768                                                NaN              NaN
# 83777                                                NaN              NaN
# 83791  |Meeting Software|Polling|Surveys|Android|iPho...          Polling
# 83825                    |Networking|Web Hosting|Mobile|      Web Hosting
# 83865                                            |Games|            Games
#
#       company_country_code company_state_code company_region company_city  \
# 9                      NaN                NaN            NaN          NaN
# 24                     NaN                NaN            NaN          NaN
# 41                     NaN                NaN            NaN          NaN
# 42                     NaN                NaN            NaN          NaN
# 51                     NaN                NaN            NaN          NaN
# ...                    ...                ...            ...          ...
# 83768                  NaN                NaN            NaN          NaN
# 83777                  NaN                NaN            NaN          NaN
# 83791                  NaN                NaN            NaN          NaN
# 83825                  NaN                NaN            NaN          NaN
# 83865                  NaN                NaN            NaN          NaN
#
#                                funding_round_permalink   funding_round_type  \
# 9      /funding-round/5727accaeaa57461bd22a9bdd945382d              venture
# 24     /funding-round/ce6749b6441f52ccaf38b6d5578779fd                 seed
# 41     /funding-round/46a9d3228f69c036e8076f1362ac58cd              venture
# 42     /funding-round/8797d60368bb0227f0d0ab4c72aef886              venture
# 51     /funding-round/3f842b5ec5236ed37e375b73e945ab7f                 seed
# ...                                                ...                  ...
# 83768  /funding-round/c1fd05266e33d67cc540de1571ff31d3                 seed
# 83777  /funding-round/1538682f335c8aed32a7079bafa8a3a0                angel
# 83791  /funding-round/817aedacbcb0993d2a748aab3f22648f                 seed
# 83825  /funding-round/4aaf79fabd66416d679c9830c01f31d1  equity_crowdfunding
# 83865  /funding-round/57d5459df4b227527e2edb2c1f183132                 seed
#
#       funding_round_code   funded_at funded_month  funded_quarter   \
# 9                      A  2008-03-19      2008-03         2008-Q1
# 24                   NaN  2009-05-15      2009-05         2009-Q2
# 41                     C  2010-08-13      2010-08         2010-Q3
# 42                     A  2008-01-07      2008-01         2008-Q1
# 51                   NaN  2014-05-08      2014-05         2014-Q2
# ...                  ...         ...          ...              ...
# 83768                NaN  2014-05-01      2014-05         2014-Q2
# 83777                NaN  2012-08-01      2012-08         2012-Q3
# 83791                NaN  2011-01-01      2011-01         2011-Q1
# 83825                NaN  2011-11-22      2011-11         2011-Q4
# 83865                NaN  2011-11-21      2011-11         2011-Q4
#
#        funded_year   raised_amount_usd
# 9           2008.0            2000000.0
# 24          2009.0             500000.0
# 41          2010.0                  NaN
# 42          2008.0            3000000.0
# 51          2014.0            1600000.0
# ...            ...                  ...
# 83768       2014.0              25000.0
# 83777       2012.0              15698.0
# 83791       2011.0             100000.0
# 83825       2011.0                  NaN
# 83865       2011.0            9300000.0
#
# [7647 rows x 16 columns]
# ==========================================================================
# FUNDING_ROUND_PERMALINK
# VALUE COUNTS
# /funding-round/cc409188fa2b63482bd9008f682c2efa    1
# /funding-round/6f07f21df5f9d1632a5664e586261217    1
# /funding-round/a0960d0d9ad9f88db43f465482277d20    1
# /funding-round/576658dab6661974462815fb7a0c20aa    1
# /funding-round/01cba1e55eb3d82da0a7e94557a96501    1
#                                                   ..
# /funding-round/5c9d8fd5e6f5fa1a28e3dafd6b23fae1    1
# /funding-round/37c6cac8889b15cb4db311d01afac287    1
# /funding-round/702499a1e2280aee7f1ada3e9da7e05c    1
# /funding-round/f05c2325ba9cc43b696357079137ff04    1
# /funding-round/5c5ebcc9d85c2a5f810e319c249a36e7    1
# Name: funding_round_permalink, Length: 83870, dtype: int64
#
#
# DUPLICATE COUNTS
# 0
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, funding_round_permalink, funding_round_type, funding_round_code, funded_at, funded_month,  funded_quarter , funded_year,  raised_amount_usd ]
# Index: []
# ==========================================================================
# FUNDING_ROUND_TYPE
# VALUE COUNTS
# venture                 41742
# seed                    21036
# debt_financing           5692
# angel                    4443
# undisclosed              3871
# equity_crowdfunding      2256
# private_equity           1828
# grant                    1476
# convertible_note          759
# post_ipo_equity           395
# product_crowdfunding      235
# post_ipo_debt              82
# secondary_market           55
# Name: funding_round_type, dtype: int64
#
#
# DUPLICATE COUNTS
# 83857
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, funding_round_permalink, funding_round_type, funding_round_code, funded_at, funded_month,  funded_quarter , funded_year,  raised_amount_usd ]
# Index: []
# ==========================================================================
# FUNDING_ROUND_CODE
# VALUE COUNTS
# A    11033
# B     6344
# C     3223
# D     1462
# E      576
# F      190
# G       38
# H        4
# Name: funding_round_code, dtype: int64
#
#
# DUPLICATE COUNTS
# 83861
#
#
# NULL COUNTS AND PERCENTAGE
# 61000
# 72.73160844163587
#
#
# NULL ROWS
#                      company_permalink           company_name  \
# 0                /organization/waywire               #waywire
# 1      /organization/tv-communications     &TV Communications
# 2      /organization/tv-communications     &TV Communications
# 3        /organization/rock-your-paper      'Rock' Your Paper
# 4       /organization/in-touch-network      (In)Touch Network
# ...                                ...                    ...
# 83863        /organization/zzzzapp-com  Zzzzapp Wireless ltd.
# 83864        /organization/zzzzapp-com  Zzzzapp Wireless ltd.
# 83865       /organization/a-list-games          [a]list games
# 83866                  /organization/x                  [x+1]
# 83869                  /organization/x                  [x+1]
#
#                                    company_category_list       company_market  \
# 0             |Entertainment|Politics|Social Media|News|                 News
# 1                                                |Games|                Games
# 2                                                |Games|                Games
# 3                                 |Publishing|Education|           Publishing
# 4      |Electronics|Guides|Coffee|Restaurants|Music|i...          Electronics
# ...                                                  ...                  ...
# 83863      |Web Development|Advertising|Wireless|Mobile|      Web Development
# 83864      |Web Development|Advertising|Wireless|Mobile|      Web Development
# 83865                                            |Games|                Games
# 83866                              |Enterprise Software|  Enterprise Software
# 83869                              |Enterprise Software|  Enterprise Software
#
#       company_country_code company_state_code company_region company_city  \
# 0                      USA                 NY  New York City     New York
# 1                      USA                 CA    Los Angeles  Los Angeles
# 2                      USA                 CA    Los Angeles  Los Angeles
# 3                      EST                NaN        Tallinn      Tallinn
# 4                      GBR                NaN         London       London
# ...                    ...                ...            ...          ...
# 83863                  HRV                NaN          Split        Split
# 83864                  HRV                NaN          Split        Split
# 83865                  NaN                NaN            NaN          NaN
# 83866                  USA                 NY  New York City     New York
# 83869                  USA                 NY  New York City     New York
#
#                                funding_round_permalink funding_round_type  \
# 0      /funding-round/cc409188fa2b63482bd9008f682c2efa               seed
# 1      /funding-round/59a3669a64e39360c2b939300bcda162            venture
# 2      /funding-round/86d22afc65107b6941e6c43c671ecbb8            venture
# 3      /funding-round/f06b420775f7cb6c1541a9db526534bb               seed
# 4      /funding-round/33c3f135f05d7b734b8d7b7c8ae82647               seed
# ...                                                ...                ...
# 83863  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 83864  /funding-round/8f6d25b8ee4199e586484d817bceda05   convertible_note
# 83865  /funding-round/57d5459df4b227527e2edb2c1f183132               seed
# 83866  /funding-round/9e17c1f6579169daac605d43926e02fb     debt_financing
# 83869  /funding-round/5c5ebcc9d85c2a5f810e319c249a36e7            venture
#
#       funding_round_code   funded_at funded_month  funded_quarter   \
# 0                    NaN  2012-06-30      2012-06         2012-Q2
# 1                    NaN  2010-09-23      2010-09         2010-Q3
# 2                    NaN  2010-06-04      2010-06         2010-Q2
# 3                    NaN  2012-08-09      2012-08         2012-Q3
# 4                    NaN  2011-04-01      2011-04         2011-Q2
# ...                  ...         ...          ...              ...
# 83863                NaN  2013-03-19      2013-03         2013-Q1
# 83864                NaN  2014-01-01      2014-01         2014-Q1
# 83865                NaN  2011-11-21      2011-11         2011-Q4
# 83866                NaN  2013-04-04      2013-04         2013-Q2
# 83869                NaN  2009-08-17      2009-08         2009-Q3
#
#        funded_year   raised_amount_usd
# 0           2012.0            1750000.0
# 1           2010.0            3000000.0
# 2           2010.0            1000000.0
# 3           2012.0              40000.0
# 4           2011.0            1500000.0
# ...            ...                  ...
# 83863       2013.0              32360.0
# 83864       2014.0              12955.0
# 83865       2011.0            9300000.0
# 83866       2013.0           17000000.0
# 83869       2009.0            2000000.0
#
# [61000 rows x 16 columns]
# ==========================================================================
# FUNDED_AT
# VALUE COUNTS
# 2012-01-01    652
# 2013-01-01    616
# 2008-01-01    548
# 2011-01-01    511
# 2014-01-01    464
#              ...
# 2004-08-25      1
# 2003-12-12      1
# 2005-06-12      1
# 1990-10-31      1
# 2005-05-27      1
# Name: funded_at, Length: 4159, dtype: int64
#
#
# DUPLICATE COUNTS
# 79711
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, funding_round_permalink, funding_round_type, funding_round_code, funded_at, funded_month,  funded_quarter , funded_year,  raised_amount_usd ]
# Index: []
# ==========================================================================
# FUNDED_MONTH
# VALUE COUNTS
# 2014-01    1889
# 2014-07    1592
# 2014-06    1590
# 2013-09    1571
# 2013-10    1570
#            ...
# 1996-04       1
# 1990-07       1
# 1991-10       1
# 1988-11       1
# 1992-02       1
# Name: funded_month, Length: 308, dtype: int64
#
#
# DUPLICATE COUNTS
# 83561
#
#
# NULL COUNTS AND PERCENTAGE
# 10
# 0.01192321449862883
#
#
# NULL ROWS
#                              company_permalink               company_name  \
# 60                       /organization/12-labs                    12 Labs
# 2637                      /organization/agflow                     AgFlow
# 11563                  /organization/buru-buru                  Buru Buru
# 24877                    /organization/exploco                    Exploco
# 50199                     /organization/nubank                     Nubank
# 54020                 /organization/peoplegoal                 PeopleGoal
# 61572                      /organization/rotor                      Rotor
# 63245  /organization/securenet-payment-systems  SecureNet Payment Systems
# 64605                 /organization/shopboostr                 Shopboostr
# 72904         /organization/the-urban-roosters         The Urban Roosters
#
#                                   company_category_list       company_market  \
# 60                                                  NaN                  NaN
# 2637                                         |Software|             Software
# 11563  |Startups|Internet|Retail|Design|Art|E-Commerce|             Startups
# 24877                                |Adventure Travel|     Adventure Travel
# 50199            |Consumer Internet|Financial Services|   Financial Services
# 54020                             |Enterprise Software|  Enterprise Software
# 61572                     |Developer Tools|Music|Video|                Video
# 63245     |Trading|Mobile Payments|Payments|E-Commerce|             Payments
# 64605     |SaaS|Reviews and Recommendations|E-Commerce|                 SaaS
# 72904                                               NaN                  NaN
#
#       company_country_code company_state_code company_region company_city  \
# 60                     NaN                NaN            NaN          NaN
# 2637                   CHE                NaN         Geneva       Geneva
# 11563                  ITA                NaN        Firenze      Firenze
# 24877                  AUS                NaN          Perth        Perth
# 50199                  BRA                NaN      Sao Paulo    São Paulo
# 54020                  NaN                NaN            NaN          NaN
# 61572                  IRL                NaN         Dublin       Dublin
# 63245                  USA                 TX         Austin       Austin
# 64605                  NaN                NaN            NaN          NaN
# 72904                  NaN                NaN            NaN          NaN
#
#                                funding_round_permalink funding_round_type  \
# 60     /funding-round/958803df0c565d11afba52347f7efcde               seed
# 2637   /funding-round/a4fcc1845670f82284af88690d1db2ad               seed
# 11563  /funding-round/1e22bfd0485bd84bd78a880edd8d25a6               seed
# 24877  /funding-round/f5769fb890cd1ab33f70abf959d932c9               seed
# 50199  /funding-round/6aaddf226adfaa6eb7dc8497331d9a7b               seed
# 54020  /funding-round/c0990da936fc935fb4eb4dc4c9c8d129               seed
# 61572  /funding-round/4f2416bb4db59e5e585ce3d57cd906ef   convertible_note
# 63245  /funding-round/d72b60bd12b826d684820c6d28957899     private_equity
# 64605  /funding-round/52b8b119eab4ea1af360c5306526c6a9               seed
# 72904  /funding-round/45a194fa4e0eec9cfd60fa00a3c098cc              angel
#
#       funding_round_code   funded_at funded_month  funded_quarter   \
# 60                   NaN  0026-11-14          NaN              NaN
# 2637                 NaN  0020-06-14          NaN              NaN
# 11563                NaN  0019-11-20          NaN              NaN
# 24877                NaN  0201-01-01          NaN              NaN
# 50199                NaN  0007-05-13          NaN              NaN
# 54020                NaN  0001-05-14          NaN              NaN
# 61572                NaN  0029-09-14          NaN              NaN
# 63245                NaN  0011-11-14          NaN              NaN
# 64605                NaN  0001-11-14          NaN              NaN
# 72904                NaN  0001-07-14          NaN              NaN
#
#        funded_year   raised_amount_usd
# 60             NaN             765000.0
# 2637           NaN                  NaN
# 11563          NaN                  NaN
# 24877          NaN                  NaN
# 50199          NaN            2000000.0
# 54020          NaN                  NaN
# 61572          NaN                  NaN
# 63245          NaN                  NaN
# 64605          NaN                  NaN
# 72904          NaN                  NaN
# ==========================================================================
#  FUNDED_QUARTER
# VALUE COUNTS
#  2014-Q1     4775
#  2014-Q2     4478
#  2013-Q4     4359
#  2014-Q3     4354
#  2013-Q3     4178
#              ...
#  1960-Q4        1
#  1974-Q1        1
#  1995-Q3        1
#  1979-Q1        1
#  1921-Q3        1
# Name:  funded_quarter , Length: 130, dtype: int64
#
#
# DUPLICATE COUNTS
# 83739
#
#
# NULL COUNTS AND PERCENTAGE
# 10
# 0.01192321449862883
#
#
# NULL ROWS
#                              company_permalink               company_name  \
# 60                       /organization/12-labs                    12 Labs
# 2637                      /organization/agflow                     AgFlow
# 11563                  /organization/buru-buru                  Buru Buru
# 24877                    /organization/exploco                    Exploco
# 50199                     /organization/nubank                     Nubank
# 54020                 /organization/peoplegoal                 PeopleGoal
# 61572                      /organization/rotor                      Rotor
# 63245  /organization/securenet-payment-systems  SecureNet Payment Systems
# 64605                 /organization/shopboostr                 Shopboostr
# 72904         /organization/the-urban-roosters         The Urban Roosters
#
#                                   company_category_list       company_market  \
# 60                                                  NaN                  NaN
# 2637                                         |Software|             Software
# 11563  |Startups|Internet|Retail|Design|Art|E-Commerce|             Startups
# 24877                                |Adventure Travel|     Adventure Travel
# 50199            |Consumer Internet|Financial Services|   Financial Services
# 54020                             |Enterprise Software|  Enterprise Software
# 61572                     |Developer Tools|Music|Video|                Video
# 63245     |Trading|Mobile Payments|Payments|E-Commerce|             Payments
# 64605     |SaaS|Reviews and Recommendations|E-Commerce|                 SaaS
# 72904                                               NaN                  NaN
#
#       company_country_code company_state_code company_region company_city  \
# 60                     NaN                NaN            NaN          NaN
# 2637                   CHE                NaN         Geneva       Geneva
# 11563                  ITA                NaN        Firenze      Firenze
# 24877                  AUS                NaN          Perth        Perth
# 50199                  BRA                NaN      Sao Paulo    São Paulo
# 54020                  NaN                NaN            NaN          NaN
# 61572                  IRL                NaN         Dublin       Dublin
# 63245                  USA                 TX         Austin       Austin
# 64605                  NaN                NaN            NaN          NaN
# 72904                  NaN                NaN            NaN          NaN
#
#                                funding_round_permalink funding_round_type  \
# 60     /funding-round/958803df0c565d11afba52347f7efcde               seed
# 2637   /funding-round/a4fcc1845670f82284af88690d1db2ad               seed
# 11563  /funding-round/1e22bfd0485bd84bd78a880edd8d25a6               seed
# 24877  /funding-round/f5769fb890cd1ab33f70abf959d932c9               seed
# 50199  /funding-round/6aaddf226adfaa6eb7dc8497331d9a7b               seed
# 54020  /funding-round/c0990da936fc935fb4eb4dc4c9c8d129               seed
# 61572  /funding-round/4f2416bb4db59e5e585ce3d57cd906ef   convertible_note
# 63245  /funding-round/d72b60bd12b826d684820c6d28957899     private_equity
# 64605  /funding-round/52b8b119eab4ea1af360c5306526c6a9               seed
# 72904  /funding-round/45a194fa4e0eec9cfd60fa00a3c098cc              angel
#
#       funding_round_code   funded_at funded_month  funded_quarter   \
# 60                   NaN  0026-11-14          NaN              NaN
# 2637                 NaN  0020-06-14          NaN              NaN
# 11563                NaN  0019-11-20          NaN              NaN
# 24877                NaN  0201-01-01          NaN              NaN
# 50199                NaN  0007-05-13          NaN              NaN
# 54020                NaN  0001-05-14          NaN              NaN
# 61572                NaN  0029-09-14          NaN              NaN
# 63245                NaN  0011-11-14          NaN              NaN
# 64605                NaN  0001-11-14          NaN              NaN
# 72904                NaN  0001-07-14          NaN              NaN
#
#        funded_year   raised_amount_usd
# 60             NaN             765000.0
# 2637           NaN                  NaN
# 11563          NaN                  NaN
# 24877          NaN                  NaN
# 50199          NaN            2000000.0
# 54020          NaN                  NaN
# 61572          NaN                  NaN
# 63245          NaN                  NaN
# 64605          NaN                  NaN
# 72904          NaN                  NaN
# ==========================================================================
# FUNDED_YEAR
# VALUE COUNTS
# 2013.0    15969
# 2014.0    15825
# 2012.0    12512
# 2011.0    10471
# 2010.0     8647
# 2009.0     6515
# 2008.0     4235
# 2007.0     3535
# 2006.0     2640
# 2005.0     1753
# 2004.0      414
# 2000.0      266
# 2003.0      259
# 2002.0      203
# 2001.0      191
# 1999.0      176
# 1998.0       61
# 1996.0       32
# 1997.0       30
# 1995.0       21
# 1994.0       15
# 1993.0       15
# 1990.0       14
# 1992.0       12
# 1991.0       10
# 1985.0        6
# 1987.0        6
# 1986.0        4
# 1989.0        4
# 1984.0        4
# 1960.0        3
# 1982.0        3
# 1974.0        2
# 1988.0        2
# 1979.0        1
# 1973.0        1
# 1983.0        1
# 2015.0        1
# 1921.0        1
# Name: funded_year, dtype: int64
#
#
# DUPLICATE COUNTS
# 83830
#
#
# NULL COUNTS AND PERCENTAGE
# 10
# 0.01192321449862883
#
#
# NULL ROWS
#                              company_permalink               company_name  \
# 60                       /organization/12-labs                    12 Labs
# 2637                      /organization/agflow                     AgFlow
# 11563                  /organization/buru-buru                  Buru Buru
# 24877                    /organization/exploco                    Exploco
# 50199                     /organization/nubank                     Nubank
# 54020                 /organization/peoplegoal                 PeopleGoal
# 61572                      /organization/rotor                      Rotor
# 63245  /organization/securenet-payment-systems  SecureNet Payment Systems
# 64605                 /organization/shopboostr                 Shopboostr
# 72904         /organization/the-urban-roosters         The Urban Roosters
#
#                                   company_category_list       company_market  \
# 60                                                  NaN                  NaN
# 2637                                         |Software|             Software
# 11563  |Startups|Internet|Retail|Design|Art|E-Commerce|             Startups
# 24877                                |Adventure Travel|     Adventure Travel
# 50199            |Consumer Internet|Financial Services|   Financial Services
# 54020                             |Enterprise Software|  Enterprise Software
# 61572                     |Developer Tools|Music|Video|                Video
# 63245     |Trading|Mobile Payments|Payments|E-Commerce|             Payments
# 64605     |SaaS|Reviews and Recommendations|E-Commerce|                 SaaS
# 72904                                               NaN                  NaN
#
#       company_country_code company_state_code company_region company_city  \
# 60                     NaN                NaN            NaN          NaN
# 2637                   CHE                NaN         Geneva       Geneva
# 11563                  ITA                NaN        Firenze      Firenze
# 24877                  AUS                NaN          Perth        Perth
# 50199                  BRA                NaN      Sao Paulo    São Paulo
# 54020                  NaN                NaN            NaN          NaN
# 61572                  IRL                NaN         Dublin       Dublin
# 63245                  USA                 TX         Austin       Austin
# 64605                  NaN                NaN            NaN          NaN
# 72904                  NaN                NaN            NaN          NaN
#
#                                funding_round_permalink funding_round_type  \
# 60     /funding-round/958803df0c565d11afba52347f7efcde               seed
# 2637   /funding-round/a4fcc1845670f82284af88690d1db2ad               seed
# 11563  /funding-round/1e22bfd0485bd84bd78a880edd8d25a6               seed
# 24877  /funding-round/f5769fb890cd1ab33f70abf959d932c9               seed
# 50199  /funding-round/6aaddf226adfaa6eb7dc8497331d9a7b               seed
# 54020  /funding-round/c0990da936fc935fb4eb4dc4c9c8d129               seed
# 61572  /funding-round/4f2416bb4db59e5e585ce3d57cd906ef   convertible_note
# 63245  /funding-round/d72b60bd12b826d684820c6d28957899     private_equity
# 64605  /funding-round/52b8b119eab4ea1af360c5306526c6a9               seed
# 72904  /funding-round/45a194fa4e0eec9cfd60fa00a3c098cc              angel
#
#       funding_round_code   funded_at funded_month  funded_quarter   \
# 60                   NaN  0026-11-14          NaN              NaN
# 2637                 NaN  0020-06-14          NaN              NaN
# 11563                NaN  0019-11-20          NaN              NaN
# 24877                NaN  0201-01-01          NaN              NaN
# 50199                NaN  0007-05-13          NaN              NaN
# 54020                NaN  0001-05-14          NaN              NaN
# 61572                NaN  0029-09-14          NaN              NaN
# 63245                NaN  0011-11-14          NaN              NaN
# 64605                NaN  0001-11-14          NaN              NaN
# 72904                NaN  0001-07-14          NaN              NaN
#
#        funded_year   raised_amount_usd
# 60             NaN             765000.0
# 2637           NaN                  NaN
# 11563          NaN                  NaN
# 24877          NaN                  NaN
# 50199          NaN            2000000.0
# 54020          NaN                  NaN
# 61572          NaN                  NaN
# 63245          NaN                  NaN
# 64605          NaN                  NaN
# 72904          NaN                  NaN
# ==========================================================================
#  RAISED_AMOUNT_USD
# VALUE COUNTS
# 1000000.0     2267
# 2000000.0     1691
# 500000.0      1660
# 5000000.0     1585
# 10000000.0    1569
#               ...
# 4891000.0        1
# 8676000.0        1
# 2874000.0        1
# 7483000.0        1
# 12955.0          1
# Name:  raised_amount_usd , Length: 16582, dtype: int64
#
#
# DUPLICATE COUNTS
# 67287
#
#
# NULL COUNTS AND PERCENTAGE
# 12955
# 15.446524382973651
#
#
# NULL ROWS
#                      company_permalink       company_name  \
# 10      /organization/004-technologies   004 Technologies
# 13               /organization/1-4-all            1-4 All
# 14         /organization/1-800-dentist      1-800-DENTIST
# 16      /organization/1-618-technology   1.618 Technology
# 25     /organization/1000jobboersen-de  1000jobboersen.de
# ...                                ...                ...
# 83816           /organization/zymergen           Zymergen
# 83825              /organization/zympi              Zympi
# 83826          /organization/zymr-inc-         Zymr, Inc.
# 83827              /organization/zyncd              Zyncd
# 83838              /organization/zynga              Zynga
#
#                                    company_category_list       company_market  \
# 10                                            |Software|             Software
# 13                        |Entertainment|Games|Software|             Software
# 14                                 |Health and Wellness|  Health and Wellness
# 16                                         |Real Estate|          Real Estate
# 25                                         |Curated Web|          Curated Web
# ...                                                  ...                  ...
# 83816                                    |Biotechnology|        Biotechnology
# 83825                    |Networking|Web Hosting|Mobile|          Web Hosting
# 83826  |Open Source|Network Security|Networking|Virtu...              Testing
# 83827               |Knowledge Management|Crowdsourcing|        Crowdsourcing
# 83838  |Technology|Facebook Applications|Networking|G...           Technology
#
#       company_country_code company_state_code         company_region  \
# 10                     USA                 IL  Springfield, Illinois
# 13                     USA                 NC             NC - Other
# 14                     USA                 CA            Los Angeles
# 16                     USA                 FL                Orlando
# 25                     DEU                NaN                 Berlin
# ...                    ...                ...                    ...
# 83816                  USA                 CA            SF Bay Area
# 83825                  NaN                NaN                    NaN
# 83826                  USA                 CA            SF Bay Area
# 83827                  GBR                NaN                 London
# 83838                  USA                 CA            SF Bay Area
#
#             company_city                          funding_round_permalink  \
# 10             Champaign  /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830
# 13     Connellys Springs  /funding-round/e97a192e13ea0ee3c4f71136b4f3ec16
# 14           Los Angeles  /funding-round/5274aacc211163fc7c86539ce94bbacc
# 16               Orlando  /funding-round/83b8f4c7d37ecef5e001a5e953bf461a
# 25                Berlin  /funding-round/3407d447c84490721358e5c0eb23e3a1
# ...                  ...                                              ...
# 83816      San Francisco  /funding-round/6b08eaf89f9a6211f1c83494c2bf8e82
# 83825                NaN  /funding-round/4aaf79fabd66416d679c9830c01f31d1
# 83826        Santa Clara  /funding-round/9048d1a80edeae803ed1790c9f473eec
# 83827             London  /funding-round/5a0d321abcfef61a8bae383176ac46e7
# 83838      San Francisco  /funding-round/d27f10a20b15b4ef3d9961d54eabf6b1
#
#         funding_round_type funding_round_code   funded_at funded_month  \
# 10                 venture                NaN  2014-07-24      2014-07
# 13     equity_crowdfunding                NaN  2013-04-21      2013-04
# 14             undisclosed                NaN  2010-08-19      2010-08
# 16     equity_crowdfunding                NaN  2014-01-22      2014-01
# 25                 venture                  B  2011-09-16      2011-09
# ...                    ...                ...         ...          ...
# 83816                 seed                NaN  2014-01-01      2014-01
# 83825  equity_crowdfunding                NaN  2011-11-22      2011-11
# 83826                angel                NaN  2012-12-12      2012-12
# 83827                 seed                NaN  2014-02-01      2014-02
# 83838                angel                NaN  2007-01-01      2007-01
#
#        funded_quarter   funded_year   raised_amount_usd
# 10            2014-Q3        2014.0                  NaN
# 13            2013-Q2        2013.0                  NaN
# 14            2010-Q3        2010.0                  NaN
# 16            2014-Q1        2014.0                  NaN
# 25            2011-Q3        2011.0                  NaN
# ...                ...          ...                  ...
# 83816         2014-Q1        2014.0                  NaN
# 83825         2011-Q4        2011.0                  NaN
# 83826         2012-Q4        2012.0                  NaN
# 83827         2014-Q1        2014.0                  NaN
# 83838         2007-Q1        2007.0                  NaN
#
# [12955 rows x 16 columns]

# %% [markdown]
# #Investments Analysis and Preprocessing

# %%
investments = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CIS 550/investments.csv')
investments['raised_amount_usd'] = investments['raised_amount_usd'].apply(lambda x: set_to_floats(x))
investments
# Out:
#                           company_permalink           company_name  \
# 0              /organization/test-company-3           test company
# 1       /organization/andrewburnett-com-ltd  AndrewBurnett.com Ltd
# 2                    /organization/abo-data               ABO Data
# 3                    /organization/abo-data               ABO Data
# 4                        /organization/ikro                   Ikro
# ...                                     ...                    ...
# 114501               /organization/helpling               Helpling
# 114502                /organization/appknox                Appknox
# 114503                  /organization/strap                  Strap
# 114504                  /organization/strap                  Strap
# 114505            /organization/vonjour-com                Vonjour
#
#                                     company_category_list  \
# 0                                                     NaN
# 1       |Internet|SEO|Services|Public Relations|Social...
# 2                                   |Enterprise Software|
# 3                                   |Enterprise Software|
# 4                                                     NaN
# ...                                                   ...
# 114501                                        |Consumers|
# 114502                      |Mobile Security|SaaS|Mobile|
# 114503                                             |Apps|
# 114504                                             |Apps|
# 114505                              |Enterprise Software|
#
#              company_market company_country_code company_state_code  \
# 0                       NaN                  ARE                NaN
# 1                  Internet                  GBR                NaN
# 2       Enterprise Software                  USA                 TX
# 3       Enterprise Software                  USA                 TX
# 4                       NaN                  BRA                NaN
# ...                     ...                  ...                ...
# 114501            Consumers                  DEU                NaN
# 114502      Mobile Security                  SGP                NaN
# 114503                 Apps                  USA                 OH
# 114504                 Apps                  USA                 OH
# 114505  Enterprise Software                  NaN                NaN
#
#        company_region company_city  \
# 0               Dubai        Dubai
# 1           Edinburgh    Edinburgh
# 2          TX - Other        Italy
# 3          TX - Other        Italy
# 4         BRA - Other       Canoas
# ...               ...          ...
# 114501         Berlin       Berlin
# 114502      Singapore    Singapore
# 114503     Cincinnati   Cincinnati
# 114504     Cincinnati   Cincinnati
# 114505            NaN          NaN
#
#                                   investor_permalink  \
# 0                           /person/jamessss-bondddd
# 1                                 /organization/ekaf
# 2                            /person/antonio-murroni
# 3                            /person/filippo-murroni
# 4       /organization/crp-companhia-de-participacoes
# ...                                              ...
# 114501                       /person/lukasz-gadowski
# 114502                         /person/rajan-anandan
# 114503                         /person/trevor-wright
# 114504                             /person/wendy-lea
# 114505                   /organization/kima-ventures
#
#                            investor_name  ... investor_region investor_city  \
# 0                       jamessss bondddd  ...             NaN           NaN
# 1                                   Ekaf  ...             NaN           NaN
# 2                        ANTONIO MURRONI  ...             NaN           NaN
# 3                        FILIPPO Murroni  ...             NaN           NaN
# 4       CRP Companhia de Participações  ...             NaN           NaN
# ...                                  ...  ...             ...           ...
# 114501                   Lukasz Gadowski  ...             NaN           NaN
# 114502                     Rajan Anandan  ...             NaN           NaN
# 114503                     Trevor Wright  ...             NaN           NaN
# 114504                         Wendy Lea  ...             NaN           NaN
# 114505                     Kima Ventures  ...           Paris         Paris
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/c308019016ead7afb2a1d117018eb6fc               seed
# 1       /funding-round/14fe2864e02d0f15ddc3ec8eacdc8e1b               seed
# 2       /funding-round/809e211b969c3f66440fc15ffcd29385               seed
# 3       /funding-round/809e211b969c3f66440fc15ffcd29385               seed
# 4       /funding-round/46c353a8249170cc4b6ab89a522fefdc            venture
# ...                                                 ...                ...
# 114501  /funding-round/681af1b330a13043b17aeac45d841b88            venture
# 114502  /funding-round/bfb0b5859be2431f35882bc03370dd67            venture
# 114503  /funding-round/375e6c61fec5b3854ecbe5732dfdcabe               seed
# 114504  /funding-round/375e6c61fec5b3854ecbe5732dfdcabe               seed
# 114505  /funding-round/3b06e2822fbd630d8baa1d696c6478fa               seed
#
#        funding_round_code   funded_at funded_month funded_quarter funded_year  \
# 0                     NaN  1921-09-01      1921-09        1921-Q3        1921
# 1                     NaN  1974-01-01      1974-01        1974-Q1        1974
# 2                     NaN  1979-01-01      1979-01        1979-Q1        1979
# 3                     NaN  1979-01-01      1979-01        1979-Q1        1979
# 4                       A  1982-06-01      1982-06        1982-Q2        1982
# ...                   ...         ...          ...            ...         ...
# 114501                  A  2014-12-02      2014-12        2014-Q4        2014
# 114502                NaN  2014-12-02      2014-12        2014-Q4        2014
# 114503                NaN  2014-12-02      2014-12        2014-Q4        2014
# 114504                NaN  2014-12-02      2014-12        2014-Q4        2014
# 114505                NaN  2014-12-20      2014-12        2014-Q4        2014
#
#        raised_amount_usd
# 0                 1000.0
# 1                    NaN
# 2              1000000.0
# 3              1000000.0
# 4               724000.0
# ...                  ...
# 114501        17000000.0
# 114502               NaN
# 114503         1200000.0
# 114504         1200000.0
# 114505               NaN
#
# [114506 rows x 24 columns]

# %% [markdown]
# ##Summary Stats

# %%
investments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114506 entries, 0 to 114505
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   company_permalink        114506 non-null  object
#  1   company_name             114505 non-null  object
#  2   company_category_list    111242 non-null  object
#  3   company_market           111240 non-null  object
#  4   company_country_code     107147 non-null  object
#  5   company_state_code       79158 non-null   object
#  6   company_region           107147 non-null  object
#  7   company_city             105801 non-null  object
#  8   investor_permalink       114440 non-null  object
#  9   investor_name            114440 non-null  object
#  10  investor_category_list   30507 non-null   object
#  11  investor_market          30455 non-null   object
#  12  investor_country_code    86521 non-null   object
#  13  investor_state_code      62274 non-null   object
#  14  investor_region          86521 non-null   object
#  15  investor_city            86007 non-null   object
#  16  funding_round_permalink  114506 non-null  object
#  17  funding_round_type       114506 non-null  object
#  18  funding_round_code       54669 non-null   object
#  19  funded_at                114506 non-null  object
#  20  funded_month             114506 non-null  object
#  21  funded_quarter           114506 non-null  object
#  22  funded_year              114506 non-null  int64
#  23  raised_amount_usd        101091 non-null  float64
# dtypes: float64(1), int64(1), object(22)
# memory usage: 21.0+ MB

# %%
investments.describe()
# Out:
#          funded_year  raised_amount_usd
# count  114506.000000       1.010910e+05
# mean     2010.686174       1.267140e+07
# std         3.065592       4.725429e+07
# min      1921.000000       1.400000e+01
# 25%      2009.000000       1.200000e+06
# 50%      2012.000000       4.600000e+06
# 75%      2013.000000       1.300000e+07
# max      2014.000000       5.800000e+09

# %%
investments.nunique()
# Out:
# company_permalink          32335
# company_name               32284
# company_category_list      11874
# company_market               712
# company_country_code         101
# company_state_code            61
# company_region               965
# company_city                2901
# investor_permalink         22276
# investor_name              22037
# investor_category_list      1160
# investor_market              272
# investor_country_code         85
# investor_state_code           59
# investor_region              589
# investor_city               1381
# funding_round_permalink    50280
# funding_round_type            13
# funding_round_code             8
# funded_at                   3923
# funded_month                 300
# funded_quarter               123
# funded_year                   36
# raised_amount_usd           7452
# dtype: int64

# %% [markdown]
# ##Analysis

# %%
column_names = ['company_permalink', 'company_name', 'company_category_list', 'company_market', 'company_country_code', 'company_state_code', 'company_region', 'company_city', 'investor_permalink', 'investor_name', 'investor_category_list', 'investor_market', 'investor_country_code','investor_state_code', 'investor_region', 'investor_city', 'funding_round_permalink', 'funding_round_type', 'funding_round_code', 'funded_at', 'funded_month', 'funded_quarter', 'funded_year', 'raised_amount_usd']

for col in column_names:
  print('\n\n')
  print("==========================================================================")
  print(col.upper())
  print("VALUE COUNTS")
  print(investments[col].value_counts())
  print("\n")

  print("DUPLICATE COUNTS")
  print(investments.duplicated(subset=col, keep='first').sum())
  print("\n")

  print("NULL COUNTS AND PERCENTAGE")
  print(investments[col].isnull().sum())
  print(investments[col].isnull().sum()/len(investments)*100)
  print('\n')
  
  print("NULL ROWS")
  display(investments[investments[col].isnull()])
# Out:
# ==========================================================================
# COMPANY_PERMALINK
# VALUE COUNTS
# /organization/fab-com            60
# /organization/ecomom             59
# /organization/cardiodx           57
# /organization/practice-fusion    55
# /organization/path               53
#                                  ..
# /organization/reaqua-systems      1
# /organization/bindhq              1
# /organization/godigex             1
# /organization/dimers-lab          1
# /organization/vonjour-com         1
# Name: company_permalink, Length: 32335, dtype: int64
#
#
# DUPLICATE COUNTS
# 82171
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, investor_permalink, investor_name, investor_category_list, investor_market, investor_country_code, investor_state_code, investor_region, investor_city, funding_round_permalink, funding_round_type, funding_round_code, funded_at, funded_month, funded_quarter, funded_year, raised_amount_usd]
# Index: []
#
# [0 rows x 24 columns]
# ==========================================================================
# COMPANY_NAME
# VALUE COUNTS
# Fab                60
# ecomom             59
# CardioDx           57
# Practice Fusion    55
# Path               53
#                    ..
# Startlocal          1
# Game Cooks          1
# Yoink Games         1
# Zeto                1
# Vonjour             1
# Name: company_name, Length: 32284, dtype: int64
#
#
# DUPLICATE COUNTS
# 82221
#
#
# NULL COUNTS AND PERCENTAGE
# 1
# 0.0008733166820952613
#
#
# NULL ROWS
#               company_permalink company_name company_category_list  \
# 59891  /organization/tell-it-in          NaN            |Startups|
#
#       company_market company_country_code company_state_code company_region  \
# 59891       Startups                  NaN                NaN            NaN
#
#       company_city                investor_permalink       investor_name  ...  \
# 59891          NaN  /organization/portland-seed-fund  Portland Seed Fund  ...
#
#         investor_region investor_city  \
# 59891  Portland, Oregon      Portland
#
#                                funding_round_permalink funding_round_type  \
# 59891  /funding-round/9c987e616755a78c51a4aa67c27a2a93               seed
#
#       funding_round_code   funded_at funded_month funded_quarter funded_year  \
# 59891                NaN  2012-03-01      2012-03        2012-Q1        2012
#
#       raised_amount_usd
# 59891           25000.0
#
# [1 rows x 24 columns]
# ==========================================================================
# COMPANY_CATEGORY_LIST
# VALUE COUNTS
# |Biotechnology|                                                      7762
# |Software|                                                           7224
# |Mobile|                                                             2979
# |Enterprise Software|                                                2710
# |E-Commerce|                                                         2616
#                                                                      ...
# |Consumer Goods|Beauty|Health Care|                                     1
# |Security|Lighting|Semiconductors|Clean Technology|                     1
# |Discounts|Location Based Services|Mobile|Messaging|SMS|Software|       1
# |Hospitality|Travel|                                                    1
# |Services|Wireless|Telecommunications|                                  1
# Name: company_category_list, Length: 11874, dtype: int64
#
#
# DUPLICATE COUNTS
# 102631
#
#
# NULL COUNTS AND PERCENTAGE
# 3264
# 2.850505650358933
#
#
# NULL ROWS
#                       company_permalink       company_name  \
# 0          /organization/test-company-3       test company
# 4                    /organization/ikro               Ikro
# 5       /organization/laborat-rios-noli  Laboratórios Noli
# 6                /organization/indelsul           Indelsul
# 7                 /organization/polimax            Polimax
# ...                                 ...                ...
# 114438    /organization/ascendis-pharma    Ascendis Pharma
# 114439    /organization/ascendis-pharma    Ascendis Pharma
# 114479             /organization/xeltis             Xeltis
# 114480             /organization/xeltis             Xeltis
# 114499             /organization/xeltis             Xeltis
#
#        company_category_list company_market company_country_code  \
# 0                        NaN            NaN                  ARE
# 4                        NaN            NaN                  BRA
# 5                        NaN            NaN                  BRA
# 6                        NaN            NaN                  NaN
# 7                        NaN            NaN                  NaN
# ...                      ...            ...                  ...
# 114438                   NaN            NaN                  USA
# 114439                   NaN            NaN                  USA
# 114479                   NaN            NaN                  CHE
# 114480                   NaN            NaN                  CHE
# 114499                   NaN            NaN                  CHE
#
#        company_state_code company_region  company_city  \
# 0                     NaN          Dubai         Dubai
# 4                     NaN    BRA - Other        Canoas
# 5                     NaN   Porto Alegre  Porto Alegre
# 6                     NaN            NaN           NaN
# 7                     NaN            NaN           NaN
# ...                   ...            ...           ...
# 114438                 CA    SF Bay Area     Palo Alto
# 114439                 CA    SF Bay Area     Palo Alto
# 114479                NaN         Zurich        Zürich
# 114480                NaN         Zurich        Zürich
# 114499                NaN         Zurich        Zürich
#
#                                   investor_permalink  \
# 0                           /person/jamessss-bondddd
# 4       /organization/crp-companhia-de-participacoes
# 5       /organization/crp-companhia-de-participacoes
# 6       /organization/crp-companhia-de-participacoes
# 7       /organization/crp-companhia-de-participacoes
# ...                                              ...
# 114438                         /organization/venrock
# 114439                    /organization/vivo-capital
# 114479     /organization/kurma-life-science-partners
# 114480          /organization/life-sciences-partners
# 114499                     /organization/vi-partners
#
#                            investor_name  ... investor_region investor_city  \
# 0                       jamessss bondddd  ...             NaN           NaN
# 4       CRP Companhia de Participações  ...             NaN           NaN
# 5       CRP Companhia de Participações  ...             NaN           NaN
# 6       CRP Companhia de Participações  ...             NaN           NaN
# 7       CRP Companhia de Participações  ...             NaN           NaN
# ...                                  ...  ...             ...           ...
# 114438                           Venrock  ...     SF Bay Area     Palo Alto
# 114439                      Vivo Capital  ...             NaN           NaN
# 114479       Kurma Life Science Partners  ...             NaN           NaN
# 114480            Life Sciences Partners  ...       Amsterdam     Amsterdam
# 114499                       VI Partners  ...          Zurich           Zug
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/c308019016ead7afb2a1d117018eb6fc               seed
# 4       /funding-round/46c353a8249170cc4b6ab89a522fefdc            venture
# 5       /funding-round/5bdff09243b72f7fb325146259880e93            venture
# 6       /funding-round/48e8db0d90f95934831603622cb3f46a            venture
# 7       /funding-round/b046f5d59bc7a5bc86ddfb69c70adf77            venture
# ...                                                 ...                ...
# 114438  /funding-round/caf8476f16c2266ac347376454ec61f5            venture
# 114439  /funding-round/caf8476f16c2266ac347376454ec61f5            venture
# 114479  /funding-round/03dd9b7cfc4a45a1bd6903143423f207            venture
# 114480  /funding-round/03dd9b7cfc4a45a1bd6903143423f207            venture
# 114499  /funding-round/03dd9b7cfc4a45a1bd6903143423f207            venture
#
#        funding_round_code   funded_at funded_month funded_quarter funded_year  \
# 0                     NaN  1921-09-01      1921-09        1921-Q3        1921
# 4                       A  1982-06-01      1982-06        1982-Q2        1982
# 5                       A  1982-12-01      1982-12        1982-Q4        1982
# 6                       A  1982-12-01      1982-12        1982-Q4        1982
# 7                       A  1983-06-01      1983-06        1983-Q2        1983
# ...                   ...         ...          ...            ...         ...
# 114438                  D  2014-12-01      2014-12        2014-Q4        2014
# 114439                  D  2014-12-01      2014-12        2014-Q4        2014
# 114479                  B  2014-12-02      2014-12        2014-Q4        2014
# 114480                  B  2014-12-02      2014-12        2014-Q4        2014
# 114499                  B  2014-12-02      2014-12        2014-Q4        2014
#
#        raised_amount_usd
# 0                 1000.0
# 4               724000.0
# 5               155000.0
# 6               165000.0
# 7                94000.0
# ...                  ...
# 114438        60000000.0
# 114439        60000000.0
# 114479        34000000.0
# 114480        34000000.0
# 114499        34000000.0
#
# [3264 rows x 24 columns]
# ==========================================================================
# COMPANY_MARKET
# VALUE COUNTS
# Software               9906
# Biotechnology          8164
# Mobile                 5282
# E-Commerce             4292
# Enterprise Software    4128
#                        ...
# Direct Sales              1
# Minerals                  1
# Music Venues              1
# Sex                       1
# Civil Engineers           1
# Name: company_market, Length: 712, dtype: int64
#
#
# DUPLICATE COUNTS
# 113793
#
#
# NULL COUNTS AND PERCENTAGE
# 3266
# 2.8522522837231237
#
#
# NULL ROWS
#                       company_permalink       company_name  \
# 0          /organization/test-company-3       test company
# 4                    /organization/ikro               Ikro
# 5       /organization/laborat-rios-noli  Laboratórios Noli
# 6                /organization/indelsul           Indelsul
# 7                 /organization/polimax            Polimax
# ...                                 ...                ...
# 114438    /organization/ascendis-pharma    Ascendis Pharma
# 114439    /organization/ascendis-pharma    Ascendis Pharma
# 114479             /organization/xeltis             Xeltis
# 114480             /organization/xeltis             Xeltis
# 114499             /organization/xeltis             Xeltis
#
#        company_category_list company_market company_country_code  \
# 0                        NaN            NaN                  ARE
# 4                        NaN            NaN                  BRA
# 5                        NaN            NaN                  BRA
# 6                        NaN            NaN                  NaN
# 7                        NaN            NaN                  NaN
# ...                      ...            ...                  ...
# 114438                   NaN            NaN                  USA
# 114439                   NaN            NaN                  USA
# 114479                   NaN            NaN                  CHE
# 114480                   NaN            NaN                  CHE
# 114499                   NaN            NaN                  CHE
#
#        company_state_code company_region  company_city  \
# 0                     NaN          Dubai         Dubai
# 4                     NaN    BRA - Other        Canoas
# 5                     NaN   Porto Alegre  Porto Alegre
# 6                     NaN            NaN           NaN
# 7                     NaN            NaN           NaN
# ...                   ...            ...           ...
# 114438                 CA    SF Bay Area     Palo Alto
# 114439                 CA    SF Bay Area     Palo Alto
# 114479                NaN         Zurich        Zürich
# 114480                NaN         Zurich        Zürich
# 114499                NaN         Zurich        Zürich
#
#                                   investor_permalink  \
# 0                           /person/jamessss-bondddd
# 4       /organization/crp-companhia-de-participacoes
# 5       /organization/crp-companhia-de-participacoes
# 6       /organization/crp-companhia-de-participacoes
# 7       /organization/crp-companhia-de-participacoes
# ...                                              ...
# 114438                         /organization/venrock
# 114439                    /organization/vivo-capital
# 114479     /organization/kurma-life-science-partners
# 114480          /organization/life-sciences-partners
# 114499                     /organization/vi-partners
#
#                            investor_name  ... investor_region investor_city  \
# 0                       jamessss bondddd  ...             NaN           NaN
# 4       CRP Companhia de Participações  ...             NaN           NaN
# 5       CRP Companhia de Participações  ...             NaN           NaN
# 6       CRP Companhia de Participações  ...             NaN           NaN
# 7       CRP Companhia de Participações  ...             NaN           NaN
# ...                                  ...  ...             ...           ...
# 114438                           Venrock  ...     SF Bay Area     Palo Alto
# 114439                      Vivo Capital  ...             NaN           NaN
# 114479       Kurma Life Science Partners  ...             NaN           NaN
# 114480            Life Sciences Partners  ...       Amsterdam     Amsterdam
# 114499                       VI Partners  ...          Zurich           Zug
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/c308019016ead7afb2a1d117018eb6fc               seed
# 4       /funding-round/46c353a8249170cc4b6ab89a522fefdc            venture
# 5       /funding-round/5bdff09243b72f7fb325146259880e93            venture
# 6       /funding-round/48e8db0d90f95934831603622cb3f46a            venture
# 7       /funding-round/b046f5d59bc7a5bc86ddfb69c70adf77            venture
# ...                                                 ...                ...
# 114438  /funding-round/caf8476f16c2266ac347376454ec61f5            venture
# 114439  /funding-round/caf8476f16c2266ac347376454ec61f5            venture
# 114479  /funding-round/03dd9b7cfc4a45a1bd6903143423f207            venture
# 114480  /funding-round/03dd9b7cfc4a45a1bd6903143423f207            venture
# 114499  /funding-round/03dd9b7cfc4a45a1bd6903143423f207            venture
#
#        funding_round_code   funded_at funded_month funded_quarter funded_year  \
# 0                     NaN  1921-09-01      1921-09        1921-Q3        1921
# 4                       A  1982-06-01      1982-06        1982-Q2        1982
# 5                       A  1982-12-01      1982-12        1982-Q4        1982
# 6                       A  1982-12-01      1982-12        1982-Q4        1982
# 7                       A  1983-06-01      1983-06        1983-Q2        1983
# ...                   ...         ...          ...            ...         ...
# 114438                  D  2014-12-01      2014-12        2014-Q4        2014
# 114439                  D  2014-12-01      2014-12        2014-Q4        2014
# 114479                  B  2014-12-02      2014-12        2014-Q4        2014
# 114480                  B  2014-12-02      2014-12        2014-Q4        2014
# 114499                  B  2014-12-02      2014-12        2014-Q4        2014
#
#        raised_amount_usd
# 0                 1000.0
# 4               724000.0
# 5               155000.0
# 6               165000.0
# 7                94000.0
# ...                  ...
# 114438        60000000.0
# 114439        60000000.0
# 114479        34000000.0
# 114480        34000000.0
# 114499        34000000.0
#
# [3266 rows x 24 columns]
# ==========================================================================
# COMPANY_COUNTRY_CODE
# VALUE COUNTS
# USA    76523
# GBR     5933
# CHN     2846
# CAN     2667
# DEU     2488
#        ...
# LAO        1
# OMN        1
# MOZ        1
# ZWE        1
# BRN        1
# Name: company_country_code, Length: 101, dtype: int64
#
#
# DUPLICATE COUNTS
# 114404
#
#
# NULL COUNTS AND PERCENTAGE
# 7359
# 6.426737463539029
#
#
# NULL ROWS
#                                         company_permalink  \
# 6                                  /organization/indelsul
# 7                                   /organization/polimax
# 9                                 /organization/mixertech
# 16      /organization/medaphis-physician-services-corp...
# 21                                /organization/nhk-world
# ...                                                   ...
# 114409                             /organization/appintop
# 114422                  /organization/a-crowd-of-monsters
# 114429                  /organization/a-crowd-of-monsters
# 114437                  /organization/a-crowd-of-monsters
# 114505                          /organization/vonjour-com
#
#                                    company_name  company_category_list  \
# 6                                      Indelsul                    NaN
# 7                                       Polimax                    NaN
# 9                                     Mixertech                    NaN
# 16      Medaphis Physician Services Corporation          |Health Care|
# 21                                    NHK World                 |News|
# ...                                         ...                    ...
# 114409                                 AppInTop                    NaN
# 114422                      A Crowd of Monsters                |Games|
# 114429                      A Crowd of Monsters                |Games|
# 114437                      A Crowd of Monsters                |Games|
# 114505                                  Vonjour  |Enterprise Software|
#
#              company_market company_country_code company_state_code  \
# 6                       NaN                  NaN                NaN
# 7                       NaN                  NaN                NaN
# 9                       NaN                  NaN                NaN
# 16              Health Care                  NaN                NaN
# 21                     News                  NaN                NaN
# ...                     ...                  ...                ...
# 114409                  NaN                  NaN                NaN
# 114422                Games                  NaN                NaN
# 114429                Games                  NaN                NaN
# 114437                Games                  NaN                NaN
# 114505  Enterprise Software                  NaN                NaN
#
#        company_region company_city  \
# 6                 NaN          NaN
# 7                 NaN          NaN
# 9                 NaN          NaN
# 16                NaN          NaN
# 21                NaN          NaN
# ...               ...          ...
# 114409            NaN          NaN
# 114422            NaN          NaN
# 114429            NaN          NaN
# 114437            NaN          NaN
# 114505            NaN          NaN
#
#                                        investor_permalink  \
# 6            /organization/crp-companhia-de-participacoes
# 7            /organization/crp-companhia-de-participacoes
# 9            /organization/crp-companhia-de-participacoes
# 16                          /organization/summit-partners
# 21                       /organization/itochu-corporation
# ...                                                   ...
# 114409          /organization/run-capital-investment-fund
# 114422                        /organization/caixa-capital
# 114429  /organization/inveready-technology-investment-...
# 114437                      /organization/the-crowd-angel
# 114505                        /organization/kima-ventures
#
#                                 investor_name  ... investor_region  \
# 6            CRP Companhia de Participações  ...             NaN
# 7            CRP Companhia de Participações  ...             NaN
# 9            CRP Companhia de Participações  ...             NaN
# 16                            Summit Partners  ...          Boston
# 21                         ITOCHU Corporation  ...           Tokyo
# ...                                       ...  ...             ...
# 114409            Run Capital Investment Fund  ...             NaN
# 114422                     Caixa Capital Risc  ...       Barcelona
# 114429  Inveready Technology Investment Group  ...       Barcelona
# 114437                        The Crowd Angel  ...       Barcelona
# 114505                          Kima Ventures  ...           Paris
#
#        investor_city                          funding_round_permalink  \
# 6                NaN  /funding-round/48e8db0d90f95934831603622cb3f46a
# 7                NaN  /funding-round/b046f5d59bc7a5bc86ddfb69c70adf77
# 9                NaN  /funding-round/4316813c5da6e06f2a15fa25c7946a73
# 16            Boston  /funding-round/679e8e54c0e43298f7692bd8e3caed1e
# 21             Tokyo  /funding-round/bdae954da8883f9b4dab3dce9a62c5ed
# ...              ...                                              ...
# 114409           NaN  /funding-round/00fda78c1c7c938c4ea3a2fb262cc812
# 114422     Barcelona  /funding-round/56ef745ff01198e5e9d4ae18b808ce13
# 114429     Barcelona  /funding-round/56ef745ff01198e5e9d4ae18b808ce13
# 114437     Barcelona  /funding-round/56ef745ff01198e5e9d4ae18b808ce13
# 114505         Paris  /funding-round/3b06e2822fbd630d8baa1d696c6478fa
#
#        funding_round_type funding_round_code   funded_at funded_month  \
# 6                 venture                  A  1982-12-01      1982-12
# 7                 venture                  A  1983-06-01      1983-06
# 9                 venture                  A  1984-05-01      1984-05
# 16            undisclosed                NaN  1986-05-30      1986-05
# 21                venture                  D  1987-06-16      1987-06
# ...                   ...                ...         ...          ...
# 114409            venture                  A  2014-11-28      2014-11
# 114422            venture                NaN  2014-12-01      2014-12
# 114429            venture                NaN  2014-12-01      2014-12
# 114437            venture                NaN  2014-12-01      2014-12
# 114505               seed                NaN  2014-12-20      2014-12
#
#        funded_quarter funded_year raised_amount_usd
# 6             1982-Q4        1982          165000.0
# 7             1983-Q2        1983           94000.0
# 9             1984-Q2        1984               NaN
# 16            1986-Q2        1986               NaN
# 21            1987-Q2        1987               NaN
# ...               ...         ...               ...
# 114409        2014-Q4        2014         6000000.0
# 114422        2014-Q4        2014          560248.0
# 114429        2014-Q4        2014          560248.0
# 114437        2014-Q4        2014          560248.0
# 114505        2014-Q4        2014               NaN
#
# [7359 rows x 24 columns]
# ==========================================================================
# COMPANY_STATE_CODE
# VALUE COUNTS
# CA    39101
# NY     8934
# MA     6540
# WA     2481
# TX     2436
#       ...
# PE        5
# SK        4
# SD        4
# AK        2
# WY        1
# Name: company_state_code, Length: 61, dtype: int64
#
#
# DUPLICATE COUNTS
# 114444
#
#
# NULL COUNTS AND PERCENTAGE
# 35348
# 30.869998078703297
#
#
# NULL ROWS
#                           company_permalink           company_name  \
# 0              /organization/test-company-3           test company
# 1       /organization/andrewburnett-com-ltd  AndrewBurnett.com Ltd
# 4                        /organization/ikro                   Ikro
# 5           /organization/laborat-rios-noli      Laboratórios Noli
# 6                    /organization/indelsul               Indelsul
# ...                                     ...                    ...
# 114496                 /organization/veniam                 Veniam
# 114499                 /organization/xeltis                 Xeltis
# 114501               /organization/helpling               Helpling
# 114502                /organization/appknox                Appknox
# 114505            /organization/vonjour-com                Vonjour
#
#                                     company_category_list  \
# 0                                                     NaN
# 1       |Internet|SEO|Services|Public Relations|Social...
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# ...                                                   ...
# 114496           |Communications Infrastructure|Wireless|
# 114499                                                NaN
# 114501                                        |Consumers|
# 114502                      |Mobile Security|SaaS|Mobile|
# 114505                              |Enterprise Software|
#
#              company_market company_country_code company_state_code  \
# 0                       NaN                  ARE                NaN
# 1                  Internet                  GBR                NaN
# 4                       NaN                  BRA                NaN
# 5                       NaN                  BRA                NaN
# 6                       NaN                  NaN                NaN
# ...                     ...                  ...                ...
# 114496             Wireless                  PRT                NaN
# 114499                  NaN                  CHE                NaN
# 114501            Consumers                  DEU                NaN
# 114502      Mobile Security                  SGP                NaN
# 114505  Enterprise Software                  NaN                NaN
#
#        company_region  company_city  \
# 0               Dubai         Dubai
# 1           Edinburgh     Edinburgh
# 4         BRA - Other        Canoas
# 5        Porto Alegre  Porto Alegre
# 6                 NaN           NaN
# ...               ...           ...
# 114496          Porto         Porto
# 114499         Zurich        Zürich
# 114501         Berlin        Berlin
# 114502      Singapore     Singapore
# 114505            NaN           NaN
#
#                                   investor_permalink  \
# 0                           /person/jamessss-bondddd
# 1                                 /organization/ekaf
# 4       /organization/crp-companhia-de-participacoes
# 5       /organization/crp-companhia-de-participacoes
# 6       /organization/crp-companhia-de-participacoes
# ...                                              ...
# 114496           /organization/union-square-ventures
# 114499                     /organization/vi-partners
# 114501                       /person/lukasz-gadowski
# 114502                         /person/rajan-anandan
# 114505                   /organization/kima-ventures
#
#                            investor_name  ... investor_region investor_city  \
# 0                       jamessss bondddd  ...             NaN           NaN
# 1                                   Ekaf  ...             NaN           NaN
# 4       CRP Companhia de Participações  ...             NaN           NaN
# 5       CRP Companhia de Participações  ...             NaN           NaN
# 6       CRP Companhia de Participações  ...             NaN           NaN
# ...                                  ...  ...             ...           ...
# 114496             Union Square Ventures  ...   New York City      New York
# 114499                       VI Partners  ...          Zurich           Zug
# 114501                   Lukasz Gadowski  ...             NaN           NaN
# 114502                     Rajan Anandan  ...             NaN           NaN
# 114505                     Kima Ventures  ...           Paris         Paris
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/c308019016ead7afb2a1d117018eb6fc               seed
# 1       /funding-round/14fe2864e02d0f15ddc3ec8eacdc8e1b               seed
# 4       /funding-round/46c353a8249170cc4b6ab89a522fefdc            venture
# 5       /funding-round/5bdff09243b72f7fb325146259880e93            venture
# 6       /funding-round/48e8db0d90f95934831603622cb3f46a            venture
# ...                                                 ...                ...
# 114496  /funding-round/e5e418907f0047bdc23e4b53440abc7e            venture
# 114499  /funding-round/03dd9b7cfc4a45a1bd6903143423f207            venture
# 114501  /funding-round/681af1b330a13043b17aeac45d841b88            venture
# 114502  /funding-round/bfb0b5859be2431f35882bc03370dd67            venture
# 114505  /funding-round/3b06e2822fbd630d8baa1d696c6478fa               seed
#
#        funding_round_code   funded_at funded_month funded_quarter funded_year  \
# 0                     NaN  1921-09-01      1921-09        1921-Q3        1921
# 1                     NaN  1974-01-01      1974-01        1974-Q1        1974
# 4                       A  1982-06-01      1982-06        1982-Q2        1982
# 5                       A  1982-12-01      1982-12        1982-Q4        1982
# 6                       A  1982-12-01      1982-12        1982-Q4        1982
# ...                   ...         ...          ...            ...         ...
# 114496                  A  2014-12-02      2014-12        2014-Q4        2014
# 114499                  B  2014-12-02      2014-12        2014-Q4        2014
# 114501                  A  2014-12-02      2014-12        2014-Q4        2014
# 114502                NaN  2014-12-02      2014-12        2014-Q4        2014
# 114505                NaN  2014-12-20      2014-12        2014-Q4        2014
#
#        raised_amount_usd
# 0                 1000.0
# 1                    NaN
# 4               724000.0
# 5               155000.0
# 6               165000.0
# ...                  ...
# 114496         4900000.0
# 114499        34000000.0
# 114501        17000000.0
# 114502               NaN
# 114505               NaN
#
# [35348 rows x 24 columns]
# ==========================================================================
# COMPANY_REGION
# VALUE COUNTS
# SF Bay Area      32120
# New York City     8604
# Boston            6286
# London            3860
# Los Angeles       3674
#                  ...
# Gilching             1
# Tarragona            1
# Borehamwood          1
# Belgaum              1
# Kathmandu            1
# Name: company_region, Length: 965, dtype: int64
#
#
# DUPLICATE COUNTS
# 113540
#
#
# NULL COUNTS AND PERCENTAGE
# 7359
# 6.426737463539029
#
#
# NULL ROWS
#                                         company_permalink  \
# 6                                  /organization/indelsul
# 7                                   /organization/polimax
# 9                                 /organization/mixertech
# 16      /organization/medaphis-physician-services-corp...
# 21                                /organization/nhk-world
# ...                                                   ...
# 114409                             /organization/appintop
# 114422                  /organization/a-crowd-of-monsters
# 114429                  /organization/a-crowd-of-monsters
# 114437                  /organization/a-crowd-of-monsters
# 114505                          /organization/vonjour-com
#
#                                    company_name  company_category_list  \
# 6                                      Indelsul                    NaN
# 7                                       Polimax                    NaN
# 9                                     Mixertech                    NaN
# 16      Medaphis Physician Services Corporation          |Health Care|
# 21                                    NHK World                 |News|
# ...                                         ...                    ...
# 114409                                 AppInTop                    NaN
# 114422                      A Crowd of Monsters                |Games|
# 114429                      A Crowd of Monsters                |Games|
# 114437                      A Crowd of Monsters                |Games|
# 114505                                  Vonjour  |Enterprise Software|
#
#              company_market company_country_code company_state_code  \
# 6                       NaN                  NaN                NaN
# 7                       NaN                  NaN                NaN
# 9                       NaN                  NaN                NaN
# 16              Health Care                  NaN                NaN
# 21                     News                  NaN                NaN
# ...                     ...                  ...                ...
# 114409                  NaN                  NaN                NaN
# 114422                Games                  NaN                NaN
# 114429                Games                  NaN                NaN
# 114437                Games                  NaN                NaN
# 114505  Enterprise Software                  NaN                NaN
#
#        company_region company_city  \
# 6                 NaN          NaN
# 7                 NaN          NaN
# 9                 NaN          NaN
# 16                NaN          NaN
# 21                NaN          NaN
# ...               ...          ...
# 114409            NaN          NaN
# 114422            NaN          NaN
# 114429            NaN          NaN
# 114437            NaN          NaN
# 114505            NaN          NaN
#
#                                        investor_permalink  \
# 6            /organization/crp-companhia-de-participacoes
# 7            /organization/crp-companhia-de-participacoes
# 9            /organization/crp-companhia-de-participacoes
# 16                          /organization/summit-partners
# 21                       /organization/itochu-corporation
# ...                                                   ...
# 114409          /organization/run-capital-investment-fund
# 114422                        /organization/caixa-capital
# 114429  /organization/inveready-technology-investment-...
# 114437                      /organization/the-crowd-angel
# 114505                        /organization/kima-ventures
#
#                                 investor_name  ... investor_region  \
# 6            CRP Companhia de Participações  ...             NaN
# 7            CRP Companhia de Participações  ...             NaN
# 9            CRP Companhia de Participações  ...             NaN
# 16                            Summit Partners  ...          Boston
# 21                         ITOCHU Corporation  ...           Tokyo
# ...                                       ...  ...             ...
# 114409            Run Capital Investment Fund  ...             NaN
# 114422                     Caixa Capital Risc  ...       Barcelona
# 114429  Inveready Technology Investment Group  ...       Barcelona
# 114437                        The Crowd Angel  ...       Barcelona
# 114505                          Kima Ventures  ...           Paris
#
#        investor_city                          funding_round_permalink  \
# 6                NaN  /funding-round/48e8db0d90f95934831603622cb3f46a
# 7                NaN  /funding-round/b046f5d59bc7a5bc86ddfb69c70adf77
# 9                NaN  /funding-round/4316813c5da6e06f2a15fa25c7946a73
# 16            Boston  /funding-round/679e8e54c0e43298f7692bd8e3caed1e
# 21             Tokyo  /funding-round/bdae954da8883f9b4dab3dce9a62c5ed
# ...              ...                                              ...
# 114409           NaN  /funding-round/00fda78c1c7c938c4ea3a2fb262cc812
# 114422     Barcelona  /funding-round/56ef745ff01198e5e9d4ae18b808ce13
# 114429     Barcelona  /funding-round/56ef745ff01198e5e9d4ae18b808ce13
# 114437     Barcelona  /funding-round/56ef745ff01198e5e9d4ae18b808ce13
# 114505         Paris  /funding-round/3b06e2822fbd630d8baa1d696c6478fa
#
#        funding_round_type funding_round_code   funded_at funded_month  \
# 6                 venture                  A  1982-12-01      1982-12
# 7                 venture                  A  1983-06-01      1983-06
# 9                 venture                  A  1984-05-01      1984-05
# 16            undisclosed                NaN  1986-05-30      1986-05
# 21                venture                  D  1987-06-16      1987-06
# ...                   ...                ...         ...          ...
# 114409            venture                  A  2014-11-28      2014-11
# 114422            venture                NaN  2014-12-01      2014-12
# 114429            venture                NaN  2014-12-01      2014-12
# 114437            venture                NaN  2014-12-01      2014-12
# 114505               seed                NaN  2014-12-20      2014-12
#
#        funded_quarter funded_year raised_amount_usd
# 6             1982-Q4        1982          165000.0
# 7             1983-Q2        1983           94000.0
# 9             1984-Q2        1984               NaN
# 16            1986-Q2        1986               NaN
# 21            1987-Q2        1987               NaN
# ...               ...         ...               ...
# 114409        2014-Q4        2014         6000000.0
# 114422        2014-Q4        2014          560248.0
# 114429        2014-Q4        2014          560248.0
# 114437        2014-Q4        2014          560248.0
# 114505        2014-Q4        2014               NaN
#
# [7359 rows x 24 columns]
# ==========================================================================
# COMPANY_CITY
# VALUE COUNTS
# San Francisco         14287
# New York               8140
# London                 2861
# Mountain View          2601
# Palo Alto              2520
#                       ...
# Cuautitlán Izcalli        1
# Scarborough               1
# Aschheim                  1
# Mapleton                  1
# Asbury Park               1
# Name: company_city, Length: 2901, dtype: int64
#
#
# DUPLICATE COUNTS
# 111604
#
#
# NULL COUNTS AND PERCENTAGE
# 8705
# 7.60222171763925
#
#
# NULL ROWS
#                                         company_permalink  \
# 6                                  /organization/indelsul
# 7                                   /organization/polimax
# 9                                 /organization/mixertech
# 12                               /organization/curtume-er
# 16      /organization/medaphis-physician-services-corp...
# ...                                                   ...
# 114422                  /organization/a-crowd-of-monsters
# 114429                  /organization/a-crowd-of-monsters
# 114430                               /organization/grid4c
# 114437                  /organization/a-crowd-of-monsters
# 114505                          /organization/vonjour-com
#
#                                    company_name  company_category_list  \
# 6                                      Indelsul                    NaN
# 7                                       Polimax                    NaN
# 9                                     Mixertech                    NaN
# 12                                  Curtume Erê                    NaN
# 16      Medaphis Physician Services Corporation          |Health Care|
# ...                                         ...                    ...
# 114422                      A Crowd of Monsters                |Games|
# 114429                      A Crowd of Monsters                |Games|
# 114430                                   Grid4C                    NaN
# 114437                      A Crowd of Monsters                |Games|
# 114505                                  Vonjour  |Enterprise Software|
#
#              company_market company_country_code company_state_code  \
# 6                       NaN                  NaN                NaN
# 7                       NaN                  NaN                NaN
# 9                       NaN                  NaN                NaN
# 12                      NaN                  BRA                NaN
# 16              Health Care                  NaN                NaN
# ...                     ...                  ...                ...
# 114422                Games                  NaN                NaN
# 114429                Games                  NaN                NaN
# 114430                  NaN                  ISR                NaN
# 114437                Games                  NaN                NaN
# 114505  Enterprise Software                  NaN                NaN
#
#        company_region company_city  \
# 6                 NaN          NaN
# 7                 NaN          NaN
# 9                 NaN          NaN
# 12        BRA - Other          NaN
# 16                NaN          NaN
# ...               ...          ...
# 114422            NaN          NaN
# 114429            NaN          NaN
# 114430    ISR - Other          NaN
# 114437            NaN          NaN
# 114505            NaN          NaN
#
#                                        investor_permalink  \
# 6            /organization/crp-companhia-de-participacoes
# 7            /organization/crp-companhia-de-participacoes
# 9            /organization/crp-companhia-de-participacoes
# 12           /organization/crp-companhia-de-participacoes
# 16                          /organization/summit-partners
# ...                                                   ...
# 114422                        /organization/caixa-capital
# 114429  /organization/inveready-technology-investment-...
# 114430            /organization/israel-cleantech-ventures
# 114437                      /organization/the-crowd-angel
# 114505                        /organization/kima-ventures
#
#                                 investor_name  ... investor_region  \
# 6            CRP Companhia de Participações  ...             NaN
# 7            CRP Companhia de Participações  ...             NaN
# 9            CRP Companhia de Participações  ...             NaN
# 12           CRP Companhia de Participações  ...             NaN
# 16                            Summit Partners  ...          Boston
# ...                                       ...  ...             ...
# 114422                     Caixa Capital Risc  ...       Barcelona
# 114429  Inveready Technology Investment Group  ...       Barcelona
# 114430              Israel Cleantech Ventures  ...        Tel Aviv
# 114437                        The Crowd Angel  ...       Barcelona
# 114505                          Kima Ventures  ...           Paris
#
#          investor_city                          funding_round_permalink  \
# 6                  NaN  /funding-round/48e8db0d90f95934831603622cb3f46a
# 7                  NaN  /funding-round/b046f5d59bc7a5bc86ddfb69c70adf77
# 9                  NaN  /funding-round/4316813c5da6e06f2a15fa25c7946a73
# 12                 NaN  /funding-round/180c9ab38e64d3abd4bfadd291519475
# 16              Boston  /funding-round/679e8e54c0e43298f7692bd8e3caed1e
# ...                ...                                              ...
# 114422       Barcelona  /funding-round/56ef745ff01198e5e9d4ae18b808ce13
# 114429       Barcelona  /funding-round/56ef745ff01198e5e9d4ae18b808ce13
# 114430  Ramat Hasharon  /funding-round/5fcdc713477ba78741e770b3118f54c6
# 114437       Barcelona  /funding-round/56ef745ff01198e5e9d4ae18b808ce13
# 114505           Paris  /funding-round/3b06e2822fbd630d8baa1d696c6478fa
#
#        funding_round_type funding_round_code   funded_at funded_month  \
# 6                 venture                  A  1982-12-01      1982-12
# 7                 venture                  A  1983-06-01      1983-06
# 9                 venture                  A  1984-05-01      1984-05
# 12                venture                  A  1985-06-01      1985-06
# 16            undisclosed                NaN  1986-05-30      1986-05
# ...                   ...                ...         ...          ...
# 114422            venture                NaN  2014-12-01      2014-12
# 114429            venture                NaN  2014-12-01      2014-12
# 114430            venture                NaN  2014-12-01      2014-12
# 114437            venture                NaN  2014-12-01      2014-12
# 114505               seed                NaN  2014-12-20      2014-12
#
#        funded_quarter funded_year raised_amount_usd
# 6             1982-Q4        1982          165000.0
# 7             1983-Q2        1983           94000.0
# 9             1984-Q2        1984               NaN
# 12            1985-Q2        1985          169000.0
# 16            1986-Q2        1986               NaN
# ...               ...         ...               ...
# 114422        2014-Q4        2014          560248.0
# 114429        2014-Q4        2014          560248.0
# 114430        2014-Q4        2014         1500000.0
# 114437        2014-Q4        2014          560248.0
# 114505        2014-Q4        2014               NaN
#
# [8705 rows x 24 columns]
# ==========================================================================
# INVESTOR_PERMALINK
# VALUE COUNTS
# /organization/sequoia-capital    776
# /organization/start-up-chile     702
# /organization/500-startups       694
# /organization/intel-capital      674
# /organization/y-combinator       624
#                                 ...
# /organization/match                1
# /person/jonas-brandon              1
# /person/matt-wyndowe               1
# /organization/ern-capital          1
# /person/trevor-wright              1
# Name: investor_permalink, Length: 22276, dtype: int64
#
#
# DUPLICATE COUNTS
# 92229
#
#
# NULL COUNTS AND PERCENTAGE
# 66
# 0.05763890101828725
#
#
# NULL ROWS
#                                 company_permalink  \
# 628          /organization/goldpocket-interactive
# 12727                         /organization/bmeye
# 40424              /organization/moon-express-inc
# 43781                        /organization/koudai
# 45072                  /organization/unbooked-ltd
# ...                                           ...
# 113281                        /organization/emaze
# 113282               /organization/social-reality
# 113283  /organization/visual-software-systems-ltd
# 113328                     /organization/nanolive
# 113632               /organization/healthcare-com
#
#                         company_name  \
# 628           Goldpocket Interactive
# 12727                          BMEYE
# 40424             Moon Express, Inc.
# 43781                         Koudai
# 45072                   Unbooked Ltd
# ...                              ...
# 113281                         emaze
# 113282                Social Reality
# 113283  Visual Software Systems Ltd.
# 113328                      Nanolive
# 113632                HealthCare.com
#
#                                     company_category_list  \
# 628                                 |Television|Software|
# 12727                                       |Health Care|
# 40424                                      |Space Travel|
# 43781                                        |E-Commerce|
# ...
# 1                  Internet                  GBR                NaN
# 2       Enterprise Software                  USA                 TX
# 3       Enterprise Software                  USA                 TX
# 8                  Hardware                  USA                 NC
# ...                     ...                  ...                ...
# 114500                 Apps                  USA                 OH
# 114502      Mobile Security                  SGP                NaN
# 114503                 Apps                  USA                 OH
# 114504                 Apps                  USA                 OH
# 114505  Enterprise Software                  NaN                NaN
#
#        company_region company_city                         investor_permalink  \
# 0               Dubai        Dubai                   /person/jamessss-bondddd
# 1           Edinburgh    Edinburgh                         /organization/ekaf
# 2          TX - Other        Italy                    /person/antonio-murroni
# 3          TX - Other        Italy                    /person/filippo-murroni
# 8             Raleigh  Morrisville  /organization/chinese-academy-of-sciences
# ...               ...          ...                                        ...
# 114500     Cincinnati   Cincinnati             /organization/vine-st-ventures
# 114502      Singapore    Singapore                      /person/rajan-anandan
# 114503     Cincinnati   Cincinnati                      /person/trevor-wright
# 114504     Cincinnati   Cincinnati                          /person/wendy-lea
# 114505            NaN          NaN                /organization/kima-ventures
#
#                       investor_name  ... investor_region investor_city  \
# 0                  jamessss bondddd  ...             NaN           NaN
# 1                              Ekaf  ...             NaN           NaN
# 2                   ANTONIO MURRONI  ...             NaN           NaN
# 3                   FILIPPO Murroni  ...             NaN           NaN
# 8       Chinese Academy Of Sciences  ...         Beijing       Beijing
# ...                             ...  ...             ...           ...
# 114500            Vine St. Ventures  ...             NaN           NaN
# 114502                Rajan Anandan  ...             NaN           NaN
# 114503                Trevor Wright  ...             NaN           NaN
# 114504                    Wendy Lea  ...             NaN           NaN
# 114505                Kima Ventures  ...           Paris         Paris
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/c308019016ead7afb2a1d117018eb6fc               seed
# 1       /funding-round/14fe2864e02d0f15ddc3ec8eacdc8e1b               seed
# 2       /funding-round/809e211b969c3f66440fc15ffcd29385               seed
# 3       /funding-round/809e211b969c3f66440fc15ffcd29385               seed
# 8       /funding-round/0f444f3fdb0c1058aa70eeba9f0f5089        undisclosed
# ...                                                 ...                ...
# 114500  /funding-round/375e6c61fec5b3854ecbe5732dfdcabe               seed
# 114502  /funding-round/bfb0b5859be2431f35882bc03370dd67            venture
# 114503  /funding-round/375e6c61fec5b3854ecbe5732dfdcabe               seed
# 114504  /funding-round/375e6c61fec5b3854ecbe5732dfdcabe               seed
# 114505  /funding-round/3b06e2822fbd630d8baa1d696c6478fa               seed
#
#        funding_round_code   funded_at funded_month funded_quarter funded_year  \
# 0                     NaN  1921-09-01      1921-09        1921-Q3        1921
# 1                     NaN  1974-01-01      1974-01        1974-Q1        1974
# 2                     NaN  1979-01-01      1979-01        1979-Q1        1979
# 3                     NaN  1979-01-01      1979-01        1979-Q1        1979
# 8                     NaN  1984-01-01      1984-01        1984-Q1        1984
# ...                   ...         ...          ...            ...         ...
# 114500                NaN  2014-12-02      2014-12        2014-Q4        2014
# 114502                NaN  2014-12-02      2014-12        2014-Q4        2014
# 114503                NaN  2014-12-02      2014-12        2014-Q4        2014
# 114504                NaN  2014-12-02      2014-12        2014-Q4        2014
# 114505                NaN  2014-12-20      2014-12        2014-Q4        2014
#
#        raised_amount_usd
# 0                 1000.0
# 1                    NaN
# 2              1000000.0
# 3              1000000.0
# 8                    NaN
# ...                  ...
# 114500         1200000.0
# 114502               NaN
# 114503         1200000.0
# 114504         1200000.0
# 114505               NaN
#
# [59837 rows x 24 columns]
# ==========================================================================
# FUNDED_AT
# VALUE COUNTS
# 2012-01-01    795
# 2013-01-01    648
# 2011-01-01    579
# 2008-01-01    573
# 2007-01-01    540
#              ...
# 2004-10-30      1
# 2004-11-08      1
# 2004-11-16      1
# 2004-11-28      1
# 2014-12-20      1
# Name: funded_at, Length: 3923, dtype: int64
#
#
# DUPLICATE COUNTS
# 110583
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, investor_permalink, investor_name, investor_category_list, investor_market, investor_country_code, investor_state_code, investor_region, investor_city, funding_round_permalink, funding_round_type, funding_round_code, funded_at, funded_month, funded_quarter, funded_year, raised_amount_usd]
# Index: []
#
# [0 rows x 24 columns]
# ==========================================================================
# FUNDED_MONTH
# VALUE COUNTS
# 2014-01    2200
# 2013-09    2153
# 2013-10    2025
# 2014-06    1948
# 2014-07    1933
#            ...
# 1992-03       1
# 1992-02       1
# 1991-04       1
# 1991-01       1
# 1921-09       1
# Name: funded_month, Length: 300, dtype: int64
#
#
# DUPLICATE COUNTS
# 114206
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, investor_permalink, investor_name, investor_category_list, investor_market, investor_country_code, investor_state_code, investor_region, investor_city, funding_round_permalink, funding_round_type, funding_round_code, funded_at, funded_month, funded_quarter, funded_year, raised_amount_usd]
# Index: []
#
# [0 rows x 24 columns]
# ==========================================================================
# FUNDED_QUARTER
# VALUE COUNTS
# 2014-Q1    5812
# 2014-Q2    5703
# 2013-Q3    5669
# 2013-Q4    5512
# 2014-Q3    5485
#            ...
# 1989-Q4       1
# 1991-Q2       1
# 1991-Q4       1
# 1995-Q3       1
# 1921-Q3       1
# Name: funded_quarter, Length: 123, dtype: int64
#
#
# DUPLICATE COUNTS
# 114383
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, investor_permalink, investor_name, investor_category_list, investor_market, investor_country_code, investor_state_code, investor_region, investor_city, funding_round_permalink, funding_round_type, funding_round_code, funded_at, funded_month, funded_quarter, funded_year, raised_amount_usd]
# Index: []
#
# [0 rows x 24 columns]
# ==========================================================================
# FUNDED_YEAR
# VALUE COUNTS
# 2013    21041
# 2014    20012
# 2012    16583
# 2011    13089
# 2010     9708
# 2008     7366
# 2009     7031
# 2007     6946
# 2006     5735
# 2005     4290
# 2004      707
# 2000      455
# 2003      374
# 2002      359
# 2001      309
# 1999      254
# 1998       65
# 1997       32
# 1996       30
# 1990       19
# 1995       17
# 1994       16
# 1993       15
# 1992       12
# 1991       10
# 1987        7
# 1985        5
# 1986        4
# 1982        3
# 1989        3
# 1988        2
# 1984        2
# 1979        2
# 1974        1
# 1983        1
# 1921        1
# Name: funded_year, dtype: int64
#
#
# DUPLICATE COUNTS
# 114470
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, investor_permalink, investor_name, investor_category_list, investor_market, investor_country_code, investor_state_code, investor_region, investor_city, funding_round_permalink, funding_round_type, funding_round_code, funded_at, funded_month, funded_quarter, funded_year, raised_amount_usd]
# Index: []
#
# [0 rows x 24 columns]
# ==========================================================================
# RAISED_AMOUNT_USD
# VALUE COUNTS
# 10000000.0    3385
# 1000000.0     3310
# 5000000.0     2585
# 2000000.0     2568
# 15000000.0    2229
#               ...
# 1118770.0        1
# 215049.0         1
# 107524.0         1
# 2463690.0        1
# 14081347.0       1
# Name: raised_amount_usd, Length: 7452, dtype: int64
#
#
# DUPLICATE COUNTS
# 107053
#
#
# NULL COUNTS AND PERCENTAGE
# 13415
# 11.71554329030793
#
#
# NULL ROWS
#                           company_permalink           company_name  \
# 1       /organization/andrewburnett-com-ltd  AndrewBurnett.com Ltd
# 8                      /organization/lenovo                 Lenovo
# 9                   /organization/mixertech              Mixertech
# 13          /organization/aehr-test-systems      Aehr Test Systems
# 14          /organization/fsi-international      FSI International
# ...                                     ...                    ...
# 114360               /organization/zendrive               Zendrive
# 114407                  /organization/orori                  Orori
# 114476                /organization/appknox                Appknox
# 114502                /organization/appknox                Appknox
# 114505            /organization/vonjour-com                Vonjour
#
#                                     company_category_list  \
# 1       |Internet|SEO|Services|Public Relations|Social...
# 8                                              |Hardware|
# 9                                                     NaN
# 13                                  |Hardware + Software|
# 14                                       |Semiconductors|
# ...                                                   ...
# 114360                                       |Automotive|
# 114407                                                NaN
# 114476                      |Mobile Security|SaaS|Mobile|
# 114502                      |Mobile Security|SaaS|Mobile|
# 114505                              |Enterprise Software|
#
#              company_market company_country_code company_state_code  \
# 1                  Internet                  GBR                NaN
# 8                  Hardware                  USA                 NC
# 9                       NaN                  NaN                NaN
# 13      Hardware + Software                  USA                 CA
# 14           Semiconductors                  USA                 MN
# ...                     ...                  ...                ...
# 114360           Automotive                  USA                 CA
# 114407                  NaN                  IDN                NaN
# 114476      Mobile Security                  SGP                NaN
# 114502      Mobile Security                  SGP                NaN
# 114505  Enterprise Software                  NaN                NaN
#
#        company_region   company_city  \
# 1           Edinburgh      Edinburgh
# 8             Raleigh    Morrisville
# 9                 NaN            NaN
# 13        SF Bay Area        Fremont
# 14        Minneapolis         Chaska
# ...               ...            ...
# 114360    SF Bay Area  San Francisco
# 114407        Jakarta        Jakarta
# 114476      Singapore      Singapore
# 114502      Singapore      Singapore
# 114505            NaN            NaN
#
#                                   investor_permalink  \
# 1                                 /organization/ekaf
# 8          /organization/chinese-academy-of-sciences
# 9       /organization/crp-companhia-de-participacoes
# 13                     /organization/summit-partners
# 14                     /organization/summit-partners
# ...                                              ...
# 114360             /organization/fontinalis-partners
# 114407                      /organization/ideosource
# 114476                 /organization/jungle-ventures
# 114502                         /person/rajan-anandan
# 114505                   /organization/kima-ventures
#
#                            investor_name  ... investor_region investor_city  \
# 1                                   Ekaf  ...             NaN           NaN
# 8            Chinese Academy Of Sciences  ...         Beijing       Beijing
# 9       CRP Companhia de Participações  ...             NaN           NaN
# 13                       Summit Partners  ...          Boston        Boston
# 14                       Summit Partners  ...          Boston        Boston
# ...                                  ...  ...             ...           ...
# 114360               Fontinalis Partners  ...         Detroit       Detroit
# 114407                        Ideosource  ...         Jakarta       Jakarta
# 114476                   Jungle Ventures  ...       Singapore     Singapore
# 114502                     Rajan Anandan  ...             NaN           NaN
# 114505                     Kima Ventures  ...           Paris         Paris
#
#                                 funding_round_permalink funding_round_type  \
# 1       /funding-round/14fe2864e02d0f15ddc3ec8eacdc8e1b               seed
# 8       /funding-round/0f444f3fdb0c1058aa70eeba9f0f5089        undisclosed
# 9       /funding-round/4316813c5da6e06f2a15fa25c7946a73            venture
# 13      /funding-round/3b02cf325be61412c2af1eb545f4d568        undisclosed
# 14      /funding-round/34b482e681b7e2ec7b0c7886e9f9d90d        undisclosed
# ...                                                 ...                ...
# 114360  /funding-round/31204ec2abf4ddf45667d231a1b11be3            venture
# 114407  /funding-round/d0f5ccae89755f0c35deaf80b6cfe4ac               seed
# 114476  /funding-round/bfb0b5859be2431f35882bc03370dd67            venture
# 114502  /funding-round/bfb0b5859be2431f35882bc03370dd67            venture
# 114505  /funding-round/3b06e2822fbd630d8baa1d696c6478fa               seed
#
#        funding_round_code   funded_at funded_month funded_quarter funded_year  \
# 1                     NaN  1974-01-01      1974-01        1974-Q1        1974
# 8                     NaN  1984-01-01      1984-01        1984-Q1        1984
# 9                       A  1984-05-01      1984-05        1984-Q2        1984
# 13                    NaN  1985-09-19      1985-09        1985-Q3        1985
# 14                    NaN  1985-10-20      1985-10        1985-Q4        1985
# ...                   ...         ...          ...            ...         ...
# 114360                NaN  2014-11-26      2014-11        2014-Q4        2014
# 114407                NaN  2014-11-28      2014-11        2014-Q4        2014
# 114476                NaN  2014-12-02      2014-12        2014-Q4        2014
# 114502                NaN  2014-12-02      2014-12        2014-Q4        2014
# 114505                NaN  2014-12-20      2014-12        2014-Q4        2014
#
#        raised_amount_usd
# 1                    NaN
# 8                    NaN
# 9                    NaN
# 13                   NaN
# 14                   NaN
# ...                  ...
# 114360               NaN
# 114407               NaN
# 114476               NaN
# 114502               NaN
# 114505               NaN
#
# [13415 rows x 24 columns]

# %% [markdown]
# #Acquisitions EDA and Preprocessing

# %%
acquisitions = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CIS 550/acquisitions.csv')
acquisitions[' price_amount '] = acquisitions[' price_amount '].apply(lambda x: set_to_floats(x))
acquisitions
# Out:
#                      company_permalink    company_name  \
# 0                /organization/waywire        #waywire
# 1          /organization/fluff-friends  (fluff)Friends
# 2                    /organization/red           (RED)
# 3      /organization/vandaele-holdings               .
# 4            /organization/co-internet             .CO
# ...                                ...             ...
# 13064               /organization/zync            Zync
# 13065        /organization/zync-render     Zync Render
# 13066        /organization/zynk-mobile     Zynk Mobile
# 13067             /organization/zyrion      Zyrion Inc
# 13068             /organization/zystor          Zystor
#
#                             company_category_list company_market  \
# 0      |Entertainment|Politics|Social Media|News|           News
# 1                                             NaN            NaN
# 2                                    |Nonprofits|     Nonprofits
# 3                                             NaN            NaN
# 4                |Registrars|Domains|Curated Web|     Registrars
# ...                                           ...            ...
# 13064                               |Curated Web|    Curated Web
# 13065                             |Digital Media|  Digital Media
# 13066                                         NaN            NaN
# 13067                       |Networking|Software|       Software
# 13068                             |Biotechnology|  Biotechnology
#
#       company_country_code company_state_code company_region company_city  \
# 0                      USA                 NY  New York City     New York
# 1                      NaN                NaN            NaN          NaN
# 2                      USA                 NY  New York City     New York
# 3                      NaN                NaN            NaN          NaN
# 4                      USA                 FL          Miami        Miami
# ...                    ...                ...            ...          ...
# 13064                  NaN                NaN            NaN          NaN
# 13065                  USA                 MA         Boston       Boston
# 13066                  NaN                NaN            NaN          NaN
# 13067                  USA                 CA    SF Bay Area    Sunnyvale
# 13068                  USA                 WI      Milwaukee    Milwaukee
#
#                                acquirer_permalink  \
# 0                           /organization/magnify
# 1             /organization/social-gaming-network
# 2      /organization/nationstar-mortgage-holdings
# 3                              /organization/hi7e
# 4                           /organization/neustar
# ...                                           ...
# 13064                     /organization/where-com
# 13065                        /organization/google
# 13066                        /organization/zenvia
# 13067                        /organization/kaseya
# 13068       /organization/biomarin-pharmaceutical
#
#                       acquirer_name  ... acquirer_country_code  \
# 0                  Waywire Networks  ...                   USA
# 1       SGN (Social Gaming Network)  ...                   USA
# 2      Nationstar Mortgage Holdings  ...                   USA
# 3                              HI7E  ...                   USA
# 4                           Neustar  ...                   USA
# ...                             ...  ...                   ...
# 13064                         Where  ...                   USA
# 13065                        Google  ...                   USA
# 13066                        Zenvia  ...                   BRA
# 13067                        Kaseya  ...                   NaN
# 13068       BioMarin Pharmaceutical  ...                   USA
#
#       acquirer_state_code   acquirer_region    acquirer_city acquired_at  \
# 0                      NY     New York City         New York  2013-10-17
# 1                      CA       Los Angeles    Beverly Hills  2008-09-16
# 2                      TX            Dallas       Lewisville  2014-05-08
# 3                      FL      Palm Beaches  West Palm Beach  2011-01-01
# 4                      VA  Washington, D.C.         Sterling  2014-03-20
# ...                   ...               ...              ...         ...
# 13064                  MA            Boston           Boston  2008-02-07
# 13065                  CA       SF Bay Area    Mountain View  2014-08-26
# 13066                 NaN      Porto Alegre     Porto Alegre  2013-03-01
# 13067                 NaN               NaN              NaN  2013-06-25
# 13068                  CA       SF Bay Area       San Rafael  2010-08-18
#
#       acquired_month acquired_quarter acquired_year  price_amount   \
# 0            2013-10          2013-Q4        2013.0            NaN
# 1            2008-09          2008-Q3        2008.0            NaN
# 2            2014-05          2014-Q2        2014.0     18000000.0
# 3            2011-01          2011-Q1        2011.0            NaN
# 4            2014-03          2014-Q1        2014.0    109000000.0
# ...              ...              ...           ...            ...
# 13064        2008-02          2008-Q1        2008.0            NaN
# 13065        2014-08          2014-Q3        2014.0            NaN
# 13066        2013-03          2013-Q1        2013.0            NaN
# 13067        2013-06          2013-Q2        2013.0            NaN
# 13068        2010-08          2010-Q3        2010.0    115000000.0
#
#        price_currency_code
# 0                      USD
# 1                      USD
# 2                      USD
# 3                      USD
# 4                      USD
# ...                    ...
# 13064                  USD
# 13065                  USD
# 13066                  USD
# 13067                  USD
# 13068                  USD
#
# [13069 rows x 22 columns]

# %% [markdown]
# ##Summary Stats

# %%
acquisitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13069 entries, 0 to 13068
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       13069 non-null  object
#  1   company_name            13069 non-null  object
#  2   company_category_list   9786 non-null   object
#  3   company_market          9784 non-null   object
#  4   company_country_code    9782 non-null   object
#  5   company_state_code      7519 non-null   object
#  6   company_region          9783 non-null   object
#  7   company_city            9584 non-null   object
#  8   acquirer_permalink      13069 non-null  object
#  9   acquirer_name           13069 non-null  object
#  10  acquirer_category_list  11565 non-null  object
#  11  acquirer_market         11559 non-null  object
#  12  acquirer_country_code   12228 non-null  object
#  13  acquirer_state_code     9782 non-null   object
#  14  acquirer_region         12228 non-null  object
#  15  acquirer_city           12109 non-null  object
#  16  acquired_at             13069 non-null  object
#  17  acquired_month          13067 non-null  object
#  18  acquired_quarter        13067 non-null  object
#  19  acquired_year           13067 non-null  float64
#  20   price_amount           3711 non-null   float64
#  21  price_currency_code     13065 non-null  object
# dtypes: float64(2), object(20)
# memory usage: 2.2+ MB

# %%
acquisitions.describe()
# Out:
#        acquired_year   price_amount
# count   13067.000000    3.711000e+03
# mean     2010.366037    7.422824e+08
# std         3.695350    4.048504e+09
# min      1960.000000    1.000000e+00
# 25%      2009.000000    1.845000e+07
# 50%      2011.000000    8.300000e+07
# 75%      2013.000000    3.427500e+08
# max      2014.000000    1.500000e+11

# %%
acquisitions.nunique()
# Out:
# company_permalink         12790
# company_name              12783
# company_category_list      3649
# company_market              536
# company_country_code         73
# company_state_code           59
# company_region              596
# company_city               1816
# acquirer_permalink         6632
# acquirer_name              6629
# acquirer_category_list     2371
# acquirer_market             451
# acquirer_country_code        67
# acquirer_state_code          57
# acquirer_region             495
# acquirer_city              1410
# acquired_at                3078
# acquired_month              279
# acquired_quarter            111
# acquired_year                37
#  price_amount              1311
# price_currency_code          11
# dtype: int64

# %% [markdown]
# ##Analysis

# %%
column_names = ['company_permalink', 'company_name', 'company_category_list', 'company_market', 'company_country_code', 'company_state_code', 'company_region', 'company_city', 'acquirer_permalink', 'acquirer_name', 'acquirer_category_list', 'acquirer_market', 'acquirer_country_code','acquirer_state_code', 'acquirer_region', 'acquirer_city', 'acquired_at', 'acquired_month', 'acquired_quarter', 'acquired_year', ' price_amount ', 'price_currency_code']

for col in column_names:
  print('\n\n')
  print("==========================================================================")
  print(col.upper())
  print("VALUE COUNTS")
  print(acquisitions[col].value_counts())
  print("\n")

  print("DUPLICATE COUNTS")
  print(acquisitions.duplicated(subset=col, keep='first').sum())
  print("\n")

  print("NULL COUNTS AND PERCENTAGE")
  print(acquisitions[col].isnull().sum())
  print(acquisitions[col].isnull().sum()/len(acquisitions)*100)
  print('\n')
  
  print("NULL ROWS")
  display(acquisitions[acquisitions[col].isnull()])
# Out:
# ==========================================================================
# COMPANY_PERMALINK
# VALUE COUNTS
# /organization/pando-networks                18
# /organization/insieme                        5
# /organization/travel-channel                 4
# /organization/udcast                         4
# /organization/webshots                       4
#                                             ..
# /organization/fortis-healthcare              1
# /organization/fortress-solutions             1
# /organization/fortress-technologies          1
# /organization/fortsum-business-solutions     1
# /organization/zystor                         1
# Name: company_permalink, Length: 12790, dtype: int64
#
#
# DUPLICATE COUNTS
# 279
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, acquirer_permalink, acquirer_name, acquirer_category_list, acquirer_market, acquirer_country_code, acquirer_state_code, acquirer_region, acquirer_city, acquired_at, acquired_month, acquired_quarter, acquired_year,  price_amount , price_currency_code]
# Index: []
#
# [0 rows x 22 columns]
# ==========================================================================
# COMPANY_NAME
# VALUE COUNTS
# Pando Networks                18
# Insieme                        5
# Webshots                       4
# UDcast                         4
# Travel Channel                 4
#                               ..
# Fortis Healthcare              1
# Fortress Solutions             1
# Fortress Technologies          1
# Fortsum Business Solutions     1
# Zystor                         1
# Name: company_name, Length: 12783, dtype: int64
#
#
# DUPLICATE COUNTS
# 286
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, acquirer_permalink, acquirer_name, acquirer_category_list, acquirer_market, acquirer_country_code, acquirer_state_code, acquirer_region, acquirer_city, acquired_at, acquired_month, acquired_quarter, acquired_year,  price_amount , price_currency_code]
# Index: []
#
# [0 rows x 22 columns]
# ==========================================================================
# COMPANY_CATEGORY_LIST
# VALUE COUNTS
# |Software|                                                                    1254
# |Curated Web|                                                                  578
# |Biotechnology|                                                                475
# |Enterprise Software|                                                          351
# |Mobile|                                                                       293
#                                                                               ...
# |Internet|Identity|Media|Personalization|Finance|Fraud Detection|Software|       1
# |Publishing|News|Media|Video|Advertising|                                        1
# |Mobile|Crowdsourcing|Gas|Travel|Oil|Curated Web|                                1
# |Media|Hardware|Computers|Hardware + Software|                                   1
# |Design|Health and Wellness|Hardware + Software|                                 1
# Name: company_category_list, Length: 3649, dtype: int64
#
#
# DUPLICATE COUNTS
# 9419
#
#
# NULL COUNTS AND PERCENTAGE
# 3283
# 25.12051419389395
#
#
# NULL ROWS
#                        company_permalink         company_name  \
# 1            /organization/fluff-friends       (fluff)Friends
# 3        /organization/vandaele-holdings                    .
# 6                   /organization/003-ru               003.RU
# 7          /organization/0958572-b-c-ltd    0958572 B.C. Ltd.
# 8      /organization/1-nation-technology  1 Nation Technology
# ...                                  ...                  ...
# 13051                  /organization/zui                  Zui
# 13052                 /organization/zuji                 Zuji
# 13053                /organization/zukes               Zuke’s
# 13061    /organization/zylom-media-group    Zylom Media Group
# 13066          /organization/zynk-mobile          Zynk Mobile
#
#       company_category_list company_market company_country_code  \
# 1                       NaN            NaN                  NaN
# 3                       NaN            NaN                  NaN
# 6                       NaN            NaN                  RUS
# 7                       NaN            NaN                  NaN
# 8                       NaN            NaN                  NaN
# ...                     ...            ...                  ...
# 13051                   NaN            NaN                  NaN
# 13052                   NaN            NaN                  NaN
# 13053                   NaN            NaN                  USA
# 13061                   NaN            NaN                  NLD
# 13066                   NaN            NaN                  NaN
#
#       company_state_code  company_region company_city  \
# 1                    NaN             NaN          NaN
# 3                    NaN             NaN          NaN
# 6                    NaN          Moscow       Moscow
# 7                    NaN             NaN          NaN
# 8                    NaN             NaN          NaN
# ...                  ...             ...          ...
# 13051                NaN             NaN          NaN
# 13052                NaN             NaN          NaN
# 13053                 CO  Grand Junction      Durango
# 13061                NaN       Eindhoven    Eindhoven
# 13066                NaN             NaN          NaN
#
#                                       acquirer_permalink  \
# 1                    /organization/social-gaming-network
# 3                                     /organization/hi7e
# 6                             /organization/media-saturn
# 7      /organization/atlas-intellectual-property-mana...
# 8                                   /organization/vology
# ...                                                  ...
# 13051                         /organization/saban-brands
# 13052                        /organization/webjet-com-au
# 13053                /organization/nestle-purina-petcare
# 13061                         /organization/realnetworks
# 13066                               /organization/zenvia
#
#                                     acquirer_name  ... acquirer_country_code  \
# 1                     SGN (Social Gaming Network)  ...                   USA
# 3                                            HI7E  ...                   USA
# 6                                    Media Saturn  ...                   ESP
# 7      ATLAS Intellectual Property Management Co.  ...                   USA
# 8                                          Vology  ...                   USA
# ...                                           ...  ...                   ...
# 13051                                Saban Brands  ...                   USA
# 13052                               Webjet.com.au  ...                   AUS
# 13053                       Nestle Purina Petcare  ...                   USA
# 13061                               Real Networks  ...                   USA
# 13066                                      Zenvia  ...                   BRA
#
#       acquirer_state_code acquirer_region    acquirer_city acquired_at  \
# 1                      CA     Los Angeles    Beverly Hills  2008-09-16
# 3                      FL    Palm Beaches  West Palm Beach  2011-01-01
# 6                     NaN       Barcelona        Barcelona  2012-07-23
# 7                      WA         Seattle          Seattle  2012-02-02
# 8                      FL           Tampa          Oldsmar  2006-01-01
# ...                   ...             ...              ...         ...
# 13051                  CA     Los Angeles      Los Angeles  2012-09-20
# 13052                 NaN       Melbourne        Melbourne  2013-03-01
# 13053                  MO       St. Louis         St Louis  2014-01-15
# 13061                  WA         Seattle          Seattle  2006-02-06
# 13066                 NaN    Porto Alegre     Porto Alegre  2013-03-01
#
#       acquired_month acquired_quarter acquired_year  price_amount   \
# 1            2008-09          2008-Q3        2008.0            NaN
# 3            2011-01          2011-Q1        2011.0            NaN
# 6            2012-07          2012-Q3        2012.0            NaN
# 7            2012-02          2012-Q1        2012.0      9000000.0
# 8            2006-01          2006-Q1        2006.0            NaN
# ...              ...              ...           ...            ...
# 13051        2012-09          2012-Q3        2012.0            NaN
# 13052        2013-03          2013-Q1        2013.0     25000000.0
# 13053        2014-01          2014-Q1        2014.0            NaN
# 13061        2006-02          2006-Q1        2006.0            NaN
# 13066        2013-03          2013-Q1        2013.0            NaN
#
#        price_currency_code
# 1                      USD
# 3                      USD
# 6                      USD
# 7                      USD
# 8                      USD
# ...                    ...
# 13051                  USD
# 13052                  AUD
# 13053                  USD
# 13061                  USD
# 13066                  USD
#
# [3283 rows x 22 columns]
# ==========================================================================
# COMPANY_MARKET
# VALUE COUNTS
# Software                 1489
# Curated Web               714
# Biotechnology             505
# Enterprise Software       448
# Mobile                    433
#                          ...
# Digital Entertainment       1
# Textiles                    1
# Licensing                   1
# UV LEDs                     1
# Racing                      1
# Name: company_market, Length: 536, dtype: int64
#
#
# DUPLICATE COUNTS
# 12532
#
#
# NULL COUNTS AND PERCENTAGE
# 3285
# 25.135817583594765
#
#
# NULL ROWS
#                        company_permalink         company_name  \
# 1            /organization/fluff-friends       (fluff)Friends
# 3        /organization/vandaele-holdings                    .
# 6                   /organization/003-ru               003.RU
# 7          /organization/0958572-b-c-ltd    0958572 B.C. Ltd.
# 8      /organization/1-nation-technology  1 Nation Technology
# ...                                  ...                  ...
# 13051                  /organization/zui                  Zui
# 13052                 /organization/zuji                 Zuji
# 13053                /organization/zukes               Zuke’s
# 13061    /organization/zylom-media-group    Zylom Media Group
# 13066          /organization/zynk-mobile          Zynk Mobile
#
#       company_category_list company_market company_country_code  \
# 1                       NaN            NaN                  NaN
# 3                       NaN            NaN                  NaN
# 6                       NaN            NaN                  RUS
# 7                       NaN            NaN                  NaN
# 8                       NaN            NaN                  NaN
# ...                     ...            ...                  ...
# 13051                   NaN            NaN                  NaN
# 13052                   NaN            NaN                  NaN
# 13053                   NaN            NaN                  USA
# 13061                   NaN            NaN                  NLD
# 13066                   NaN            NaN                  NaN
#
#       company_state_code  company_region company_city  \
# 1                    NaN             NaN          NaN
# 3                    NaN             NaN          NaN
# 6                    NaN          Moscow       Moscow
# 7                    NaN             NaN          NaN
# 8                    NaN             NaN          NaN
# ...                  ...             ...          ...
# 13051                NaN             NaN          NaN
# 13052                NaN             NaN          NaN
# 13053                 CO  Grand Junction      Durango
# 13061                NaN       Eindhoven    Eindhoven
# 13066                NaN             NaN          NaN
#
#                                       acquirer_permalink  \
# 1                    /organization/social-gaming-network
# 3                                     /organization/hi7e
# 6                             /organization/media-saturn
# 7      /organization/atlas-intellectual-property-mana...
# 8                                   /organization/vology
# ...                                                  ...
# 13051                         /organization/saban-brands
# 13052                        /organization/webjet-com-au
# 13053                /organization/nestle-purina-petcare
# 13061                         /organization/realnetworks
# 13066                               /organization/zenvia
#
#                                     acquirer_name  ... acquirer_country_code  \
# 1                     SGN (Social Gaming Network)  ...                   USA
# 3                                            HI7E  ...                   USA
# 6                                    Media Saturn  ...                   ESP
# 7      ATLAS Intellectual Property Management Co.  ...                   USA
# 8                                          Vology  ...                   USA
# ...                                           ...  ...                   ...
# 13051                                Saban Brands  ...                   USA
# 13052                               Webjet.com.au  ...                   AUS
# 13053                       Nestle Purina Petcare  ...                   USA
# 13061                               Real Networks  ...                   USA
# 13066                                      Zenvia  ...                   BRA
#
#       acquirer_state_code acquirer_region    acquirer_city acquired_at  \
# 1                      CA     Los Angeles    Beverly Hills  2008-09-16
# 3                      FL    Palm Beaches  West Palm Beach  2011-01-01
# 6                     NaN       Barcelona        Barcelona  2012-07-23
# 7                      WA         Seattle          Seattle  2012-02-02
# 8                      FL           Tampa          Oldsmar  2006-01-01
# ...                   ...             ...              ...         ...
# 13051                  CA     Los Angeles      Los Angeles  2012-09-20
# 13052                 NaN       Melbourne        Melbourne  2013-03-01
# 13053                  MO       St. Louis         St Louis  2014-01-15
# 13061                  WA         Seattle          Seattle  2006-02-06
# 13066                 NaN    Porto Alegre     Porto Alegre  2013-03-01
#
#       acquired_month acquired_quarter acquired_year  price_amount   \
# 1            2008-09          2008-Q3        2008.0            NaN
# 3            2011-01          2011-Q1        2011.0            NaN
# 6            2012-07          2012-Q3        2012.0            NaN
# 7            2012-02          2012-Q1        2012.0      9000000.0
# 8            2006-01          2006-Q1        2006.0            NaN
# ...              ...              ...           ...            ...
# 13051        2012-09          2012-Q3        2012.0            NaN
# 13052        2013-03          2013-Q1        2013.0     25000000.0
# 13053        2014-01          2014-Q1        2014.0            NaN
# 13061        2006-02          2006-Q1        2006.0            NaN
# 13066        2013-03          2013-Q1        2013.0            NaN
#
#        price_currency_code
# 1                      USD
# 3                      USD
# 6                      USD
# 7                      USD
# 8                      USD
# ...                    ...
# 13051                  USD
# 13052                  AUD
# 13053                  USD
# 13061                  USD
# 13066                  USD
#
# [3285 rows x 22 columns]
# ==========================================================================
# COMPANY_COUNTRY_CODE
# VALUE COUNTS
# USA    7177
# GBR     646
# CAN     348
# DEU     206
# FRA     138
#        ...
# BLR       1
# GIB       1
# COL       1
# CYM       1
# MAF       1
# Name: company_country_code, Length: 73, dtype: int64
#
#
# DUPLICATE COUNTS
# 12995
#
#
# NULL COUNTS AND PERCENTAGE
# 3287
# 25.151120973295587
#
#
# NULL ROWS
#                        company_permalink         company_name  \
# 1            /organization/fluff-friends       (fluff)Friends
# 3        /organization/vandaele-holdings                    .
# 7          /organization/0958572-b-c-ltd    0958572 B.C. Ltd.
# 8      /organization/1-nation-technology  1 Nation Technology
# 10            /organization/1000-markets         1000 Markets
# ...                                  ...                  ...
# 13052                 /organization/zuji                 Zuji
# 13054                /organization/zulip                Zulip
# 13055           /organization/zuneboards           ZuneBoards
# 13064                 /organization/zync                 Zync
# 13066          /organization/zynk-mobile          Zynk Mobile
#
#                company_category_list       company_market  \
# 1                                NaN                  NaN
# 3                                NaN                  NaN
# 7                                NaN                  NaN
# 8                                NaN                  NaN
# 10     |Marketplaces|Art|E-Commerce|         Marketplaces
# ...                              ...                  ...
# 13052                            NaN                  NaN
# 13054          |Enterprise Software|  Enterprise Software
# 13055          |Hardware + Software|  Hardware + Software
# 13064                  |Curated Web|          Curated Web
# 13066                            NaN                  NaN
#
#       company_country_code company_state_code company_region company_city  \
# 1                      NaN                NaN            NaN          NaN
# 3                      NaN                NaN            NaN          NaN
# 7                      NaN                NaN            NaN          NaN
# 8                      NaN                NaN            NaN          NaN
# 10                     NaN                NaN            NaN          NaN
# ...                    ...                ...            ...          ...
# 13052                  NaN                NaN            NaN          NaN
# 13054                  NaN                NaN            NaN          NaN
# 13055                  NaN                NaN            NaN          NaN
# 13064                  NaN                NaN            NaN          NaN
# 13066                  NaN                NaN            NaN          NaN
#
#                                       acquirer_permalink  \
# 1                    /organization/social-gaming-network
# 3                                     /organization/hi7e
# 7      /organization/atlas-intellectual-property-mana...
# 8                                   /organization/vology
# 10                                /organization/bonanzle
# ...                                                  ...
# 13052                        /organization/webjet-com-au
# 13054                              /organization/dropbox
# 13055                          /organization/crowdgather
# 13064                            /organization/where-com
# 13066                               /organization/zenvia
#
#                                     acquirer_name  ... acquirer_country_code  \
# 1                     SGN (Social Gaming Network)  ...                   USA
# 3                                            HI7E  ...                   USA
# 7      ATLAS Intellectual Property Management Co.  ...                   USA
# 8                                          Vology  ...                   USA
# 10                                        Bonanza  ...                   USA
# ...                                           ...  ...                   ...
# 13052                               Webjet.com.au  ...                   AUS
# 13054                                     Dropbox  ...                   USA
# 13055                                 CrowdGather  ...                   USA
# 13064                                       Where  ...                   USA
# 13066                                      Zenvia  ...                   BRA
#
#       acquirer_state_code acquirer_region    acquirer_city acquired_at  \
# 1                      CA     Los Angeles    Beverly Hills  2008-09-16
# 3                      FL    Palm Beaches  West Palm Beach  2011-01-01
# 7                      WA         Seattle          Seattle  2012-02-02
# 8                      FL           Tampa          Oldsmar  2006-01-01
# 10                     WA         Seattle          Seattle  2012-09-22
# ...                   ...             ...              ...         ...
# 13052                 NaN       Melbourne        Melbourne  2013-03-01
# 13054                  CA     SF Bay Area    San Francisco  2014-03-17
# 13055                  CA     Los Angeles   Woodland Hills  2008-08-01
# 13064                  MA          Boston           Boston  2008-02-07
# 13066                 NaN    Porto Alegre     Porto Alegre  2013-03-01
#
#       acquired_month acquired_quarter acquired_year  price_amount   \
# 1            2008-09          2008-Q3        2008.0            NaN
# 3            2011-01          2011-Q1        2011.0            NaN
# 7            2012-02          2012-Q1        2012.0      9000000.0
# 8            2006-01          2006-Q1        2006.0            NaN
# 10           2012-09          2012-Q3        2012.0            NaN
# ...              ...              ...           ...            ...
# 13052        2013-03          2013-Q1        2013.0     25000000.0
# 13054        2014-03          2014-Q1        2014.0            NaN
# 13055        2008-08          2008-Q3        2008.0        62000.0
# 13064        2008-02          2008-Q1        2008.0            NaN
# 13066        2013-03          2013-Q1        2013.0            NaN
#
#        price_currency_code
# 1                      USD
# 3                      USD
# 7                      USD
# 8                      USD
# 10                     USD
# ...                    ...
# 13052                  AUD
# 13054                  USD
# 13055                  USD
# 13064                  USD
# 13066                  USD
#
# [3287 rows x 22 columns]
# ==========================================================================
# COMPANY_STATE_CODE
# VALUE COUNTS
# CA    2520
# NY     641
# MA     510
# TX     416
# IL     279
# WA     266
# CO     212
# FL     202
# PA     193
# NJ     190
# ON     183
# VA     180
# GA     155
# MD     129
# NC     124
# OH      99
# MN      88
# AZ      80
# UT      77
# CT      72
# OR      71
# MI      66
# MO      64
# QC      61
# WI      58
# BC      57
# TN      56
# KS      37
# IN      35
# NH      31
# DC      29
# AL      28
# AB      28
# NV      27
# LA      22
# KY      22
# SC      22
# OK      22
# IA      17
# NE      16
# RI      15
# ID      13
# VT      12
# AR      11
# DE      11
# ND      10
# MT       9
# NS       8
# ME       8
# MS       6
# NM       6
# HI       6
# WV       5
# MB       5
# AK       4
# WY       2
# NB       1
# NL       1
# SK       1
# Name: company_state_code, dtype: int64
#
#
# DUPLICATE COUNTS
# 13009
#
#
# NULL COUNTS AND PERCENTAGE
# 5550
# 42.46690641977197
#
#
# NULL ROWS
#                      company_permalink       company_name  \
# 1          /organization/fluff-friends     (fluff)Friends
# 3      /organization/vandaele-holdings                  .
# 5              /organization/vantronix         .vantronix
# 6                 /organization/003-ru             003.RU
# 7        /organization/0958572-b-c-ltd  0958572 B.C. Ltd.
# ...                                ...                ...
# 13061  /organization/zylom-media-group  Zylom Media Group
# 13062            /organization/zymenex            Zymenex
# 13063           /organization/zynamics           zynamics
# 13064               /organization/zync               Zync
# 13066        /organization/zynk-mobile        Zynk Mobile
#
#                             company_category_list  company_market  \
# 1                                             NaN             NaN
# 3                                             NaN             NaN
# 5      |Cloud Security|Network Security|Security|  Cloud Security
# 6                                             NaN             NaN
# 7                                             NaN             NaN
# ...                                           ...             ...
# 13061                                         NaN             NaN
# 13062                             |Biotechnology|   Biotechnology
# 13063                                  |Security|        Security
# 13064                               |Curated Web|     Curated Web
# 13066                                         NaN             NaN
#
#       company_country_code company_state_code company_region company_city  \
# 1                      NaN                NaN            NaN          NaN
# 3                      NaN                NaN            NaN          NaN
# 5                      DEU                NaN        Hanover      Hanover
# 6                      RUS                NaN         Moscow       Moscow
# 7                      NaN                NaN            NaN          NaN
# ...                    ...                ...            ...          ...
# 13061                  NLD                NaN      Eindhoven    Eindhoven
# 13062                  DNK                NaN    DNK - Other     Hillerød
# 13063                  DEU                NaN         Bochum       Bochum
# 13064                  NaN                NaN            NaN          NaN
# 13066                  NaN                NaN            NaN          NaN
#
#                                       acquirer_permalink  \
# 1                    /organization/social-gaming-network
# 3                                     /organization/hi7e
# 5                              /organization/compumatica
# 6                             /organization/media-saturn
# 7      /organization/atlas-intellectual-property-mana...
# ...                                                  ...
# 13061                         /organization/realnetworks
# 13062               /organization/chiesi-pharmaceuticals
# 13063                               /organization/google
# 13064                            /organization/where-com
# 13066                               /organization/zenvia
#
#                                     acquirer_name  ... acquirer_country_code  \
# 1                     SGN (Social Gaming Network)  ...                   USA
# 3                                            HI7E  ...                   USA
# 5                                     Compumatica  ...                   NaN
# 6                                    Media Saturn  ...                   ESP
# 7      ATLAS Intellectual Property Management Co.  ...                   USA
# ...                                           ...  ...                   ...
# 13061                               Real Networks  ...                   USA
# 13062                      Chiesi Pharmaceuticals  ...                   ITA
# 13063                                      Google  ...                   USA
# 13064                                       Where  ...                   USA
# 13066                                      Zenvia  ...                   BRA
#
#       acquirer_state_code acquirer_region    acquirer_city acquired_at  \
# 1                      CA     Los Angeles    Beverly Hills  2008-09-16
# 3                      FL    Palm Beaches  West Palm Beach  2011-01-01
# 5                     NaN             NaN              NaN  2011-01-01
# 6                     NaN       Barcelona        Barcelona  2012-07-23
# 7                      WA         Seattle          Seattle  2012-02-02
# ...                   ...             ...              ...         ...
# 13061                  WA         Seattle          Seattle  2006-02-06
# 13062                 NaN           Parma            Parma  2013-08-26
# 13063                  CA     SF Bay Area    Mountain View  2011-03-01
# 13064                  MA          Boston           Boston  2008-02-07
# 13066                 NaN    Porto Alegre     Porto Alegre  2013-03-01
#
#       acquired_month acquired_quarter acquired_year  price_amount   \
# 1            2008-09          2008-Q3        2008.0            NaN
# 3            2011-01          2011-Q1        2011.0            NaN
# 5            2011-01          2011-Q1        2011.0            NaN
# 6            2012-07          2012-Q3        2012.0            NaN
# 7            2012-02          2012-Q1        2012.0      9000000.0
# ...              ...              ...           ...            ...
# 13061        2006-02          2006-Q1        2006.0            NaN
# 13062        2013-08          2013-Q3        2013.0            NaN
# 13063        2011-03          2011-Q1        2011.0            NaN
# 13064        2008-02          2008-Q1        2008.0            NaN
# 13066        2013-03          2013-Q1        2013.0            NaN
#
#        price_currency_code
# 1                      USD
# 3                      USD
# 5                      USD
# 6                      USD
# 7                      USD
# ...                    ...
# 13061                  USD
# 13062                  USD
# 13063                  USD
# 13064                  USD
# 13066                  USD
#
# [5550 rows x 22 columns]
# ==========================================================================
# COMPANY_REGION
# VALUE COUNTS
# SF Bay Area        1794
# New York City       554
# Boston              477
# London              380
# Los Angeles         331
#                    ...
# Appenzell             1
# Nottinghamshire       1
# Itá                   1
# Weybridge             1
# Cheadle Hulme         1
# Name: company_region, Length: 596, dtype: int64
#
#
# DUPLICATE COUNTS
# 12472
#
#
# NULL COUNTS AND PERCENTAGE
# 3286
# 25.143469278445174
#
#
# NULL ROWS
#                        company_permalink         company_name  \
# 1            /organization/fluff-friends       (fluff)Friends
# 3        /organization/vandaele-holdings                    .
# 7          /organization/0958572-b-c-ltd    0958572 B.C. Ltd.
# 8      /organization/1-nation-technology  1 Nation Technology
# 10            /organization/1000-markets         1000 Markets
# ...                                  ...                  ...
# 13052                 /organization/zuji                 Zuji
# 13054                /organization/zulip                Zulip
# 13055           /organization/zuneboards           ZuneBoards
# 13064                 /organization/zync                 Zync
# 13066          /organization/zynk-mobile          Zynk Mobile
#
#                company_category_list       company_market  \
# 1                                NaN                  NaN
# 3                                NaN                  NaN
# 7                                NaN                  NaN
# 8                                NaN                  NaN
# 10     |Marketplaces|Art|E-Commerce|         Marketplaces
# ...                              ...                  ...
# 13052                            NaN                  NaN
# 13054          |Enterprise Software|  Enterprise Software
# 13055          |Hardware + Software|  Hardware + Software
# 13064                  |Curated Web|          Curated Web
# 13066                            NaN                  NaN
#
#       company_country_code company_state_code company_region company_city  \
# 1                      NaN                NaN            NaN          NaN
# 3                      NaN                NaN            NaN          NaN
# 7                      NaN                NaN            NaN          NaN
# 8                      NaN                NaN            NaN          NaN
# 10                     NaN                NaN            NaN          NaN
# ...                    ...                ...            ...          ...
# 13052                  NaN                NaN            NaN          NaN
# 13054                  NaN                NaN            NaN          NaN
# 13055                  NaN                NaN            NaN          NaN
# 13064                  NaN                NaN            NaN          NaN
# 13066                  NaN                NaN            NaN          NaN
#
#                                       acquirer_permalink  \
# 1                    /organization/social-gaming-network
# 3                                     /organization/hi7e
# 7      /organization/atlas-intellectual-property-mana...
# 8                                   /organization/vology
# 10                                /organization/bonanzle
# ...                                                  ...
# 13052                        /organization/webjet-com-au
# 13054                              /organization/dropbox
# 13055                          /organization/crowdgather
# 13064                            /organization/where-com
# 13066                               /organization/zenvia
#
#                                     acquirer_name  ... acquirer_country_code  \
# 1                     SGN (Social Gaming Network)  ...                   USA
# 3                                            HI7E  ...                   USA
# 7      ATLAS Intellectual Property Management Co.  ...                   USA
# 8                                          Vology  ...                   USA
# 10                                        Bonanza  ...                   USA
# ...                                           ...  ...                   ...
# 13052                               Webjet.com.au  ...                   AUS
# 13054                                     Dropbox  ...                   USA
# 13055                                 CrowdGather  ...                   USA
# 13064                                       Where  ...                   USA
# 13066                                      Zenvia  ...                   BRA
#
#       acquirer_state_code acquirer_region    acquirer_city acquired_at  \
# 1                      CA     Los Angeles    Beverly Hills  2008-09-16
# 3                      FL    Palm Beaches  West Palm Beach  2011-01-01
# 7                      WA         Seattle          Seattle  2012-02-02
# 8                      FL           Tampa          Oldsmar  2006-01-01
# 10                     WA         Seattle          Seattle  2012-09-22
# ...                   ...             ...              ...         ...
# 13052                 NaN       Melbourne        Melbourne  2013-03-01
# 13054                  CA     SF Bay Area    San Francisco  2014-03-17
# 13055                  CA     Los Angeles   Woodland Hills  2008-08-01
# 13064                  MA          Boston           Boston  2008-02-07
# 13066                 NaN    Porto Alegre     Porto Alegre  2013-03-01
#
#       acquired_month acquired_quarter acquired_year  price_amount   \
# 1            2008-09          2008-Q3        2008.0            NaN
# 3            2011-01          2011-Q1        2011.0            NaN
# 7            2012-02          2012-Q1        2012.0      9000000.0
# 8            2006-01          2006-Q1        2006.0            NaN
# 10           2012-09          2012-Q3        2012.0            NaN
# ...              ...              ...           ...            ...
# 13052        2013-03          2013-Q1        2013.0     25000000.0
# 13054        2014-03          2014-Q1        2014.0            NaN
# 13055        2008-08          2008-Q3        2008.0        62000.0
# 13064        2008-02          2008-Q1        2008.0            NaN
# 13066        2013-03          2013-Q1        2013.0            NaN
#
#        price_currency_code
# 1                      USD
# 3                      USD
# 7                      USD
# 8                      USD
# 10                     USD
# ...                    ...
# 13052                  AUD
# 13054                  USD
# 13055                  USD
# 13064                  USD
# 13066                  USD
#
# [3286 rows x 22 columns]
# ==========================================================================
# COMPANY_CITY
# VALUE COUNTS
# San Francisco           584
# New York                516
# London                  274
# Mountain View           161
# Seattle                 153
#                        ...
# Ft Mitchell               1
# Niantic                   1
# Hendersonville            1
# Weinstadt-endersbach      1
# Hillerød                  1
# Name: company_city, Length: 1816, dtype: int64
#
#
# DUPLICATE COUNTS
# 11252
#
#
# NULL COUNTS AND PERCENTAGE
# 3485
# 26.66615655367664
#
#
# NULL ROWS
#                        company_permalink         company_name  \
# 1            /organization/fluff-friends       (fluff)Friends
# 3        /organization/vandaele-holdings                    .
# 7          /organization/0958572-b-c-ltd    0958572 B.C. Ltd.
# 8      /organization/1-nation-technology  1 Nation Technology
# 10            /organization/1000-markets         1000 Markets
# ...                                  ...                  ...
# 13052                 /organization/zuji                 Zuji
# 13054                /organization/zulip                Zulip
# 13055           /organization/zuneboards           ZuneBoards
# 13064                 /organization/zync                 Zync
# 13066          /organization/zynk-mobile          Zynk Mobile
#
#                company_category_list       company_market  \
# 1                                NaN                  NaN
# 3                                NaN                  NaN
# 7                                NaN                  NaN
# 8                                NaN                  NaN
# 10     |Marketplaces|Art|E-Commerce|         Marketplaces
# ...                              ...                  ...
# 13052                            NaN                  NaN
# 13054          |Enterprise Software|  Enterprise Software
# 13055          |Hardware + Software|  Hardware + Software
# 13064                  |Curated Web|          Curated Web
# 13066                            NaN                  NaN
#
#       company_country_code company_state_code company_region company_city  \
# 1                      NaN                NaN            NaN          NaN
# 3                      NaN                NaN            NaN          NaN
# 7                      NaN                NaN            NaN          NaN
# 8                      NaN                NaN            NaN          NaN
# 10                     NaN                NaN            NaN          NaN
# ...                    ...                ...            ...          ...
# 13052                  NaN                NaN            NaN          NaN
# 13054                  NaN                NaN            NaN          NaN
# 13055                  NaN                NaN            NaN          NaN
# 13064                  NaN                NaN            NaN          NaN
# 13066                  NaN                NaN            NaN          NaN
#
#                                       acquirer_permalink  \
# 1                    /organization/social-gaming-network
# 3                                     /organization/hi7e
# 7      /organization/atlas-intellectual-property-mana...
# 8                                   /organization/vology
# 10                                /organization/bonanzle
# ...                                                  ...
# 13052                        /organization/webjet-com-au
# 13054                              /organization/dropbox
# 13055                          /organization/crowdgather
# 13064                            /organization/where-com
# 13066                               /organization/zenvia
#
#                                     acquirer_name  ... acquirer_country_code  \
# 1                     SGN (Social Gaming Network)  ...                   USA
# 3                                            HI7E  ...                   USA
# 7      ATLAS Intellectual Property Management Co.  ...                   USA
# 8                                          Vology  ...                   USA
# 10                                        Bonanza  ...                   USA
# ...                                           ...  ...                   ...
# 13052                               Webjet.com.au  ...                   AUS
# 13054                                     Dropbox  ...                   USA
# 13055                                 CrowdGather  ...                   USA
# 13064                                       Where  ...                   USA
# 13066                                      Zenvia  ...                   BRA
#
#       acquirer_state_code acquirer_region    acquirer_city acquired_at  \
# 1                      CA     Los Angeles    Beverly Hills  2008-09-16
# 3                      FL    Palm Beaches  West Palm Beach  2011-01-01
# 7                      WA         Seattle          Seattle  2012-02-02
# 8                      FL           Tampa          Oldsmar  2006-01-01
# 10                     WA         Seattle          Seattle  2012-09-22
# ...                   ...             ...              ...         ...
# 13052                 NaN       Melbourne        Melbourne  2013-03-01
# 13054                  CA     SF Bay Area    San Francisco  2014-03-17
# 13055                  CA     Los Angeles   Woodland Hills  2008-08-01
# 13064                  MA          Boston           Boston  2008-02-07
# 13066                 NaN    Porto Alegre     Porto Alegre  2013-03-01
#
#       acquired_month acquired_quarter acquired_year  price_amount   \
# 1            2008-09          2008-Q3        2008.0            NaN
# 3            2011-01          2011-Q1        2011.0            NaN
# 7            2012-02          2012-Q1        2012.0      9000000.0
# 8            2006-01          2006-Q1        2006.0            NaN
# 10           2012-09          2012-Q3        2012.0            NaN
# ...              ...              ...           ...            ...
# 13052        2013-03          2013-Q1        2013.0     25000000.0
# 13054        2014-03          2014-Q1        2014.0            NaN
# 13055        2008-08          2008-Q3        2008.0        62000.0
# 13064        2008-02          2008-Q1        2008.0            NaN
# 13066        2013-03          2013-Q1        2013.0            NaN
#
#        price_currency_code
# 1                      USD
# 3                      USD
# 7                      USD
# 8                      USD
# 10                     USD
# ...                    ...
# 13052                  AUD
# 13054                  USD
# 13055                  USD
# 13064                  USD
# 13066                  USD
#
# [3485 rows x 22 columns]
# ==========================================================================
# ACQUIRER_PERMALINK
# VALUE COUNTS
# /organization/cisco                     168
# /organization/google                    165
# /organization/microsoft                 156
# /organization/ibm                       122
# /organization/yahoo                     116
#                                        ...
# /organization/wunderman                   1
# /organization/savvis                      1
# /organization/nuvotv                      1
# /organization/diigo                       1
# /organization/chiesi-pharmaceuticals      1
# Name: acquirer_permalink, Length: 6632, dtype: int64
#
#
# DUPLICATE COUNTS
# 6437
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, acquirer_permalink, acquirer_name, acquirer_category_list, acquirer_market, acquirer_country_code, acquirer_state_code, acquirer_region, acquirer_city, acquired_at, acquired_month, acquired_quarter, acquired_year,  price_amount , price_currency_code]
# Index: []
#
# [0 rows x 22 columns]
# ==========================================================================
# ACQUIRER_NAME
# VALUE COUNTS
# Cisco                               168
# Google                              165
# Microsoft                           156
# IBM                                 122
# Yahoo!                              116
#                                    ...
# CenturyLink Technology Solutions      1
# nuvoTV                                1
# Diigo                                 1
# LookSmart                             1
# Chiesi Pharmaceuticals                1
# Name: acquirer_name, Length: 6629, dtype: int64
#
#
# DUPLICATE COUNTS
# 6440
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, acquirer_permalink, acquirer_name, acquirer_category_list, acquirer_market, acquirer_country_code, acquirer_state_code, acquirer_region, acquirer_city, acquired_at, acquired_month, acquired_quarter, acquired_year,  price_amount , price_currency_code]
# Index: []
#
# [0 rows x 22 columns]
# ==========================================================================
# ACQUIRER_CATEGORY_LIST
# VALUE COUNTS
# |Software|                                                                                                              1137
# |Biotechnology|                                                                                                          459
# |Enterprise Software|                                                                                                    304
# |Curated Web|                                                                                                            303
# |Hardware + Software|                                                                                                    297
#                                                                                                                         ...
# |Collaboration|Marketplaces|Textbooks|Publishing|E-Commerce|                                                               1
# |Startups|Software|Business Services|Consulting|                                                                           1
# |Social Media Marketing|Facebook Applications|SEO|Web Hosting|Health and Insurance|Development Platforms|E-Commerce|       1
# |Consumer Lending|Banking|Personal Finance|                                                                                1
# |Travel & Tourism|Hotels|Travel|                                                                                           1
# Name: acquirer_category_list, Length: 2371, dtype: int64
#
#
# DUPLICATE COUNTS
# 10697
#
#
# NULL COUNTS AND PERCENTAGE
# 1504
# 11.508149055015686
#
#
# NULL ROWS
#                                  company_permalink  \
# 3                  /organization/vandaele-holdings
# 5                          /organization/vantronix
# 8                /organization/1-nation-technology
# 23     /organization/1st-choice-security-solutions
# 35                    /organization/24-7-solutions
# ...                                            ...
# 13018                         /organization/zipcar
# 13029                      /organization/zitra-com
# 13034                          /organization/zoidu
# 13051                            /organization/zui
# 13059               /organization/zygo-corporation
#
#                         company_name  \
# 3                                  .
# ...
#
#        price_currency_code
# 5                      USD
# 14                     USD
# 35                     USD
# 47                     USD
# 49                     USD
# ...                    ...
# 12981                  USD
# 13006                  USD
# 13018                  USD
# 13058                  EUR
# 13067                  USD
#
# [960 rows x 22 columns]
# ==========================================================================
# ACQUIRED_AT
# VALUE COUNTS
# 2011-01-01    96
# 2012-01-01    73
# 2008-05-01    59
# 2010-01-01    42
# 2013-01-01    42
#               ..
# 2004-10-10     1
# 2009-10-10     1
# 1999-01-04     1
# 2005-10-17     1
# 1999-07-07     1
# Name: acquired_at, Length: 3078, dtype: int64
#
#
# DUPLICATE COUNTS
# 9991
#
#
# NULL COUNTS AND PERCENTAGE
# 0
# 0.0
#
#
# NULL ROWS
# Empty DataFrame
# Columns: [company_permalink, company_name, company_category_list, company_market, company_country_code, company_state_code, company_region, company_city, acquirer_permalink, acquirer_name, acquirer_category_list, acquirer_market, acquirer_country_code, acquirer_state_code, acquirer_region, acquirer_city, acquired_at, acquired_month, acquired_quarter, acquired_year,  price_amount , price_currency_code]
# Index: []
#
# [0 rows x 22 columns]
# ==========================================================================
# ACQUIRED_MONTH
# VALUE COUNTS
# 2014-06    260
# 2014-07    246
# 2011-01    244
# 2014-10    242
# 2014-09    230
#           ...
# 1991-12      1
# 1989-04      1
# 1998-05      1
# 1995-04      1
# 1998-02      1
# Name: acquired_month, Length: 279, dtype: int64
#
#
# DUPLICATE COUNTS
# 12789
#
#
# NULL COUNTS AND PERCENTAGE
# 2
# 0.01530338970081873
#
#
# NULL ROWS
#                company_permalink company_name  \
# 3093   /organization/datapad-inc      DataPad
# 11206   /organization/tastykhana   TastyKhana
#
#                                    company_category_list company_market  \
# 3093   |Big Data Analytics|Business Intelligence|Big ...      Analytics
# 11206                                       |E-Commerce|     E-Commerce
#
#       company_country_code company_state_code company_region   company_city  \
# 3093                   USA                 CA    SF Bay Area  San Francisco
# 11206                  IND                NaN           Pune           Pune
#
#             acquirer_permalink          acquirer_name  ...  \
# 3093    /organization/cloudera               Cloudera  ...
# 11206  /organization/foodpanda  foodpanda / hellofood  ...
#
#       acquirer_country_code acquirer_state_code acquirer_region acquirer_city  \
# 3093                    USA                  CA     SF Bay Area     Palo Alto
# 11206                   DEU                 NaN          Berlin        Berlin
#
#       acquired_at acquired_month acquired_quarter acquired_year  \
# 3093   0030-09-14            NaN              NaN           NaN
# 11206  0017-11-14            NaN              NaN           NaN
#
#        price_amount   price_currency_code
# 3093             NaN                  USD
# 11206            NaN                  USD
#
# [2 rows x 22 columns]
# ==========================================================================
# ACQUIRED_QUARTER
# VALUE COUNTS
# 2014-Q3    681
# 2014-Q2    661
# 2014-Q1    561
# 2013-Q4    527
# 2011-Q1    520
#           ...
# 1980-Q1      1
# 1984-Q3      1
# 1989-Q2      1
# 1977-Q1      1
# 1967-Q2      1
# Name: acquired_quarter, Length: 111, dtype: int64
#
#
# DUPLICATE COUNTS
# 12957
#
#
# NULL COUNTS AND PERCENTAGE
# 2
# 0.01530338970081873
#
#
# NULL ROWS
#                company_permalink company_name  \
# 3093   /organization/datapad-inc      DataPad
# 11206   /organization/tastykhana   TastyKhana
#
#                                    company_category_list company_market  \
# 3093   |Big Data Analytics|Business Intelligence|Big ...      Analytics
# 11206                                       |E-Commerce|     E-Commerce
#
#       company_country_code company_state_code company_region   company_city  \
# 3093                   USA                 CA    SF Bay Area  San Francisco
# 11206                  IND                NaN           Pune           Pune
#
#             acquirer_permalink          acquirer_name  ...  \
# 3093    /organization/cloudera               Cloudera  ...
# 11206  /organization/foodpanda  foodpanda / hellofood  ...
#
#       acquirer_country_code acquirer_state_code acquirer_region acquirer_city  \
# 3093                    USA                  CA     SF Bay Area     Palo Alto
# 11206                   DEU                 NaN          Berlin        Berlin
#
#       acquired_at acquired_month acquired_quarter acquired_year  \
# 3093   0030-09-14            NaN              NaN           NaN
# 11206  0017-11-14            NaN              NaN           NaN
#
#        price_amount   price_currency_code
# 3093             NaN                  USD
# 11206            NaN                  USD
#
# [2 rows x 22 columns]
# ==========================================================================
# ACQUIRED_YEAR
# VALUE COUNTS
# 2014.0    2351
# 2011.0    1814
# 2013.0    1771
# 2010.0    1583
# 2012.0    1553
# 2009.0    1172
# 2008.0    1100
# 2007.0     473
# 2006.0     289
# 2005.0     203
# 2004.0     139
# 1999.0     102
# 2000.0      95
# 2003.0      76
# 2002.0      71
# 2001.0      67
# 1998.0      48
# 1997.0      40
# 1996.0      33
# 1995.0      24
# 1994.0      11
# 1993.0      11
# 1988.0       7
# 1991.0       6
# 1992.0       5
# 1987.0       4
# 1990.0       3
# 1989.0       3
# 1981.0       2
# 1984.0       2
# 1960.0       2
# 1986.0       2
# 1977.0       1
# 1980.0       1
# 1973.0       1
# 1982.0       1
# 1967.0       1
# Name: acquired_year, dtype: int64
#
#
# DUPLICATE COUNTS
# 13031
#
#
# NULL COUNTS AND PERCENTAGE
# 2
# 0.01530338970081873
#
#
# NULL ROWS
#                company_permalink company_name  \
# 3093   /organization/datapad-inc      DataPad
# 11206   /organization/tastykhana   TastyKhana
#
#                                    company_category_list company_market  \
# 3093   |Big Data Analytics|Business Intelligence|Big ...      Analytics
# 11206                                       |E-Commerce|     E-Commerce
#
#       company_country_code company_state_code company_region   company_city  \
# 3093                   USA                 CA    SF Bay Area  San Francisco
# 11206                  IND                NaN           Pune           Pune
#
#             acquirer_permalink          acquirer_name  ...  \
# 3093    /organization/cloudera               Cloudera  ...
# 11206  /organization/foodpanda  foodpanda / hellofood  ...
#
#       acquirer_country_code acquirer_state_code acquirer_region acquirer_city  \
# 3093                    USA                  CA     SF Bay Area     Palo Alto
# 11206                   DEU                 NaN          Berlin        Berlin
#
#       acquired_at acquired_month acquired_quarter acquired_year  \
# 3093   0030-09-14            NaN              NaN           NaN
# 11206  0017-11-14            NaN              NaN           NaN
#
#        price_amount   price_currency_code
# 3093             NaN                  USD
# 11206            NaN                  USD
#
# [2 rows x 22 columns]
# ==========================================================================
#  PRICE_AMOUNT
# VALUE COUNTS
# 1.000000e+07    56
# 3.000000e+07    52
# 1.000000e+08    51
# 5.000000e+07    49
# 2.000000e+07    47
#                 ..
# 5.460000e+08     1
# 2.260000e+07     1
# 1.170000e+09     1
# 5.240000e+07     1
# 6.200000e+04     1
# Name:  price_amount , Length: 1311, dtype: int64
#
#
# DUPLICATE COUNTS
# 11757
#
#
# NULL COUNTS AND PERCENTAGE
# 9358
# 71.60456041013084
#
#
# NULL ROWS
#                      company_permalink    company_name  \
# 0                /organization/waywire        #waywire
# 1          /organization/fluff-friends  (fluff)Friends
# 3      /organization/vandaele-holdings               .
# 5              /organization/vantronix      .vantronix
# 6                 /organization/003-ru          003.RU
# ...                                ...             ...
# 13063           /organization/zynamics        zynamics
# 13064               /organization/zync            Zync
# 13065        /organization/zync-render     Zync Render
# 13066        /organization/zynk-mobile     Zynk Mobile
# 13067             /organization/zyrion      Zyrion Inc
#
#                             company_category_list  company_market  \
# 0      |Entertainment|Politics|Social Media|News|            News
# 1                                             NaN             NaN
# 3                                             NaN             NaN
# 5      |Cloud Security|Network Security|Security|  Cloud Security
# 6                                             NaN             NaN
# ...                                           ...             ...
# 13063                                  |Security|        Security
# 13064                               |Curated Web|     Curated Web
# 13065                             |Digital Media|   Digital Media
# 13066                                         NaN             NaN
# 13067                       |Networking|Software|        Software
#
#       company_country_code company_state_code company_region company_city  \
# 0                      USA                 NY  New York City     New York
# 1                      NaN                NaN            NaN          NaN
# 3                      NaN                NaN            NaN          NaN
# 5                      DEU                NaN        Hanover      Hanover
# 6                      RUS                NaN         Moscow       Moscow
# ...                    ...                ...            ...          ...
# 13063                  DEU                NaN         Bochum       Bochum
# 13064                  NaN                NaN            NaN          NaN
# 13065                  USA                 MA         Boston       Boston
# 13066                  NaN                NaN            NaN          NaN
# 13067                  USA                 CA    SF Bay Area    Sunnyvale
#
#                         acquirer_permalink                acquirer_name  ...  \
# 0                    /organization/magnify             Waywire Networks  ...
# 1      /organization/social-gaming-network  SGN (Social Gaming Network)  ...
# 3                       /organization/hi7e                         HI7E  ...
# 5                /organization/compumatica                  Compumatica  ...
# 6               /organization/media-saturn                 Media Saturn  ...
# ...                                    ...                          ...  ...
# 13063                 /organization/google                       Google  ...
# 13064              /organization/where-com                        Where  ...
# 13065                 /organization/google                       Google  ...
# 13066                 /organization/zenvia                       Zenvia  ...
# 13067                 /organization/kaseya                       Kaseya  ...
#
#       acquirer_country_code acquirer_state_code acquirer_region  \
# 0                       USA                  NY   New York City
# 1                       USA                  CA     Los Angeles
# 3                       USA                  FL    Palm Beaches
# 5                       NaN                 NaN             NaN
# 6                       ESP                 NaN       Barcelona
# ...                     ...                 ...             ...
# 13063                   USA                  CA     SF Bay Area
# 13064                   USA                  MA          Boston
# 13065                   USA                  CA     SF Bay Area
# 13066                   BRA                 NaN    Porto Alegre
# 13067                   NaN                 NaN             NaN
#
#          acquirer_city acquired_at acquired_month acquired_quarter  \
# 0             New York  2013-10-17        2013-10          2013-Q4
# 1        Beverly Hills  2008-09-16        2008-09          2008-Q3
# 3      West Palm Beach  2011-01-01        2011-01          2011-Q1
# 5                  NaN  2011-01-01        2011-01          2011-Q1
# 6            Barcelona  2012-07-23        2012-07          2012-Q3
# ...                ...         ...            ...              ...
# 13063    Mountain View  2011-03-01        2011-03          2011-Q1
# 13064           Boston  2008-02-07        2008-02          2008-Q1
# 13065    Mountain View  2014-08-26        2014-08          2014-Q3
# 13066     Porto Alegre  2013-03-01        2013-03          2013-Q1
# 13067              NaN  2013-06-25        2013-06          2013-Q2
#
#       acquired_year  price_amount   price_currency_code
# 0            2013.0            NaN                  USD
# 1            2008.0            NaN                  USD
# 3            2011.0            NaN                  USD
# 5            2011.0            NaN                  USD
# 6            2012.0            NaN                  USD
# ...             ...            ...                  ...
# 13063        2011.0            NaN                  USD
# 13064        2008.0            NaN                  USD
# 13065        2014.0            NaN                  USD
# 13066        2013.0            NaN                  USD
# 13067        2013.0            NaN                  USD
#
# [9358 rows x 22 columns]
# ==========================================================================
# PRICE_CURRENCY_CODE
# VALUE COUNTS
# USD    12800
# EUR      115
# GBP      108
# CAD       16
# AUD       10
# JPY        7
# SEK        4
# NZD        2
# NOK        1
# AZN        1
# SAR        1
# Name: price_currency_code, dtype: int64
#
#
# DUPLICATE COUNTS
# 13057
#
#
# NULL COUNTS AND PERCENTAGE
# 4
# 0.03060677940163746
#
#
# NULL ROWS
#                company_permalink company_name  \
# 784    /organization/anywhere-fm  Anywhere.FM
# 6615      /organization/local2me     Local2Me
# 10504       /organization/snocap       Snocap
# 12842      /organization/xiaonei      Xiaonei
#
#                                    company_category_list  \
# 784                                              |Music|
# 6615                                 |Local|Advertising|
# 10504  |Content|Social Network Media|Peer-to-Peer|Games|
# 12842     |Networking|Facebook Applications|Curated Web|
#
#               company_market company_country_code company_state_code  \
# 784                    Music                  NaN                NaN
# 6615                   Local                  USA                 CA
# 10504                  Games                  USA                 CA
# 12842  Facebook Applications                  CHN                NaN
#
#       company_region   company_city        acquirer_permalink acquirer_name  \
# 784              NaN            NaN       /organization/imeem         imeem
# 6615     SF Bay Area      San Mateo   /organization/smalltown     Smalltown
# 10504    SF Bay Area  San Francisco       /organization/imeem         imeem
# 12842    CHN - Other            NaN  /organization/renren-inc   Renren Inc.
#
#        ... acquirer_country_code acquirer_state_code acquirer_region  \
# 784    ...                   USA                  CA     SF Bay Area
# 6615   ...                   USA                  CA     SF Bay Area
# 10504  ...                   USA                  CA     SF Bay Area
# 12842  ...                   CHN                 NaN     CHN - Other
#
#        acquirer_city acquired_at acquired_month acquired_quarter  \
# 784    San Francisco  2008-01-28        2008-01          2008-Q1
# 6615       San Mateo  2007-12-01        2007-12          2007-Q4
# 10504  San Francisco  2008-02-01        2008-02          2008-Q1
# 12842       Chaoyang  2006-10-24        2006-10          2006-Q4
#
#       acquired_year  price_amount   price_currency_code
# 784          2008.0            NaN                  NaN
# 6615         2007.0            NaN                  NaN
# 10504        2008.0            NaN                  NaN
# 12842        2006.0            NaN                  NaN
#
# [4 rows x 22 columns]

# %% [markdown]
# #Additional Tests for Data Analysis and Entity Resolution Understanding

# %%
mergeI = pd.merge(companies[['permalink']], investments[['investor_permalink']], left_on='permalink', right_on='investor_permalink', how='outer', indicator=True)
mergeI = mergeI[mergeI['_merge'] == 'both']
mergeI
# Out:
#                       permalink        investor_permalink _merge
# 67     /organization/1c-company  /organization/1c-company   both
# 107      /organization/21vianet    /organization/21vianet   both
# 136     /organization/2b-angels   /organization/2b-angels   both
# 137     /organization/2b-angels   /organization/2b-angels   both
# 138     /organization/2b-angels   /organization/2b-angels   both
# ...                         ...                       ...    ...
# 52606      /organization/zipcar      /organization/zipcar   both
# 52607      /organization/zipcar      /organization/zipcar   both
# 52717    /organization/zoominfo    /organization/zoominfo   both
# 52778      /organization/zulily      /organization/zulily   both
# 52779      /organization/zulily      /organization/zulily   both
#
# [3937 rows x 3 columns]

# %%
mergeA = pd.merge(companies[['permalink']], acquisitions[['acquirer_permalink']], left_on='permalink', right_on='acquirer_permalink', how='outer', indicator=True)
mergeA = mergeA[mergeA['_merge'] == 'both']
mergeA
# Out:
#                             permalink              acquirer_permalink _merge
# 38        /organization/11i-solutions     /organization/11i-solutions   both
# 39        /organization/11i-solutions     /organization/11i-solutions   both
# 68           /organization/1c-company        /organization/1c-company   both
# 91              /organization/1stdibs           /organization/1stdibs   both
# 94        /organization/1world-online     /organization/1world-online   both
# ...                               ...                             ...    ...
# 52170             /organization/zynga             /organization/zynga   both
# 52171             /organization/zynga             /organization/zynga   both
# 52175  /organization/zyraz-technology  /organization/zyraz-technology   both
# 52182                 /organization/x                 /organization/x   both
# 52183                 /organization/x                 /organization/x   both
#
# [4894 rows x 3 columns]

# %%
mergeA = pd.merge(investments[['investor_permalink']], acquisitions[['acquirer_permalink']], left_on='investor_permalink', right_on='acquirer_permalink', how='outer', indicator=True)
mergeA = mergeA[mergeA['_merge'] != 'both']
mergeA
# Out:
#                                   investor_permalink  \
# 0                           /person/jamessss-bondddd
# 1                                 /organization/ekaf
# 2                            /person/antonio-murroni
# 3                            /person/filippo-murroni
# 4       /organization/crp-companhia-de-participacoes
# ...                                              ...
# 172772                                           NaN
# 172773                                           NaN
# 172774                                           NaN
# 172775                                           NaN
# 172776                                           NaN
#
#                           acquirer_permalink      _merge
# 0                                        NaN   left_only
# 1                                        NaN   left_only
# 2                                        NaN   left_only
# 3                                        NaN   left_only
# 4                                        NaN   left_only
# ...                                      ...         ...
# 172772           /organization/webjet-com-au  right_only
# 172773   /organization/nestle-purina-petcare  right_only
# 172774         /organization/cupcake-digital  right_only
# 172775                /organization/withings  right_only
# 172776  /organization/chiesi-pharmaceuticals  right_only
#
# [118761 rows x 3 columns]

# %%
agg = rounds.groupby('company_permalink').sum().reset_index(drop=False)[['company_permalink', ' raised_amount_usd ']]
agg = pd.merge(companies[['permalink', ' funding_total_usd ']], agg, left_on='permalink', right_on='company_permalink', how='outer', indicator=True)
agg

check = agg[agg['_merge'] != 'both']
print(len(check))
check

def replace_null(x):
  if x == 0.0:
    return np.nan
  else:
    return x
# found out that prysm is duplicate
both = agg[agg['_merge'] == 'both']
#both[' raised_amount_usd '] = both[' raised_amount_usd '].apply(lambda x: replace_null(x))
both = both[both[' funding_total_usd '] != both[' raised_amount_usd ']]
both = both.sort_values(by=' raised_amount_usd ', ascending=False)
both = both[both[' raised_amount_usd '] != 0.0]
both
# Out:
# 35
#                                         permalink   funding_total_usd   \
# 34074                  /organization/pure-storage          534856468.0
# 33939                         /organization/prysm          145521193.0
# 33940                         /organization/prysm          147558930.0
# 31086  /organization/oxford-nanopore-technologies          270725149.0
# 40911                        /organization/stripe          120000000.0
# ...                                           ...                  ...
# 29330                          /organization/niwa             200000.0
# 37387                     /organization/seesearch              27181.0
# 45238                        /organization/urbita             675000.0
# 4228                        /organization/babbaco            4525000.0
# 29277                    /organization/nimbus-llc              10000.0
#
#                                 company_permalink   raised_amount_usd  _merge
# 34074                  /organization/pure-storage          474856468.0   both
# 33939                         /organization/prysm          293080123.0   both
# 33940                         /organization/prysm          293080123.0   both
# 31086  /organization/oxford-nanopore-technologies          211725149.0   both
# 40911                        /organization/stripe          190000000.0   both
# ...                                           ...                  ...    ...
# 29330                          /organization/niwa             150000.0   both
# 37387                     /organization/seesearch              54362.0   both
# 45238                        /organization/urbita              25000.0   both
# 4228                        /organization/babbaco              25000.0   both
# 29277                    /organization/nimbus-llc              20000.0   both
#
# [79 rows x 5 columns]

# %% [markdown]
# #Creation of Tables according to our Schema

# %% [markdown]
# ## Plan for cleaning
#
# 1.   Preliminary cleaning of companies, investments, rounds
# and acquisitions.
# 2.   Next, using the companies table, I create a company_entity for the financial_entity
# 3. I create investor_entity using the investments table
# 4. I create the acquirer entity from the acquisitions table
# 5. Original Rounds table contains after being merged on funding_round_permalink has three cases (post checking with original companies) -
#   *   companies in round but not in original companies - need to add to company_entity
#   *   Companies in original but not in rounds - nothing to be done
#   *   investor as null for the round post merging - needs to be imputed to unknown in both the final rounds table and investor_entity
# 6. Acquisitions after checking merge with original companies has companies that are in acquisitions table that are not in original companies - needs to be added to company_entity
#
# 7. Finally need to combine all three (and update is_a accordingly if an entity is more than one of the three)
#
# 8. Give them a unique integer ID

# %% [markdown]
# ##Cleaning up Companies

# %% [markdown]
# ###Fixing category_list

# %%
def reformat_lists(x):
  if x is np.nan:
    return 'unknown'
  x = str(x)
  x = x.replace("|","   ")
  x = x.strip()
  x = x.replace("   ",", ")
  return x

companies['category_list'] = companies['category_list'].apply(lambda x: reformat_lists(x))

# %% [markdown]
# ###Fixing Permalink duplicates

# %%
companies.at[33940, 'funding_rounds'] = 4
companies.at[33940, 'last_funding_at'] = '2014-11-25'
companies.at[33940, ' funding_total_usd '] = 100000000.0 + 44808930.0 + 2750000.0 + 145521193
companies[companies.duplicated(subset='permalink', keep='first')]

companies.at[44033, 'funding_rounds'] = 5
companies.at[44033, 'last_funding_at'] = '2014-07-18'
companies.at[44033, ' funding_total_usd '] = 286873.0 + 45321.0

companies = companies.drop(33939)
companies = companies.drop(44034)

# %%
companies = companies.reset_index(drop=False)

# %% [markdown]
# ###Filling name null

# %%
companies.at[28221, 'name'] = 'Tell-IT'

# %% [markdown]
# ###Filling Status nulls

# %%
def replace_nan_status(x):
  if x is np.nan:
    return 'unknown'
  else:
    return x

companies['status'] = companies['status'].apply(lambda x: replace_nan_status(x))

# %% [markdown]
# ###Changing date to Datetime dtype and formatted

# %%
companies['founded_at'] = pd.to_datetime(companies['founded_at'],format='%Y-%m-%d', errors = 'coerce')

# %% [markdown]
# ##Cleaning Investments

# %% [markdown]
# ###Fixing investor_category_list

# %%
investments['investor_category_list'] = investments['investor_category_list'].apply(lambda x: reformat_lists(x))

# %% [markdown]
# ###Resolving null investor_permalink

# %% [markdown]
# 66 investors were imputed to as unknowns because they were nulls, and investor permalink cannot be null

# %%
nulls = investments[investments['investor_permalink'].isna()]
index = nulls.index

investor_impute_count = 1
for i in index:
  investments.at[i, 'investor_permalink'] = 'unknown' + str(investor_impute_count)
  investments.at[i, 'investor_name'] = 'unknown'
  investor_impute_count+=1

# %% [markdown]
# ###Creating isPerson column

# %%
def create_is_person(x):
  if 'organization' in x:
    return "False"
  elif 'person' in x:
    return "True"
  else:
    return np.nan

investments['is_person'] = investments['investor_permalink'].apply(lambda x: create_is_person(x))

# %% [markdown]
# ##Cleaning Acquisitions

# %% [markdown]
# ###Fixing acquirer_category_list

# %%
acquisitions['acquirer_category_list'] = acquisitions['acquirer_category_list'].apply(lambda x: reformat_lists(x))

# %% [markdown]
# ###Fixing null price_currency_code

# %%
nulls = acquisitions[acquisitions['price_currency_code'].isna()]
index = nulls.index

for i in index:
  acquisitions.at[i, 'price_currency_code'] = 'USD'

acquisitions.at[12842, 'price_currency_code'] = 'CNY'

# %% [markdown]
# ###Converting acquired_at to datetime

# %%
acquisitions['acquired_at'] = pd.to_datetime(acquisitions['acquired_at'],format='%Y-%m-%d', errors = 'coerce')

# %% [markdown]
# ##Cleaning Rounds

# %% [markdown]
# ###Converting funded_at to datetime

# %%
rounds['funded_at'] = pd.to_datetime(rounds['funded_at'],format='%Y-%m-%d', errors = 'coerce')

# %% [markdown]
# ###Creating round_number

# %%
rounds['round_number'] = np.arange(len(rounds))

# %% [markdown]
# ## Creating Financial_Entity Components

# %% [markdown]
# ###Restructuring companies

# %%
company_entity = companies[['permalink', 'name', 'category_list', ' market ',  'country_code', 'state_code', 'city']]
company_entity.insert(7, 'is_a', 'company')
company_entity = company_entity.rename(columns={'category_list': 'categories', ' market ': 'market', 'country_code': 'country', 'state_code': 'state'})


company_entity
# Out:
#                                                permalink  \
# 0                                  /organization/waywire
# 1                        /organization/tv-communications
# 2                          /organization/rock-your-paper
# 3                         /organization/in-touch-network
# 4                         /organization/r-ranch-and-mine
# ...                                                  ...
# 49431                                /organization/zzish
# 49432  /organization/zznode-science-and-technology-co...
# 49433                          /organization/zzzzapp-com
# 49434                         /organization/a-list-games
# 49435                                    /organization/x
#
#                                 name  \
# 0                           #waywire
# 1                 &TV Communications
# 2                  'Rock' Your Paper
# 3                  (In)Touch Network
# 4                 -R- Ranch and Mine
# ...                              ...
# 49431                          Zzish
# 49432  ZZNode Science and Technology
# 49433          Zzzzapp Wireless ltd.
# 49434                  [a]list games
# 49435                          [x+1]
#
#                                               categories  \
# 0            Entertainment, Politics, Social Media, News
# 1                                                  Games
# 2                                  Publishing, Education
# 3      Electronics, Guides, Coffee, Restaurants, Musi...
# 4                          Tourism, Entertainment, Games
# ...                                                  ...
# 49431  Analytics, Gamification, Developer APIs, iOS, ...
# 49432                                Enterprise Software
# 49433     Web Development, Advertising, Wireless, Mobile
# 49434                                              Games
# 49435                                Enterprise Software
#
#                       market country state         city     is_a
# 0                      News      USA    NY     New York  company
# 1                     Games      USA    CA  Los Angeles  company
# 2                Publishing      EST   NaN      Tallinn  company
# 3               Electronics      GBR   NaN       London  company
# 4                   Tourism      USA    TX   Fort Worth  company
# ...                      ...     ...   ...          ...      ...
# 49431             Education      GBR   NaN       London  company
# 49432   Enterprise Software      CHN   NaN      Beijing  company
# 49433       Web Development      HRV   NaN        Split  company
# 49434                 Games      NaN   NaN          NaN  company
# 49435   Enterprise Software      USA    NY     New York  company
#
# [49436 rows x 8 columns]

# %% [markdown]
# ###Restructuring Investments

# %%
investor_entity = investments[['investor_permalink', 'investor_name', 'investor_category_list', 'investor_market',  'investor_country_code', 'investor_state_code', 'investor_city']]

#To see which were duplicated
#investor_entity[investor_entity.duplicated(subset='investor_permalink', keep='first')]

investor_entity = investor_entity.drop_duplicates("investor_permalink")
investor_entity.insert(7, 'is_a', 'investor')
investor_entity = investor_entity.rename(columns={'investor_permalink': 'permalink', 'investor_name': 'name','investor_category_list': 'categories', 'investor_market': 'market', 'investor_country_code': 'country', 'investor_state_code': 'state', 'investor_city': 'city'})
investor_entity
# Out:
#                                            permalink  \
# 0                           /person/jamessss-bondddd
# 1                                 /organization/ekaf
# 2                            /person/antonio-murroni
# 3                            /person/filippo-murroni
# 4       /organization/crp-companhia-de-participacoes
# ...                                              ...
# 114446                             /person/doug-cobb
# 114452                 /person/s-kris-gopalakrishnan
# 114466                /organization/dcl-ventures-inc
# 114482           /organization/math-venture-partners
# 114503                         /person/trevor-wright
#
#                                     name categories market country state  \
# 0                       jamessss bondddd    unknown    NaN     NaN   NaN
# 1                                   Ekaf    unknown    NaN     NaN   NaN
# 2                        ANTONIO MURRONI    unknown    NaN     NaN   NaN
# 3                        FILIPPO Murroni    unknown    NaN     NaN   NaN
# 4       CRP Companhia de Participações    unknown    NaN     NaN   NaN
# ...                                  ...        ...    ...     ...   ...
# 114446                         Doug Cobb    unknown    NaN     NaN   NaN
# 114452          S. "Kris" Gopalakrishnan    unknown    NaN     NaN   NaN
# 114466                DCL Ventures, Inc.       Pets   Pets     USA    NY
# 114482             Math Venture Partners    unknown    NaN     USA    IL
# 114503                     Trevor Wright    unknown    NaN     NaN   NaN
#
#             city      is_a
# 0            NaN  investor
# 1            NaN  investor
# 2            NaN  investor
# 3            NaN  investor
# 4            NaN  investor
# ...          ...       ...
# 114446       NaN  investor
# 114452       NaN  investor
# 114466  New York  investor
# 114482   Chicago  investor
# 114503       NaN  investor
#
# [22342 rows x 8 columns]

# %% [markdown]
# ###Restructuring Acquisitions

# %%
acquirer_entity = acquisitions[['acquirer_permalink', 'acquirer_name', 'acquirer_category_list', 'acquirer_market',  'acquirer_country_code', 'acquirer_state_code', 'acquirer_city']]

#To see which were duplicated
#acquirer_entity[acquirer_entity.duplicated(subset='acquirer_permalink', keep='first')]

acquirer_entity.insert(7, 'is_a', 'acquirer')
acquirer_entity = acquirer_entity.drop_duplicates("acquirer_permalink")


acquirer_entity = acquirer_entity.rename(columns={'acquirer_permalink': 'permalink', 'acquirer_name': 'name','acquirer_category_list': 'categories', 'acquirer_market': 'market', 'acquirer_country_code': 'country', 'acquirer_state_code': 'state', 'acquirer_city': 'city'})
acquirer_entity
# Out:
#                                         permalink  \
# 0                           /organization/magnify
# 1             /organization/social-gaming-network
# 2      /organization/nationstar-mortgage-holdings
# 3                              /organization/hi7e
# 4                           /organization/neustar
# ...                                           ...
# 13052                 /organization/webjet-com-au
# 13053         /organization/nestle-purina-petcare
# 13056               /organization/cupcake-digital
# 13060                      /organization/withings
# 13062        /organization/chiesi-pharmaceuticals
#
#                                name  \
# 0                  Waywire Networks
# 1       SGN (Social Gaming Network)
# 2      Nationstar Mortgage Holdings
# 3                              HI7E
# 4                           Neustar
# ...                             ...
# 13052                 Webjet.com.au
# 13053         Nestle Purina Petcare
# 13056               Cupcake Digital
# 13060                      Withings
# 13062        Chiesi Pharmaceuticals
#
#                                               categories               market  \
# 0                                     Curated Web, Video          Curated Web
# 1                                                  Games                Games
# 2                                                Finance              Finance
# 3                                                unknown                  NaN
# 4      Telecommunications, Analytics, Information Tec...            Analytics
# ...                                                  ...                  ...
# 13052                   Travel & Tourism, Hotels, Travel     Travel & Tourism
# 13053                                               Pets                 Pets
# 13056                                              Games                Games
# 13060                                Hardware + Software  Hardware + Software
# 13062                                      Biotechnology        Biotechnology
#
#       country state                 city      is_a
# 0         USA    NY             New York  acquirer
# 1         USA    CA        Beverly Hills  acquirer
# 2         USA    TX           Lewisville  acquirer
# 3         USA    FL      West Palm Beach  acquirer
# 4         USA    VA             Sterling  acquirer
# ...       ...   ...                  ...       ...
# 13052     AUS   NaN            Melbourne  acquirer
# 13053     USA    MO             St Louis  acquirer
# 13056     USA    NY             New York  acquirer
# 13060     FRA   NaN  Issy-les-moulineaux  acquirer
# 13062     ITA   NaN                Parma  acquirer
#
# [6632 rows x 8 columns]

# %% [markdown]
# ##Round

# %%
round_schema = pd.merge(rounds[['company_permalink','funding_round_permalink', 'funding_round_type', ' raised_amount_usd ', 'funded_at', 'round_number']], investments[['investor_permalink','funding_round_permalink']], left_on='funding_round_permalink', right_on='funding_round_permalink', how='outer', indicator=True)

# %% [markdown]
# ###Fixing Investor Nulls

# %% [markdown]
# Imputing investor permalinks in cases where a funding round does not have a investor associated with it --> setting investor to be unknown. Adding newly created values to investor entity as well.

# %%
# Get a list of all funding_round_permalinks that have this problem
problematic_funding_rounds = round_schema[round_schema['_merge'] == 'left_only'].index
print(problematic_funding_rounds)
count = 67
for i in problematic_funding_rounds:
  round_schema.at[i, 'investor_permalink'] = 'unknown' + str(count)
  investor_entity = investor_entity.append({'permalink': ('unknown' + str(count)), 'name': 'unknown', 'is_a': 'investor' }, ignore_index=True)
  count += 1



round_schema[round_schema['_merge'] == 'left_only']
# Out:
# Int64Index([     6,      7,      9,     10,     11,     12,     18,     21,
#                 22,     23,
#             ...
#             148061, 148062, 148063, 148064, 148068, 148074, 148075, 148081,
#             148082, 148095],
#            dtype='int64', length=33590)
#                       company_permalink  \
# 6       /organization/tv-communications
# 7       /organization/tv-communications
# 9        /organization/in-touch-network
# 10       /organization/r-ranch-and-mine
# 11       /organization/r-ranch-and-mine
# ...                                 ...
# 148074              /organization/zyrra
# 148075              /organization/zyrra
# 148081        /organization/zzzzapp-com
# 148082        /organization/zzzzapp-com
# 148095                  /organization/x
#
#                                 funding_round_permalink   funding_round_type  \
# 6       /funding-round/59a3669a64e39360c2b939300bcda162              venture
# 7       /funding-round/86d22afc65107b6941e6c43c671ecbb8              venture
# 9       /funding-round/33c3f135f05d7b734b8d7b7c8ae82647                 seed
# 10      /funding-round/029720f7eeb218f51c43df5155671472  equity_crowdfunding
# 11      /funding-round/766b0bcead9ca8560af5e1ade579fb7f  equity_crowdfunding
# ...                                                 ...                  ...
# 148074  /funding-round/cc8cd96a500332d5b4f4bcbddb306099                angel
# 148075  /funding-round/7a0fa791c96c9c447ee54662395beab9              venture
# 148081  /funding-round/87b5f54b90a09a05ed3d1b8ee509ed11     convertible_note
# 148082  /funding-round/22ef2fafb4d20ac3aa4b86143dbf6c8e                 seed
# 148095  /funding-round/5c5ebcc9d85c2a5f810e319c249a36e7              venture
#
#          raised_amount_usd   funded_at  round_number investor_permalink  \
# 6                 3000000.0 2010-09-23             1          unknown67
# 7                 1000000.0 2010-06-04             2          unknown68
# 9                 1500000.0 2011-04-01             4          unknown69
# 10                  10000.0 2014-08-17             5          unknown70
# 11                  50000.0 2014-09-26             6          unknown71
# ...                     ...        ...           ...                ...
# 148074             875000.0 2010-12-15         83854       unknown33652
# 148075             140500.0 2012-10-18         83855       unknown33653
# 148081              12918.0 2014-09-10         83860       unknown33654
# 148082               7000.0 2011-11-01         83861       unknown33655
# 148095            2000000.0 2009-08-17         83869       unknown33656
#
#            _merge
# 6       left_only
# 7       left_only
# 9       left_only
# 10      left_only
# 11      left_only
# ...           ...
# 148074  left_only
# 148075  left_only
# 148081  left_only
# 148082  left_only
# 148095  left_only
#
# [33590 rows x 8 columns]

# %% [markdown]
# Checking to see if finanicial entity was correctly updated

# %%
investor_entity[investor_entity['permalink'].str.contains('unknown')]
# Out:
#           permalink     name categories market country state city      is_a
# 312        unknown1  unknown    unknown    NaN     NaN   NaN  NaN  investor
# 3388       unknown2  unknown    unknown    NaN     NaN   NaN  NaN  investor
# 8336       unknown3  unknown    unknown    NaN     NaN   NaN  NaN  investor
# 8952       unknown4  unknown    unknown    NaN     NaN   NaN  NaN  investor
# 9268       unknown5  unknown    unknown    NaN     NaN   NaN  NaN  investor
# ...             ...      ...        ...    ...     ...   ...  ...       ...
# 55927  unknown33652  unknown        NaN    NaN     NaN   NaN  NaN  investor
# 55928  unknown33653  unknown        NaN    NaN     NaN   NaN  NaN  investor
# 55929  unknown33654  unknown        NaN    NaN     NaN   NaN  NaN  investor
# 55930  unknown33655  unknown        NaN    NaN     NaN   NaN  NaN  investor
# 55931  unknown33656  unknown        NaN    NaN     NaN   NaN  NaN  investor
#
# [33656 rows x 8 columns]

# %% [markdown]
# ###Adding companies from Rounds

# %% [markdown]
# There are certain companies found in Rounds table that were not present in the original companies table. I add these to the company entity.

# %%
mergeCR = pd.merge(rounds, company_entity[['permalink']], left_on='company_permalink', right_on='permalink', how='outer', indicator=True)
missing_companies = mergeCR[mergeCR['_merge'] == 'left_only'][['company_permalink', 'company_name', 'company_category_list', 'company_market',  'company_country_code', 'company_state_code', 'company_city']].drop_duplicates()
missing_companies.insert(7, 'is_a', 'company')
missing_companies = missing_companies.rename(columns={'company_permalink': 'permalink', 'company_name': 'name','company_category_list': 'categories', 'company_market': 'market', 'company_country_code': 'country', 'company_state_code': 'state', 'company_city': 'city'})

company_entity = pd.concat([company_entity, missing_companies], axis=0)
company_entity
# Out:
#                              permalink                name  \
# 0                /organization/waywire            #waywire
# 1      /organization/tv-communications  &TV Communications
# 2        /organization/rock-your-paper   'Rock' Your Paper
# 3       /organization/in-touch-network   (In)Touch Network
# 4       /organization/r-ranch-and-mine  -R- Ranch and Mine
# ...                                ...                 ...
# 64465     /organization/shift-payments      Shift Payments
# 67874            /organization/sparkow             Sparkow
# 74118             /organization/totems              TOTEMS
# 80113            /organization/wedpics             WedPics
# 83534             /organization/zomato              Zomato
#
#                                               categories         market  \
# 0            Entertainment, Politics, Social Media, News          News
# 1                                                  Games         Games
# 2                                  Publishing, Education    Publishing
# 3      Electronics, Guides, Coffee, Restaurants, Musi...   Electronics
# 4                          Tourism, Entertainment, Games       Tourism
# ...                                                  ...            ...
# 64465      |Finance Technology|Personal Finance|Finance|        Finance
# 67874                                                NaN            NaN
# 74118                                                NaN            NaN
# 80113                                                NaN            NaN
# 83534                                                NaN            NaN
#
#       country state           city     is_a
# 0         USA    NY       New York  company
# 1         USA    CA    Los Angeles  company
# 2         EST   NaN        Tallinn  company
# 3         GBR   NaN         London  company
# 4         USA    TX     Fort Worth  company
# ...       ...   ...            ...      ...
# 64465     USA    CA  San Francisco  company
# 67874     NaN   NaN            NaN  company
# 74118     NaN   NaN            NaN  company
# 80113     NaN   NaN            NaN  company
# 83534     NaN   NaN            NaN  company
#
# [49449 rows x 8 columns]

# %% [markdown]
# ##Adding companies from acquisitions

# %%
mergeCA = pd.merge(acquisitions, company_entity[['permalink']], left_on='company_permalink', right_on='permalink', how='outer', indicator=True)
missing_companiesA = mergeCA[mergeCA['_merge'] == 'left_only'][['company_permalink', 'company_name', 'company_category_list', 'company_market',  'company_country_code', 'company_state_code', 'company_city']].drop_duplicates()
missing_companiesA.insert(7, 'is_a', 'company')
missing_companiesA = missing_companiesA.rename(columns={'company_permalink': 'permalink', 'company_name': 'name','company_category_list': 'categories', 'company_market': 'market', 'company_country_code': 'country', 'company_state_code': 'state', 'company_city': 'city'})

company_entity = pd.concat([company_entity, missing_companiesA], axis=0)

# %% [markdown]
# ##Combining all three entities to form Financial Entity

# %% [markdown]
# ####Starting with merging Company and Investor

# %%
commonCI = pd.merge(company_entity[['permalink']], investor_entity[['permalink']], left_on='permalink', right_on='permalink', how='outer', indicator=True)
commonCIBoth = commonCI[commonCI['_merge'] == 'both']
commonCIBoth = commonCIBoth['permalink']
commonCIRight = commonCI[commonCI['_merge'] == 'right_only']
commonCIRight = commonCIRight['permalink']

financial_entity_schema = company_entity.copy()

for i in commonCIBoth:
  financial_entity_schema.loc[financial_entity_schema['permalink'] == i, 'is_a'] = financial_entity_schema.loc[financial_entity_schema['permalink'] == i, 'is_a'] + ', investor'

for i in commonCIRight:
  financial_entity_schema = financial_entity_schema.append(investor_entity[investor_entity['permalink'] == i], ignore_index=True)


financial_entity_schema
# Out:
#                               permalink                name  \
# 0                 /organization/waywire            #waywire
# 1       /organization/tv-communications  &TV Communications
# 2         /organization/rock-your-paper   'Rock' Your Paper
# 3        /organization/in-touch-network   (In)Touch Network
# 4        /organization/r-ranch-and-mine  -R- Ranch and Mine
# ...                                 ...                 ...
# 113716                     unknown33652             unknown
# 113717                     unknown33653             unknown
# 113718                     unknown33654             unknown
# 113719                     unknown33655             unknown
# 113720                     unknown33656             unknown
#
#                                                categories         market  \
# 0             Entertainment, Politics, Social Media, News          News
# 1                                                   Games         Games
# 2                                   Publishing, Education    Publishing
# 3       Electronics, Guides, Coffee, Restaurants, Musi...   Electronics
# 4                           Tourism, Entertainment, Games       Tourism
# ...                                                   ...            ...
# 113716                                                NaN            NaN
# 113717                                                NaN            NaN
# 113718                                                NaN            NaN
# 113719                                                NaN            NaN
# 113720                                                NaN            NaN
#
#        country state         city      is_a
# 0          USA    NY     New York   company
# 1          USA    CA  Los Angeles   company
# 2          EST   NaN      Tallinn   company
# 3          GBR   NaN       London   company
# 4          USA    TX   Fort Worth   company
# ...        ...   ...          ...       ...
# 113716     NaN   NaN          NaN  investor
# 113717     NaN   NaN          NaN  investor
# 113718     NaN   NaN          NaN  investor
# 113719     NaN   NaN          NaN  investor
# 113720     NaN   NaN          NaN  investor
#
# [113721 rows x 8 columns]

# %%
#financial_entity_schema[financial_entity_schema['is_a'] == 'investor']
financial_entity_schema[financial_entity_schema.duplicated(subset='permalink', keep='first')]
# Out:
# Empty DataFrame
# Columns: [permalink, name, categories, market, country, state, city, is_a]
# Index: []

# %% [markdown]
# ####Merging Result with Acquirers

# %%
commonCA = pd.merge(financial_entity_schema[['permalink']], acquirer_entity[['permalink']], left_on='permalink', right_on='permalink', how='outer', indicator=True)
commonCABoth = commonCA[commonCA['_merge'] == 'both']
commonCABoth = commonCABoth['permalink']
commonCARight = commonCA[commonCA['_merge'] == 'right_only']
commonCARight = commonCARight['permalink']

for i in commonCABoth:
  financial_entity_schema.loc[financial_entity_schema['permalink'] == i, 'is_a'] = financial_entity_schema.loc[financial_entity_schema['permalink'] == i, 'is_a'] + ', acquirer'

for i in commonCARight:
  financial_entity_schema = financial_entity_schema.append(acquirer_entity[acquirer_entity['permalink'] == i], ignore_index=True)


financial_entity_schema
# Out:
#                                    permalink                    name  \
# 0                      /organization/waywire                #waywire
# 1            /organization/tv-communications      &TV Communications
# 2              /organization/rock-your-paper       'Rock' Your Paper
# 3             /organization/in-touch-network       (In)Touch Network
# 4             /organization/r-ranch-and-mine      -R- Ranch and Mine
# ...                                      ...                     ...
# 117200            /organization/apsis-sweden            Apsis Sweden
# 117201           /organization/webjet-com-au           Webjet.com.au
# 117202   /organization/nestle-purina-petcare   Nestle Purina Petcare
# 117203         /organization/cupcake-digital         Cupcake Digital
# 117204  /organization/chiesi-pharmaceuticals  Chiesi Pharmaceuticals
#
#                                                categories            market  \
# 0             Entertainment, Politics, Social Media, News             News
# 1                                                   Games            Games
# 2                                   Publishing, Education       Publishing
# 3       Electronics, Guides, Coffee, Restaurants, Musi...      Electronics
# 4                           Tourism, Entertainment, Games          Tourism
# ...                                                   ...               ...
# 117200                                        Advertising       Advertising
# 117201                   Travel & Tourism, Hotels, Travel  Travel & Tourism
# 117202                                               Pets              Pets
# 117203                                              Games             Games
# 117204                                      Biotechnology     Biotechnology
#
#        country state         city      is_a
# 0          USA    NY     New York   company
# 1          USA    CA  Los Angeles   company
# 2          EST   NaN      Tallinn   company
# 3          GBR   NaN       London   company
# 4          USA    TX   Fort Worth   company
# ...        ...   ...          ...       ...
# 117200     SWE   NaN        Malma  acquirer
# 117201     AUS   NaN    Melbourne  acquirer
# 117202     USA    MO     St Louis  acquirer
# 117203     USA    NY     New York  acquirer
# 117204     ITA   NaN        Parma  acquirer
#
# [117205 rows x 8 columns]

# %%
#financial_entity_schema[financial_entity_schema['is_a'] == 'company, investor, acquirer']
financial_entity_schema[financial_entity_schema.duplicated(subset='permalink', keep='first')]
# Out:
# Empty DataFrame
# Columns: [permalink, name, categories, market, country, state, city, is_a]
# Index: []

# %% [markdown]
# ###Creating ID

# %%
financial_entity_schema['ID'] = np.arange(len(financial_entity_schema))
financial_entity_schema
# Out:
#                                    permalink                    name  \
# 0                      /organization/waywire                #waywire
# 1            /organization/tv-communications      &TV Communications
# 2              /organization/rock-your-paper       'Rock' Your Paper
# 3             /organization/in-touch-network       (In)Touch Network
# 4             /organization/r-ranch-and-mine      -R- Ranch and Mine
# ...                                      ...                     ...
# 117200            /organization/apsis-sweden            Apsis Sweden
# 117201           /organization/webjet-com-au           Webjet.com.au
# 117202   /organization/nestle-purina-petcare   Nestle Purina Petcare
# 117203         /organization/cupcake-digital         Cupcake Digital
# 117204  /organization/chiesi-pharmaceuticals  Chiesi Pharmaceuticals
#
#                                                categories            market  \
# 0             Entertainment, Politics, Social Media, News             News
# 1                                                   Games            Games
# 2                                   Publishing, Education       Publishing
# 3       Electronics, Guides, Coffee, Restaurants, Musi...      Electronics
# 4                           Tourism, Entertainment, Games          Tourism
# ...                                                   ...               ...
# 117200                                        Advertising       Advertising
# 117201                   Travel & Tourism, Hotels, Travel  Travel & Tourism
# 117202                                               Pets              Pets
# 117203                                              Games             Games
# 117204                                      Biotechnology     Biotechnology
#
#        country state         city      is_a      ID
# 0          USA    NY     New York   company       0
# 1          USA    CA  Los Angeles   company       1
# 2          EST   NaN      Tallinn   company       2
# 3          GBR   NaN       London   company       3
# 4          USA    TX   Fort Worth   company       4
# ...        ...   ...          ...       ...     ...
# 117200     SWE   NaN        Malma  acquirer  117200
# 117201     AUS   NaN    Melbourne  acquirer  117201
# 117202     USA    MO     St Louis  acquirer  117202
# 117203     USA    NY     New York  acquirer  117203
# 117204     ITA   NaN        Parma  acquirer  117204
#
# [117205 rows x 9 columns]

# %% [markdown]
# ##Company

# %%
company_schema = financial_entity_schema[financial_entity_schema['is_a'].str.contains('company')][['permalink', 'ID']]
company_schema = pd.merge(company_schema, companies[['permalink', 'founded_at', 'homepage_url', 'status']], left_on='permalink', right_on='permalink', how='left')
company_schema = company_schema.sort_values(by='ID', ascending=True)
company_schema = company_schema[['ID', 'founded_at', 'homepage_url', 'status']]
company_schema = company_schema.rename(columns={'ID': 'company_ID', 'founded_at': 'founding_date', 'homepage_url': 'homepage_URL'})

# %%
company_schema['status'] = company_schema['status'].apply(lambda x: replace_nan_status(x))
company_schema
# Out:
#        company_ID founding_date                   homepage_URL     status
# 0               0    2012-06-01         http://www.waywire.com   acquired
# 1               1           NaT          http://enjoyandtv.com  operating
# 2               2    2012-10-26   http://www.rockyourpaper.org  operating
# 3               3    2011-04-01  http://www.InTouchNetwork.com  operating
# 4               4    2014-01-01                            NaN  operating
# ...           ...           ...                            ...        ...
# 58447       58447           NaT                            NaN    unknown
# 58448       58448           NaT                            NaN    unknown
# 58449       58449           NaT                            NaN    unknown
# 58450       58450           NaT                            NaN    unknown
# 58451       58451           NaT                            NaN    unknown
#
# [58452 rows x 4 columns]

# %% [markdown]
# ##Investor

# %%
investor_schema = financial_entity_schema[financial_entity_schema['is_a'].str.contains('investor')][['permalink', 'ID']]
investor_schema = pd.merge(investor_schema, investments[['investor_permalink', 'is_person']], left_on='permalink', right_on='investor_permalink', how='left')
investor_schema = investor_schema.sort_values(by='ID', ascending=True)
investor_schema = investor_schema[['ID', 'is_person']]
investor_schema = investor_schema.rename(columns={'ID': 'investor_ID'})
investor_schema = investor_schema.drop_duplicates("investor_ID")
investor_schema
# Out:
#         investor_ID is_person
# 0                67     False
# 1               107     False
# 13              136     False
# 14              185     False
# 15              190     False
# ...             ...       ...
# 148091       113716       NaN
# 148092       113717       NaN
# 148093       113718       NaN
# 148094       113719       NaN
# 148095       113720       NaN
#
# [55932 rows x 2 columns]

# %% [markdown]
# ##Acquisition

# %%
acquisition_schema = financial_entity_schema[financial_entity_schema['is_a'].str.contains('acquirer')][['permalink', 'ID']]
acquisition_schema = pd.merge(acquisition_schema, acquisitions[['acquirer_permalink', 'company_permalink', 'acquired_at', ' price_amount ', 'price_currency_code']], left_on='permalink', right_on='acquirer_permalink', how='left')
acquisition_schema = acquisition_schema.rename(columns={'ID': 'acquirer_ID', ' price_amount ': 'price', 'price_currency_code': 'currency', 'acquired_at': 'date'})
acquisition_schema = pd.merge(acquisition_schema, financial_entity_schema[['permalink', 'ID']], left_on='company_permalink', right_on='permalink', how='left')
acquisition_schema = acquisition_schema[['acquirer_ID', 'ID', 'date', 'price', 'currency']]
acquisition_schema = acquisition_schema.rename(columns={'ID': 'acquired_ID'})
acquisition_schema
# Out:
#        acquirer_ID  acquired_ID       date       price currency
# 0               38        53372 2011-03-28         NaN      USD
# 1               38        54909 2011-04-05         NaN      USD
# 2               67         6603 2008-07-18  80000000.0      USD
# 3               90        55198 2012-09-18         NaN      USD
# 4               93        15577 2014-09-15         NaN      USD
# ...            ...          ...        ...         ...      ...
# 13064       117200        49304 2012-06-17         NaN      USD
# 13065       117201        58440 2013-03-01  25000000.0      AUD
# 13066       117202        58441 2014-01-15         NaN      USD
# 13067       117203        49393 2014-03-12         NaN      USD
# 13068       117204        58445 2013-08-26         NaN      USD
#
# [13069 rows x 5 columns]

# %% [markdown]
# ##Round Creation

# %%
round_schema = pd.merge(round_schema, financial_entity_schema[['permalink','ID']], left_on='company_permalink', right_on='permalink', how='left')
round_schema = round_schema.rename(columns={'ID': 'company_ID', 'funding_round_type': 'round_type', ' raised_amount_usd ': 'amount_USD', 'funded_at': 'date'})
round_schema = pd.merge(round_schema, financial_entity_schema[['permalink','ID']], left_on='investor_permalink', right_on='permalink', how='left')
round_schema = round_schema[['company_ID', 'ID', 'round_number', 'round_type', 'amount_USD', 'date']]

# %%
round_schema = round_schema.rename(columns={'ID': 'investor_ID'})
round_schema
# Out:
#         company_ID  investor_ID  round_number round_type  amount_USD  \
# 0                0        66814             0       seed   1750000.0
# 1                0        59532             0       seed   1750000.0
# 2                0        65705             0       seed   1750000.0
# 3                0        64316             0       seed   1750000.0
# 4                0        71038             0       seed   1750000.0
# ...            ...          ...           ...        ...         ...
# 148091       49435        59224         83868    venture  10000000.0
# 148092       49435        59037         83868    venture  10000000.0
# 148093       49435        60929         83868    venture  10000000.0
# 148094       49435        58520         83868    venture  10000000.0
# 148095       49435       113720         83869    venture   2000000.0
#
#              date
# 0      2012-06-30
# 1      2012-06-30
# 2      2012-06-30
# 3      2012-06-30
# 4      2012-06-30
# ...           ...
# 148091 2011-01-03
# 148092 2011-01-03
# 148093 2011-01-03
# 148094 2011-01-03
# 148095 2009-08-17
#
# [148096 rows x 6 columns]
# Warning: total number of rows (148096) exceeds max_rows (20000). Limiting to first (20000) rows.

# %% [markdown]
# ##Final Financial Entity

# %%
financial_entity_schema = financial_entity_schema[['ID', 'name', 'categories', 'market', 'country', 'state', 'city', 'is_a']]
financial_entity_schema
# Out:
#             ID                    name  \
# 0            0                #waywire
# 1            1      &TV Communications
# 2            2       'Rock' Your Paper
# 3            3       (In)Touch Network
# 4            4      -R- Ranch and Mine
# ...        ...                     ...
# 117200  117200            Apsis Sweden
# 117201  117201           Webjet.com.au
# 117202  117202   Nestle Purina Petcare
# 117203  117203         Cupcake Digital
# 117204  117204  Chiesi Pharmaceuticals
#
#                                                categories            market  \
# 0             Entertainment, Politics, Social Media, News             News
# 1                                                   Games            Games
# 2                                   Publishing, Education       Publishing
# 3       Electronics, Guides, Coffee, Restaurants, Musi...      Electronics
# 4                           Tourism, Entertainment, Games          Tourism
# ...                                                   ...               ...
# 117200                                        Advertising       Advertising
# 117201                   Travel & Tourism, Hotels, Travel  Travel & Tourism
# 117202                                               Pets              Pets
# 117203                                              Games             Games
# 117204                                      Biotechnology     Biotechnology
#
#        country state         city      is_a
# 0          USA    NY     New York   company
# 1          USA    CA  Los Angeles   company
# 2          EST   NaN      Tallinn   company
# 3          GBR   NaN       London   company
# 4          USA    TX   Fort Worth   company
# ...        ...   ...          ...       ...
# 117200     SWE   NaN        Malma  acquirer
# 117201     AUS   NaN    Melbourne  acquirer
# 117202     USA    MO     St Louis  acquirer
# 117203     USA    NY     New York  acquirer
# 117204     ITA   NaN        Parma  acquirer
#
# [117205 rows x 8 columns]
# Warning: total number of rows (117205) exceeds max_rows (20000). Limiting to first (20000) rows.

# %% [markdown]
# #Convert to CSV files

# %%
financial_entity_schema.to_csv('Financial_Entity_Schema.csv', index=False)

# %%
company_schema.to_csv('Company_Schema.csv', index=False)

# %%
investor_schema.to_csv('Investor_Schema.csv', index=False)

# %%
round_schema.to_csv('Round_Schema.csv', index=False)

# %%
acquisition_schema.to_csv('Acquisition_Schema.csv', index=False)
